# %% [markdown]
# # ***DATA HANDLING***
# Pada pertemuan kesebelas ini, akan dilakukan praktek *Data Handling* -- mulai dari proses parsing, manipulasi, dan pengolahan agar dapat dihasilkan sebuah dataframe yang siap dianalisis lebih lanjut untuk memperoleh *insights*. Dalam latihan kali ini, kita akan menggunakan salah satu dataset dari koleksi datasets yang disediakan oleh **R** secara gratis pada [Link](https://vincentarelbundock.github.io/Rdatasets/datasets.html) berikut.
#
# Proses *data handling* mensyaratkan penguasaan beragam teknik pengolahan data yang meliputi teknik-teknik mulai dari parsing data, manipulasi kolom data, pembuatan ringkasan statistik, visualisasi data, hingga ke pemahaman pola yang muncul dalam data. Tingkat kesulitan dari proses ini akan sangat tergantung pada kondisi dataset yang tersedia. Dataset yang tergolong sudah rapi cenderung akan mudah untuk di-*handle*, sebaliknya *dataset* yang 'berantakan' akan membutuhkan waktu *handling* yang jauh lebih panjang. Oleh karena itu, paparan terhadap berbagai jenis data set dari bermacam sumber akan meningkatkan kemahiran data analis dalam melakukan data handling yang akan menentukan kelancaran proses *data handling* ini.
#
# Secara umum pertemuan ini adalah sebuah sessi perkenalan terhadap kegiatan *data handling*, khususnya dengan pemanfaatan modul **pandas** dalam **Python** sebagai alat untuk melakukan *data handling*, melalui kegiatan praktek langsung. Pada praktek ini, berbagai `functions` dan `methods`, baik yang telah disampaikan pada pertemuan-pertemuan sebelumnya maupun yang baru akan diterapkan terhadap dataset `Titanic.csv` untuk menghasilkan sebuah dataset yang rapi hingga siap dipergunakan sebagai bahan analisis lebih lanjut. Untuk membantu memahami berbagai teknik yang diterapkan, maka pada hampir setiap proses akan disertakan juga **TECHNICAL NOTE** yang merupakan penjelasan ringkas dari teknik yang diterapkan.
#
# ## ***Dataset Titanic***
# > Dataset Titanic berisikan informasi rinci tentang penumpang yang berada di kapal **MS. Titanic**, yang tenggelam pada 15 April 1912 setelah bertabrakan dengan gunung es, dan merupakan salah satu dataset yang paling populer digunakan dalam *data science* terutama untuk materi klasifikasi.
#
# Salah satu jenis analisis yang paling umum dilakukan menggunakan dataset Titanic adalah melakukan *Survival Analysis* yang melibatkan pembangunan model *Machine Learning* untuk memprediksi kelangsungan hidup penumpang berdasarkan karakteristiknya. Fitur seperti jenis kelamin dan kelas memiliki dampak signifikan terhadap tingkat kelangsungan hidup seorang penumpang. Sebagai ilustrasi, wanita dan anak-anak akan memiliki peluang hidup yang lebih tinggi dibanding kelompok lain, karena adanya protokol evakuasi yang mendahulukan kedua kelompok tersebut. Selain itu penumpang di kelas yang lebih tinggi (1st) memiliki peluang selamat yang lebih besar dibandingkan dengan mereka yang menumpang di kelas lebih rendah (2nd dan 3rd).

# %% [markdown]
# # PRAKTEK
# ## *Data Parsing*
# Data parsing mengacu pada proses ekstraksi, interpretasi, dan transformasi data dari satu format ke format lain, sehingga siap untuk dianalisis. Dalam konteks **data science**, parsing sangat penting untuk menangani data yang berasal dari berbagai sumber data seperti CSV, JSON, XML, atau *database*. Tujuannya adalah mengubah data mentah menjadi bentuk terstruktur, seperti **DataFrame** dalam **pandas**, yang siap digunakan untuk analisis.
#
# Di dalam modul **pandas** tersedia beberapa *tools* untuk melakukan parsing data, seperti:
#
# 1. **Membaca Data**:
#    - `pd.read_csv()`: Untuk membaca file CSV.
#    - `pd.read_json()`: Untuk parsing data JSON.
#    - `pd.read_excel()`: Untuk membaca data dari file Excel.
#    - `pd.read_sql()`: Untuk membaca query SQL ke dalam DataFrame.
#
# 2. **Pembersihan Data**: Setelah parsing, data sering kali perlu dibersihkan, seperti menangani nilai yang hilang, memformat string, atau menghapus duplikat. Alat seperti `df.fillna()`, `df.dropna()`, dan `df.replace()` sangat berguna dalam proses ini.
#
# 3. **Parsing String**: Akses `str` di pandas memungkinkan manipulasi dan parsing data teks, sehingga lebih mudah mengekstrak informasi dari string menggunakan fungsi seperti `str.split()`, `str.contains()`, dan `str.extract()` untuk parsing berbasis regular expression.
#
# 4. **Parsing Tanggal**: `pd.to_datetime()` dapat memparsing string tanggal menjadi objek datetime yang tepat, yang sangat penting ketika bekerja dengan data deret waktu.
#
# Data parsing adalah langkah dasar yang memungkinkan manipulasi dan analisis data selanjutnya, memastikan bahwa data mentah disiapkan dalam bentuk yang dapat dengan mudah diolah dan dieksplorasi.

# %%
import pandas as pd

# %%
# Set file path
file_path_titanic = 'https://vincentarelbundock.github.io/Rdatasets/csv/Stat2Data/Titanic.csv'

# Data Parsing
df_titanic = pd.read_csv(file_path_titanic).set_index('rownames')

# %% [markdown]
# ### Pengecekan Awal
#
# *Preliminary Checking* adalah tahap perkenalan paling awal dengan dataset yang akan ditangani. Umumnya perkenalan terhadap dataset dimulai dengan menggali informasi terkait struktur, dan statistik deskriptif dari dataset. Dari hasil *preliminary checking* ini seorang data analis dapat menilai berbagai kekurangan dari dataset, sehingga memperoleh **perkiraan** awal proses apa saja yang perlu dilakukan untuk mempersiapkan data bagi analisis lebih lanjut.
#
# Pengenalan struktur dataset dilakukan dengan mencari informasi terkait dimensi dataset, seperti jumlah rows serta kolom yang terdapat pada dataset tersebut. Informasi penting lain yang biasanya diperoleh pada tahap ini adalah tipe data pada masing-masing kolom, berbagai pattern dari formatting data yang dikenakan, dan kelengkapan data setiap rows pada dataset.
#
# Sebagai pendalaman, pada tahap selanjutnya biasanya dilakukan analisis statistik deskriptif untuk memperoleh informasi sebaran dari data pada masing-masing kolom. Berbagai indikator yang dihasilkan dari analisis statistik desktiptif--semacam frekuensi, nilai minimum dan maksimum, rata-rata, median, kwartil pertama, kwartil ketiga, serta modus--dapat membantu kita untuk mengetahui kondisi dataset lebih mendalam.

# %% [markdown]
# #### Struktur Dataset

# %%
# Cek lima rows paling atas
df_titanic.head()
# Out:
#                                                    Name PClass    Age     Sex  \
# rownames
# 1                          Allen, Miss Elisabeth Walton    1st  29.00  female
# 2                           Allison, Miss Helen Loraine    1st   2.00  female
# 3                   Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 4         Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 5                         Allison, Master Hudson Trevor    1st   0.92    male
#
#           Survived  SexCode
# rownames
# 1                1        1
# 2                0        1
# 3                0        0
# 4                0        1
# 5                1        0

# %%
# Cek lima rows paling bawah
df_titanic.tail()
# Out:
#                             Name PClass   Age   Sex  Survived  SexCode
# rownames
# 1309          Zakarian, Mr Artun    3rd  27.0  male         0        0
# 1310      Zakarian, Mr Maprieder    3rd  26.0  male         0        0
# 1311            Zenni, Mr Philip    3rd  22.0  male         0        0
# 1312            Lievens, Mr Rene    3rd  24.0  male         0        0
# 1313              Zimmerman, Leo    3rd  29.0  male         0        0

# %%
# Cek Struktur Data
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1313 entries, 1 to 1313
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1313 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
#  5   SexCode   1313 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 71.8+ KB

# %% [markdown]
# ___
# **RESUME**: Struktur Dataset
#
# Tuliskan temuan dari proses pengecekan visual struktur data!
# 1. Penulisan nama formatnya Surname, Title, Firstname
# 2. Penulisan Surname terpisah oleh karakter ',' dengan Title dan Firstname;
# 3. Kolom Sex redundant dengan kolom SexCode;
# 4. missing value di kolom Age.
# ___

# %% [markdown]
# #### Statistik Deskriptif

# %%
# Cek Statistik Deskriptif
df_titanic.describe() # Secara default hanya menampilkan Stat Desc untuk kolom numeric
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %%
# Cek Statistik Deskriptif
df_titanic.describe(include='object') # Untuk menampilkan Stat Desc tipe data tertentu (float, int, object, category, all)
# Out:
#                        Name PClass   Sex
# count                  1313   1313  1313
# unique                 1310      4     2
# top     Connolly, Miss Kate    3rd  male
# freq                      2    711   851

# %% [markdown]
# ___
# **RESUME**: Statistik Deskriptif
#
# Tuliskan hasil temuan Analisis Deskriptif!!
# 1. Cek nama penumpang yang terduplikasi
# 2. Perkiraan ada 2 nama terduplikasi, masing-masing 2 kali.
# 3. Kategori kelas penumpang, apa aja sih? ada 4.
# ___

# %% [markdown]
# ### Pengecekan Lanjutan
# *Follow up checking* adalah tahap dimana berbagai pertanyaan, dan dugaan terkait isi dari dataset dijawab, sehingga seorang data analis dapat menggali informasi lebih dalam dan jauh lebih mengenali dataset yang sedang ditangani.
#
# Beberapa temuan penting pada pengecekan terdahulu atas dataset pada dataframe `df_titanic` adalah sebagai berikut:
# 1. Terdapat duplikasi data:
#   - Perlu diverifikasi apakah duplikasi Nama terjadi karena pencatatan terhadap objek yang sama;
#   - Perlu dicermati apakah terjadi duplikasi baris pada dataset.
# 2. Terdapat *Missing Values*:
#   - Harus dicermati rows mana saja yang terdapat *missing values*;
#   - Harus dicermati seberapa banyak *missing values* yang ada;
#   - Harus diputuskan apa yang harus dilakukan terhadap *missing values* yang ada (dihapus, diisi) dan jika harus diisi, metode apa yang akan dipergunakan untuk mengisi.
# 3. Terdapat *formatting* penulisan data pada kolom `Name` dan `PClass`, sehingga perlu dicermati keseragaman data pada kedua kolom tersebut.

# %% [markdown]
# #### Pengecekan Duplikasi
# Salah satu hal yang harus dipastikan ketika melakukan data handling adalah, **tidak ada rows yang terduplikasi**. Dalam hal ini, yang dimaksud dengan duplikasi adalah kejadian di mana sebuah transaksi tercatat secara berulang pada dataset. Rows yang terduplikasi harus dihilangkan dari dataset pada proses data handling, karena dapat mengakibatkan bias pada hasil analisis.
#
# Modul `pandas` menyediakan method `duplicated` dan `drop_duplicates` untuk melakukan penanganan terhadap rows yang terduplikasi. Berikut ini adalah ilustrasi penggunaan method `duplicated` untuk mengamati dan menghilangkan rows yang terduplikasi:
# ```python
# # MENGAMATI ROWS TERDUPLIKASI
# # 1. Buat filter untuk rows terduplikat
# filter_duplicated_first = dataframe.duplicated(keep='first')
# filter_duplicated_last = dataframe.duplicated(keep='last')
# filter_duplicated_False = dataframe.duplicated(keep=False)
#
# # 2. Sortir data menggunakan salah satu filter di atas
# dataframe.loc[filter_duplicated_first, :].sort_values(by=list(dataframe.columns))
#
# # MENGHILANGKAN ROWS TERDUPLIKASI
# # 1. Menghilangkan seluruh rows duplikasi selain rows duplikasi pertama
# dataframe.drop_duplicates(keep='first', inplace=True)
#
# # 2. Menghilangkan seluruh rows duplikasi selain rows duplikasi terakhir
# dataframe.drop_duplicates(keep='last', inplace=True)
#
# # 3. Menghilangkan seluruh rows duplikasi tanpa kecuali
# dataframe.drop_duplicates(keep=False, inplace=True)
# ```
# ___

# %% [markdown]
# **ILUSTRASI: HANDLING DUPLICATED ROWS**

# %%
"""
Amir, Budi, Cici, dan Didi bermain lempar dadu sebanyak 6 ronde.
Hasil setiap lemparan setiap pemain dicatat pada dataframe df.
Akan tetapi terjadi kesalahan pencatatan,
sehingga terdapat dua ronde yang tercatatkan 2 kali.
"""
data = {
  "Amir":[1, 2, 3, 4, 1, 1, 6, 4],
  "Budi":[3, 1, 1, 1, 3, 4, 5, 1],
  "Cici":[4, 4, 4, 4, 4, 4, 4, 4],
  "Didi":[6, 6, 6, 6, 6, 6, 6, 6]
}

# Parse data menjadi sebuah dataframe
df = pd.DataFrame(data)

# Cek isi dataframe
df
# Out:
#    Amir  Budi  Cici  Didi
# 0     1     3     4     6
# 1     2     1     4     6
# 2     3     1     4     6
# 3     4     1     4     6
# 4     1     3     4     6
# 5     1     4     4     6
# 6     6     5     4     6
# 7     4     1     4     6

# %%
# Cek duplicate jika "keep='first'"
filter_duplicated_first = df.duplicated(keep='first')
df.loc[filter_duplicated_first, :]
# Out:
#    Amir  Budi  Cici  Didi
# 4     1     3     4     6
# 7     4     1     4     6

# %%
# Cek duplicate jika "keep='last'"
filter_duplicated_last = df.duplicated(keep='last')
df.loc[filter_duplicated_last, :]
# Out:
#    Amir  Budi  Cici  Didi
# 0     1     3     4     6
# 3     4     1     4     6

# %%
# Cek duplicate jika "keep=False"
filter_duplicated_false = df.duplicated(keep=False)
df.loc[filter_duplicated_false, :].sort_values(by=list(df.columns))
# Out:
#    Amir  Budi  Cici  Didi
# 0     1     3     4     6
# 4     1     3     4     6
# 3     4     1     4     6
# 7     4     1     4     6

# %%
# Buang seluruh duplikat kecuali data duplikat pertama
df.drop_duplicates(keep='first')
# Out:
#    Amir  Budi  Cici  Didi
# 0     1     3     4     6
# 1     2     1     4     6
# 2     3     1     4     6
# 3     4     1     4     6
# 5     1     4     4     6
# 6     6     5     4     6

# %%
# Buang seluruh duplikat kecuali duplikat terakhir
df.drop_duplicates(keep='last')
# Out:
#    Amir  Budi  Cici  Didi
# 1     2     1     4     6
# 2     3     1     4     6
# 4     1     3     4     6
# 5     1     4     4     6
# 6     6     5     4     6
# 7     4     1     4     6

# %%
# Buang seluruh duplikat tanpa kecuali
df.drop_duplicates(keep=False)
# Out:
#    Amir  Budi  Cici  Didi
# 1     2     1     4     6
# 2     3     1     4     6
# 5     1     4     4     6
# 6     6     5     4     6

# %% [markdown]
# ___
# 1. Duplicated Rows

# %%
# Buat filter menggunakan method 'duplicated'
filter_duplicated_rows = df_titanic.duplicated(keep=False)

# Pergunakan filter_duplicated_rows untuk memfilter dataframe
df_titanic.loc[filter_duplicated_rows, :]
# Out:
# Empty DataFrame
# Columns: [Name, PClass, Age, Sex, Survived, SexCode]
# Index: []

# %% [markdown]
# 2. Duplicated `Name` Values

# %%
# Buat Filter menggunakan method 'duplicated'
filter_duplicated_names = df_titanic.duplicated(subset='Name', keep=False)

# Lakukan filtering dataframe menggunakan filter_duplicated_names
df_titanic.loc[filter_duplicated_names, :]
# Out:
#                              Name PClass   Age     Sex  Survived  SexCode
# rownames
# 45        Carlsson, Mr Frans Olof    1st  33.0    male         0        0
# 708       Carlsson, Mr Frans Olof    3rd  33.0    male         0        0
# 729           Connolly, Miss Kate    3rd  30.0  female         0        1
# 730           Connolly, Miss Kate    3rd  22.0  female         1        1
# 922               Kelly, Mr James    3rd  44.0    male         0        0
# 923               Kelly, Mr James    3rd  42.0    male         0        0

# %% [markdown]
# ___
# **RESUME**: *Duplications*
#
# Write down your findings here:
# 1. ... abacab ...
# 2. ... abacab ...

# %% [markdown]
# ___
# #### Mendeteksi *Missing Values*
# Modul `pandas` menotasikan *missing values* sebagai `NaN`, sebuah object bertipe `float`, yang sering kali diartikan sebagai *Not a Number*. Dalam bahasa pemrograman SQL, padanan dari `NaN` ini adalah `null`, yang menunjukkan bahwa tidak ada nilai yang tercatat untuk *field* tersebut.
#
# Seperti nilai `null`, `NaN` tidak dihitung dalam proses agregasi seperti `count` maupun `sum`, sehingga keberadaannya akan sangat mempengaruhi hasil dari analisis. Oleh karena itu, penanganan *missing values* merupakan salah satu proses yang sangat penting dalam *data handling*, terutama jika data akan digunakan dalam permodelan statistik atau *Machine Learning*. Ada beberapa pendekatan yang bisa diambil untuk menangani *missing values*, tergantung pada konteks dan tujuan analisis:
#
# 1. Penghapusan (*Deletion*)<br>
#    **Jenis dan cara** penghapusan:
#    - **Penghapusan Kolom:** Jika sebuah kolom memiliki banyak *missing values*, lebih efisien untuk menghapus seluruh kolom tersebut, terutama jika variabel tersebut tidak relevan atau tidak memberikan kontribusi signifikan dalam analisis.
#    ```python
#    df.dropna(axis=1)
#    ```
#    - **Penghapusan Baris:** Jika hanya sebagian kecil baris yang mengandung *missing values*, kita dapat mempertimbangkan untuk menghapus baris-baris tersebut. Penghapusan baris umum dilakukan jika data yang hilang bersifat acak dan tidak berjumlah besar.
#    ```python
#    df.dropna(axis=0)
#    ```
#
#   **Kapan Melakukan Deletion**: <br>
#   *Deletion* lebih tepat digunakan jika jumlah *missing values* relatif sedikit, atau saat data yang hilang tidak memiliki signifikansi bagi analisis.
#
# 2. Pengisian Nilai (*Imputation*)<br>
#    Pengisian nilai adalah alternatif lain yang sering kali lebih baik dibandingkan penghapusan data, terutama jika kita perlu menjaga ukuran dataset. Pengisian nilai dapat dilakukan dengan berbagai cara:
#    - **Mengisi dengan Nilai Konstan:** Misalnya, kita bisa menggantikan *missing values* dengan nilai tertentu seperti 0, atau kata "Unknown" untuk tipe data teks.
#    ```python
#    df.fillna(0)
#    df.fillna("Unknown")
#    ```
#    - **Mengisi dengan Statistik:** *Missing values* bisa diisi dengan nilai rata-rata (*mean*) atau median--bagi data `numeric`--atau modus--bagi data `string`--dari data lain yang tersedia. Cara ini sering digunakan jika data *missing* terdistribusi secara acak.
#    ```python
#    df.fillna(df['Age'].mean())
#    df.fillna(df['Age'].median())
#    df.fillna(df['Firstname'].mode())
#    ```
#    - **Interpolasi:** Teknik interpolasi menggunakan data di sekitar *missing values* untuk memperkirakan nilai yang hilang. Interpolasi ini sangat tepat untuk dipergunakan jika dataset berisikan data deret waktu atau data kontinu.
#    ```python
#    df.interpolate()
#    ```
#
#   **Kapan Melakukan Imputation:** <br>
#   *Imputation* lebih tepat untuk dilakukan jika kolom atau baris dengan *missing values* mengandung informasi penting, atau jika penghapusan akan menyebabkan hilangnya terlalu banyak data. Namun, metode yang digunakan harus dipilih dengan hati-hati agar tidak mengubah karakteristik asli data.
# ___

# %% [markdown]
# 1. Rows with missing values

# %%
# Creating Filter for missing value
filter_missing_values = df_titanic['Age'].isnull()

# Selecting Rows with missing Age value
df_titanic.loc[filter_missing_values, :]
# Out:
#                                   Name PClass  Age     Sex  Survived  SexCode
# rownames
# 13        Aubert, Mrs Leontine Pauline    1st  NaN  female         1        1
# 14            Barkworth, Mr Algernon H    1st  NaN    male         1        0
# 15                  Baumann, Mr John D    1st  NaN    male         0        0
# 30             Borebank, Mr John James    1st  NaN    male         0        0
# 33                  Bradley, Mr George    1st  NaN    male         1        0
# ...                                ...    ...  ...     ...       ...      ...
# 1301             Wiseman, Mr Phillippe    3rd  NaN    male         0        0
# 1303                 Yalsevac, Mr Ivan    3rd  NaN    male         1        0
# 1306                Youssef, Mr Gerios    3rd  NaN    male         0        0
# 1307               Zabour, Miss Hileni    3rd  NaN  female         0        1
# 1308               Zabour, Miss Tamini    3rd  NaN  female         0        1
#
# [557 rows x 6 columns]

# %%
# Creating filter
filter_non_missing_values = ~df_titanic['Age'].isnull()
# df_titanic['Age'].notnull()

# Selecting rows with Age value not missing
df_titanic.loc[filter_non_missing_values, :]
# Out:
#                                                    Name PClass    Age     Sex  \
# rownames
# 1                          Allen, Miss Elisabeth Walton    1st  29.00  female
# 2                           Allison, Miss Helen Loraine    1st   2.00  female
# 3                   Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 4         Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 5                         Allison, Master Hudson Trevor    1st   0.92    male
# ...                                                 ...    ...    ...     ...
# 1309                                 Zakarian, Mr Artun    3rd  27.00    male
# 1310                             Zakarian, Mr Maprieder    3rd  26.00    male
# 1311                                   Zenni, Mr Philip    3rd  22.00    male
# 1312                                   Lievens, Mr Rene    3rd  24.00    male
# 1313                                     Zimmerman, Leo    3rd  29.00    male
#
#           Survived  SexCode
# rownames
# 1                1        1
# 2                0        1
# 3                0        0
# 4                0        1
# 5                1        0
# ...            ...      ...
# 1309             0        0
# 1310             0        0
# 1311             0        0
# 1312             0        0
# 1313             0        0
#
# [756 rows x 6 columns]

# %% [markdown]
# 2. How many missing values in each columns

# %%
# Lakukan method chaining 'isnull' atau 'isna' lalu 'sum' terhadap df_titanic
df_titanic.isnull().sum()
# Out:
# Name          0
# PClass        0
# Age         557
# Sex           0
# Survived      0
# SexCode       0
# dtype: int64

# %% [markdown]
# ___
# **RESUME**: *Missing Values*
#
# Write down your findings here:
# 1. ... abacab ...
# 2. ... abacab ...
# ___

# %% [markdown]
# #### Pengecekan Konsistensi Format Data String

# %% [markdown]
# ##### Column `Name`: Naming Conventions

# %% [markdown]
# 1. Kolom `Name` memisahkan `surname` dengan `title` dan `firstname` menggunakan karakter koma

# %%
# Set pattern yang akan di cek
pattern_koma = ","

# create filter for values with comma
filter_comma = df_titanic['Name'].str.contains(pat=pattern_koma, na=False, regex=True)

# Select rows using negation of filter_comma
df_titanic.loc[~filter_comma, :]
# Out:
#                          Name PClass  Age   Sex  Survived  SexCode
# rownames
# 457       Jacobsohn Mr Samuel      *  NaN  male         0        0
# 1196      Seman Master Betros    3rd  NaN  male         0        0

# %% [markdown]
# 2. Format penulisan values pada kolom `Name` menggunakan ***Title Case***

# %%
# Tentukan pattern yang akan dicari
pattern_to_find = "\\b[a-z]+\\b"

# Buat filter menggunakan pattern_to_find
filter_lower_case = df_titanic['Name'].str.contains(pat=pattern_to_find, regex=True, na=False)

# Select Rows menggunakan filter_lower_case
df_titanic.loc[filter_lower_case, :]
# Out:
#                                                        Name PClass   Age  \
# rownames
# 8                                    Andrews, Mr Thomas, jr    1st  39.0
# 53        Cassebeer, Mrs Henry Arthur jr (Genevieve Fosd...    1st   NaN
# 82                               de Villiers, Madame Berthe    1st   NaN
# 196                          Ovies y Rodriguez, Mr Servando    1st  28.0
# 202                            Penasco, Mr Victor de Satode    1st  18.0
# 203          Penasco, Mrs Victor de Satode (Josefa de Soto)    1st  17.0
# 215       Rothes, the Countess of (Noel Lucy Martha Dyer...    1st  27.0
# 264                             Thayer, Mr John Borland, jr    1st  17.0
# 265       Thorne, Mr George (alias of: Mr George Rosensh...    1st  46.0
# 267                         Tucker, Mr Gilbert Milligan, jr    1st  31.0
# 388                               de Brito, Mr Jose Joaquim    2nd   NaN
# 389                                del Carlo, Mr Sebastiano    2nd  28.0
# 390            del Carlo, Mrs Sebastiano (Argenia Genovese)    2nd  22.0
# 399                             Duran y More, Miss Asuncion    2nd   NaN
# 400                           Duran y More, Miss Florentina    2nd   NaN
# 405               Faunthorpe, Mrs Lizzie (see Wilkinson, E)    2nd   NaN
# 519           Nourney, Mr Alfred (aka Baron von Drachstedt)    2nd  20.0
# 523                               Padro y Manent, Mr Julian    2nd   NaN
# 525                            Pallas y Castello, Mr Emilio    2nd   NaN
# 1180                                   Sage, Thomas (child)    3rd   NaN
# 1249                      Thomas, Mr John (? 1st/2nd class)    3rd   NaN
# 1270                           Van der Planke, Miss Augusta    3rd  18.0
# 1271                               Van der Planke, Mr Jules    3rd  31.0
# 1272                              Van der Planke, Mrs Jules    3rd  31.0
# 1273                                Van der Planke, Mr Leon    3rd  15.0
# 1274                            Van der Steen, Mr Leo Peter    3rd  28.0
# 1275                           Van de Velde, Mr John Joseph    3rd  36.0
#
#              Sex  Survived  SexCode
# rownames
# 8           male         0        0
# 53        female         1        1
# 82        female         1        1
# 196         male         0        0
# 202         male         0        0
# 203       female         1        1
# 215       female         1        1
# 264         male         1        0
# 265         male         0        0
# 267         male         1        0
# 388         male         0        0
# 389         male         0        0
# 390       female         1        1
# 399       female         1        1
# 400       female         1        1
# 405       female         1        1
# 519         male         1        0
# 523         male         1        0
# 525         male         1        0
# 1180        male         0        0
# 1249        male         0        0
# 1270      female         0        1
# 1271        male         0        0
# 1272      female         0        1
# 1273        male         0        0
# 1274        male         0        0
# 1275        male         0        0

# %% [markdown]
# ___
# **TECHNICAL NOTES**: `REGEX`
# >Method `str.contains` di atas menggunakan **`Python Regular Expression Operation`**, biasa diacu sebagai **`regex`**, untuk memeriksa apakah setiap value mengandung string dengan pola tertentu. `regex` biasanya dipergunakan untuk menemukan padanan dari pola tertentu pada data berupa `string`.
#
# `Regex` sebetulnya bukan hal yang asing, sebagai ilustrasi, kita pasti pernah melakukan proses pembuatan password, dimana biasanya melibatkan **Validasi** untuk memastikan terpenuhinya beberapa syarat tertentu, seperti:
#   - Minimal jumlah karakter adalah 8;
#   - Minimal salah satu karakter tersebut berupa angka;
#   - Minimal salah satu karakter tersebut berupa huruf kapital; dan
#   - Minimal salah satu karakter tersebut berupa *special character*.
#
# Untuk mempelajari lebih lanjut terkait **`regex`** silahkan cermati dokumentasinya pada tautan [**`berikut`**](https://docs.python.org/3/library/re.html).
#
# Beberapa notasi `regex` umum:
# 1. `"\\b"` atau `r"\b"` ==> notasi bagi **Word Boundary**;
# 2. `"[a-z]"` ==> notasi bagi seluruh karakter alfabet lowercase;
# 3. `"[A-Z]`" ==> notasi bagi seluruh karakter alfabet uppercase;
# 4. `"[0-9]"` ==> notasi bagi seluruh karakter numeric;
# 5. `"+"` ==> notasi bagi **kemungkinan** berulangnya pola string sebelumnya;
# 6. `"*"` ==> notasi bagi adanya pengulangan pola string sebelumnya;
# 7. `"^"` ==> notasi bagi pola di awal dari string;
# 8. `"$"` ==> notasi bagi pola di akhir dari string;
# 9. `"|"` ==> notasi bagi alternatif pola;
# 10. `"{x}"` ==> notasi bagi pengulangan karakter sebanyak x kali;
# 11. `"{a, b}"` ==> notasi bagi pengulangan karakter sebanyak antara a hingga b kali;
# 12. `"{b, }"` ==> notasi bagi pengulangan karakter setidaknya sebanyak b kali.
#
# Berdasarkan daftar notasi di atas, maka arti harfiah dari notasi `regex` `pattern_to_find` di contoh kasus di atas adalah:
#
# >"Pola berupa **rangkaian string** (kata) yang terdiri dari **minimal satu** karakter **alfabet** berformat **lowercase**".
#
# Cara Penulisan notasi `regex`:
# ```python
# string_pattern = "\\b[a-z]+\\b"     # Sebuah Pattern regex bertipe string
# raw_string_pattern = r"\b[a-z]+\b"  # Sebuah pattern regex bertipe raw string
# ```
# ___

# %% [markdown]
# **ILUSTRASI: REGEX**
#
# Cermati kedua **regular expression** di bawah berikut:
# ```python
# regex_1 = "\\b[A-Z][a-z]+\\b"
# regex_2 = r"\b0817[0-9]*\b"
# ```
# Lalu coba jawab dua soal di bawah ini.

# %%
# @title 1. Berikan tanda cek pada string yang sesuai dengan pola pada regex_1:
from IPython.display import display
import ipywidgets as widgets

# Function to check answers
def check_answers(correct_answers, options, result_widget):
    # Get the current user answers
    user_answers = tuple(option.value for option in options)

    # Check if user answers match the correct answers
    if user_answers == correct_answers:
        feedback = "Jawaban Anda Benar!"
    else:
        feedback = "Jawaban Anda Salah!"

    result_widget.value = feedback

correct_answers_1 = (False, False, True, True, True)

# Create checkboxes for each option in Question 1
option_a_1 = widgets.Checkbox(value=False, description='a. "AMIR"')
option_b_1 = widgets.Checkbox(value=False, description='b. "amir"')
option_c_1 = widgets.Checkbox(value=False, description='c. "Amir Hamzah"')
option_d_1 = widgets.Checkbox(value=False, description='d. "Amir"')
option_e_1 = widgets.Checkbox(value=False, description='e. "Am"')

options = [option_a_1, option_b_1, option_c_1, option_d_1, option_e_1]

# Output box for feedback
result_1 = widgets.Textarea(value="", placeholder='Feedback', description='', disabled=True)

# Button to check answers for Question 1
check_button_1 = widgets.Button(description="Cek Jawaban")
check_button_1.on_click(lambda event: check_answers(correct_answers_1, options, result_1))

# Display the interactive form for Question 1
display(option_a_1, option_b_1, option_c_1, option_d_1, option_e_1, check_button_1, result_1)
# Out:
# Checkbox(value=False, description='a. "AMIR"')
# Checkbox(value=False, description='b. "amir"')
# Checkbox(value=False, description='c. "Amir Hamzah"')
# Checkbox(value=False, description='d. "Amir"')
# Checkbox(value=False, description='e. "Am"')
# Button(description='Cek Jawaban', style=ButtonStyle())
# Textarea(value='', disabled=True, placeholder='Feedback')

# %%
# @title 2. Berikan tanda cek pada String yang sesuai dengan pola pada regex_2:
correct_answers_2 = (True, False, True, False, True)

# Create checkboxes for each option in Question 1
option_a_2 = widgets.Checkbox(value=False, description="a. '08170'")
option_b_2 = widgets.Checkbox(value=False, description='b. "081902345"')
option_c_2 = widgets.Checkbox(value=False, description='c. "08170000"')
option_d_2 = widgets.Checkbox(value=False, description='d. "0817 8787 8988"')
option_e_2 = widgets.Checkbox(value=False, description='e. "081733"')

options_2 = [option_a_2, option_b_2, option_c_2, option_d_2, option_e_2]

# Output box for feedback
result_2 = widgets.Textarea(value="", placeholder='Feedback', description='', disabled=True)

# Button to check answers for Question 1
check_button_2 = widgets.Button(description="Cek Jawaban")
check_button_2.on_click(lambda event: check_answers(correct_answers_2, options_2, result_2))

# Display the interactive form for Question 1
display(option_a_2, option_b_2, option_c_2, option_d_2, option_e_2, check_button_2, result_2)
# Out:
# Checkbox(value=False, description="a. '08170'")
# Checkbox(value=False, description='b. "081902345"')
# Checkbox(value=False, description='c. "08170000"')
# Checkbox(value=False, description='d. "0817 8787 8988"')
# Checkbox(value=False, description='e. "081733"')
# Button(description='Cek Jawaban', style=ButtonStyle())
# Textarea(value='', disabled=True, placeholder='Feedback')

# %%
import re

nama = "KA01-KB02"

re.findall("KA[0-9A-Za-z]+", nama)
# Out:
# ['KA01']

# %% [markdown]
# ___
# 3. Setiap value pada `Name` terdiri dari `Surname`, `Title`, dan `Firstname`
#
# Di bawah berikut dicontohkan cara untuk mengumpulkan informasi terkait berbagai Title yang terdapat pada dataset, dengan menggunakan sebuah user-defined function yang terdapat pada modul functions. Untuk memanfaatkan modul tersebut, silahkan unduh pada link [berikut](https://drive.google.com/file/d/1dXMuGyplSRowrLZ-_tvowhavE7rJ3Xw_/view?usp=drive_link), lalu unggah file tersebut ke environment.

# %%
# import fungsi create_title_pattern ke environment
from functions import create_title_pattern

# %%
# Cek dokumentasi fungsi tersebut
help(create_title_pattern)
# Out:
# Help on function create_title_pattern in module functions:
#
# create_title_pattern(df: object, nama_kolom: str) -> str
#     FUNGSI UNTUK MEMBUAT LIST BERISI ALTERNATIF PATTERN DARI STR VALUE PADA SEBUAH KOLOM
#     ARGUMENTS:
#       1. df : object, dataframe yang akan dibuatkan pattern;
#       2. nama_kolom : str, nama kolom yang valuenya berisi pattern.
#     OUTPUT:
#       Sebuah str berisi pattern pencarian string.

# %%
# Buat title_pattern untuk dipakai mengekstrak Title dari kolom Name
title_pattern = create_title_pattern(df_titanic, 'Name')
# Out:
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#                                              Pattern Masih Kosong
# --------------------------------------------------------------------------------------------------------------
#                                         Values pada kolom Name = 1313                                         :
# ['Allen, Miss Elisabeth Walton', 'Allison, Miss Helen Loraine', 'Allison, Mr Hudson Joshua Creighton', 'Allison, Mrs Hudson JC (Bessie Waldo Daniels)', 'Allison, Master Hudson Trevor']
# ['Anderson, Mr Harry', 'Andrews, Miss Kornelia Theodosia', 'Andrews, Mr Thomas, jr', 'Appleton, Mrs Edward Dale (Charlotte Lamson)', 'Artagaveytia, Mr Ramon']
# ['Astor, Colonel John Jacob', 'Astor, Mrs John Jacob (Madeleine Talmadge Force)', 'Aubert, Mrs Leontine Pauline', 'Barkworth, Mr Algernon H', 'Baumann, Mr John D']
# ['Baxter, Mrs James (Helene DeLaudeniere Chaput)', 'Baxter, Mr Quigg Edmond', 'Beattie, Mr Thomson', 'Beckwith, Mr Richard Leonard', 'Beckwith, Mrs Richard Leonard (Sallie Monypeny)']
# ['Behr, Mr Karl Howell', 'Birnbaum, Mr Jakob', 'Bishop, Mr Dickinson H', 'Bishop, Mrs Dickinson H (Helen Walton)', 'Bjornstrm-Steffansson, Mr Mauritz Hakan']
# ['Blackwell, Mr Stephen Weart', 'Blank, Mr Henry', 'Bonnell, Miss Caroline', 'Bonnell, Miss Elizabeth', 'Borebank, Mr John James']
# ['Bowen, Miss Grace Scott', 'Bowerman, Miss Elsie Edith', 'Bradley, Mr George', 'Brady, Mr John Bertram', 'Brandeis, Mr Emil']
# ['Brewe, Dr Arthur Jackson', 'Brown, Mrs James Joseph (Margaret Molly" Tobin)"', 'Brown, Mrs John Murray (Caroline Lane Lamson)', 'Bucknell, Mrs William Robert (Emma Eliza Ward)', 'Butt, Major Archibald Willingham']
# ['Calderhead, Mr Edward P', 'Candee, Mrs Edward (Helen Churchill Hungerford)', 'Cardeza, Mrs James Warburton Martinez (Charlotte Wardle Drake)', 'Cardeza, Mr Thomas Drake Martinez', 'Carlsson, Mr Frans Olof']
# ['Carrau, Mr Francisco M', 'Carrau, Mr Jose Pedro', 'Carter, Mr William Ernest', 'Carter, Mrs William Ernest (Lucile Polk)', 'Carter, Miss Lucile Polk']
# ['Carter, Master William T II', 'Case, Mr Howard Brown', 'Cassebeer, Mrs Henry Arthur jr (Genevieve Fosdick)', 'Cavendish, Mr Tyrell William', 'Cavendish, Mrs Tyrell William Julia Florence Siegel']
# ['Chaffee, Mr Herbert Fuller', 'Chaffee, Mrs Herbert Fuller (Carrie Constance Toogood)', 'Chambers, Mr Norman Campbell', 'Chambers, Mrs Norman Campbell (Bertha Griggs)', 'Cherry, Miss Gladys']
# ['Chevre, Mr Paul', 'Chibnall (Bowerman), Mrs Edith Martha', 'Chisholm, Mr Roderick Robert', 'Clark, Mr Walter Miller', 'Clark, Mrs Walter Miller (Virginia McDowell)']
# ['Clifford, Mr George Quincy', 'Colley, Mr Edward Pomeroy', 'Compton, Mrs Alexander Taylor (Mary Eliza Ingersoll)', 'Compton, Mr Alexander Taylor, Jr', 'Compton, Miss Sara Rebecca']
# ['Cornell, Mrs Robert Clifford (Malvina Helen Lamson)', 'Crafton, Mr John Bertram', 'Crosby, Captain Edward Gifford', 'Crosby, Mrs Edward Gifford (Catherine Elizabeth Halstead)', 'Crosby, Miss Harriet R']
# ['Cumings, Mr John Bradley', 'Cumings, Mrs John Bradley (Florence Briggs Thayer)', 'Daly, Mr Peter Denis ', 'Daniel, Mr Robert Williams', 'Davidson, Mr Thornton']
# ['Davidson, Mrs Thornton (Orian Hays)', 'de Villiers, Madame Berthe', 'Dick, Mr Albert Adrian', 'Dick, Mrs Albert Adrian Vera Gillespie', 'Dodge, Dr Washington']
# ['Dodge, Mrs Washington (Ruth Vidaver)', 'Dodge, Master Washington', 'Douglas, Mrs Frederick Charles (Suzette Baxter)', 'Douglas, Mr Walter Donald', 'Douglas, Mrs Walter Donald (Mahala Dutton)']
# ['Duff Gordon, Sir Cosmo Edmund', 'Duff Gordon, Lady (Lucille Wallace Sutherland)', 'Dulles, Mr William Crothers', 'Earnshaw, Mrs Boulton (Olive Potter)', 'Eustis, Miss Elizabeth Mussey']
# ['Evans, Miss Edith Corse', 'Flegenheim, Mrs Alfred (Antoinette)', 'Flynn, Mr John Irving', 'Foreman, Mr Benjamin Laventall', 'Fortune, Miss Alice Elizabeth']
# ['Fortune, Mr Charles Alexander', 'Fortune, Miss Ethel Flora', 'Fortune, Miss Mabel', 'Fortune, Mr Mark', 'Fortune, Mrs Mark (Mary McDougald)']
# ['Franklin, Mr Thomas Parham', 'Frauenthal, Dr Henry William', 'Frauenthal, Mrs Henry William (Clara Heinsheimer)', 'Frauenthal, Mr Isaac Gerald', 'Frolicher, Miss Marguerite']
# ['Frolicher-Stehli, Mr Maxmillian', 'Frolicher-Stehli, Mrs Maxmillian (Margaretha Emerentia Stehli)', 'Futrelle, Mr Jacques', 'Futrelle, Mrs Jacques (May Peel)', 'Gee, Mr Arthur H']
# ['Gibson, Miss Dorothy', 'Gibson, Mrs Leonard (Pauline C Boeson)', 'Goldenberg, Mr Samuel L', 'Goldenberg, Mrs Samuel L (Edwiga Grabowsko)', 'Goldschmidt, Mr George B']
# ['Gracie, Colonel Archibald IV', 'Graham, Mr George Edward', 'Graham, Miss Margaret Edith', 'Graham, Mrs William Thompson (Edith Junkins)', 'Greenfield, Mrs Leo David (Blanche Strouse)']
# ['Greenfield, Mr William Bertram', 'Guggenheim, Mr Benjamin', 'Harder, Mr George Achilles', 'Harder, Mrs George Achilles (Dorothy Annan)', 'Harper, Mr Henry Sleeper']
# ['Harper, Mrs Henry Sleeper (Myna Haxtun)', 'Harris, Mr Henry Birkhardt', 'Harris, Mrs Henry Birkhardt (Irene Wallach)', 'Hawksford, Mr Walter James', 'Hays, Mr Charles Melville']
# ['Hays, Mrs Charles Melville (Clara Jennings Gregg)', 'Hays, Miss Margaret Bechstein', 'Head, Mr Christopher', 'Hilliard, Mr Herbert Henry', 'Hipkins, Mr William Edward']
# ['Hippach, Miss Jean Gertrude', 'Hippach, Mrs Louis Albert (Ida Sophia Fischer)', 'Hogeboom, Mrs John C (Anna Andrews)', 'Holverson, Mr Alexander Oskar', 'Holverson, Mrs Alexander Oskar (Mary Aline Towner)']
# ['Homer, Mr Harry', 'Hoyt, Mr Frederick Maxfield', 'Hoyt, Mrs Frederick Maxfield (Jane Anne Forby)', 'Hoyt, Mr William F', 'Isham, Miss Anne Elizabeth']
# ['Ismay, Mr Joseph Bruce', 'Jones, Mr Charles Cresson', 'Julian, Mr Henry Forbes', 'Kent, Mr Edward Austin', 'Kenyon, Mr Frederick R']
# ['Kenyon, Mrs Frederick R (Marion)', 'Kimball, Mr Edwin Nelson Jr', 'Kimball, Mrs Edwin Nelson Jr (Gertrude Parsons)', 'Klaber, Mr Herman', 'Leader, Dr Alice Farnham']
# ['Lewy, Mr Ervin G', 'Lindeberg-Lind, Mr Erik Gustaf', 'Lindstrom, Mrs Carl Johan (Sigrid Posse)', 'Lines, Mrs Ernest H (Elizabeth Lindsey James)', 'Lines, Miss Mary Conover']
# ['Lingrey, Mr Edward', 'Long, Mr Milton Clyde', 'Longley, Miss Gretchen Fiske', 'Loring, Mr Joseph Holland', 'Madill, Miss Georgette Alexandra']
# ['Maguire, Mr John Edward', 'Marechal, Mr Pierre', 'Marvin, Mr Daniel Warner', 'Marvin, Mrs Daniel Warner (Mary Graham Carmichael Farquarson)', 'McCaffry, Mr Thomas Francis']
# ['McCarthy, Mr Timothy J', 'McGough, Mr James R', 'Meyer, Mr Edgar Joseph', 'Meyer, Mrs Edgar Joseph (Leila Saks)', 'Millet, Mr Francis Davis']
# ['Minahan, Miss Daisy E', 'Minahan, Dr William Edward', 'Minahan, Mrs William Edward (Lillian E Thorpe)', 'Mock, Mr Philip E', 'Molson, Mr Harry Markland']
# ['Moore, Mr Clarence Bloomfield', 'Natsch, Mr Charles H', 'Newell, Mr Arthur Webster', 'Newell, Miss Madeleine', 'Newell, Miss Marjorie']
# ['Newsom, Miss Helen Monypeny', 'Nicholson, Mr Arthur Ernest', 'Omont, Mr A Fernand', 'Ostby, Mr Engelhart Cornelius', 'Ostby, Miss Helen Raghnild']
# ['Ovies y Rodriguez, Mr Servando', 'Parr, Mr William Henry Marsh', 'Partner, Mr Austin', 'Payne, Mr Vivian Ponsonby', 'Pears, Mr Thomas']
# ['Pears, Mrs Thomas (Edith)', 'Penasco, Mr Victor de Satode', 'Penasco, Mrs Victor de Satode (Josefa de Soto)', 'Peuchen, Major Arthur Godfrey', 'Porter, Mr Walter Chamberlain']
# ['Potter, Mrs Thomas, Jr (Lily Alexenia Wilson)', 'Reuchlin, Jonkheer John George', 'Rheims, Mr George Lucien', 'Robert, Mrs Edward Scott (Elisabeth Walton McMillan)', 'Roebling, Mr Washington Augustus 2nd']
# ['Romaine, Mr Charles Hallace', 'Rood, Mr Hugh R', 'Rosenbaum (Russell), Miss Edith Louise', 'Ross, Mr John Hugo', 'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)']
# ['Rothschild, Mr Martin', 'Rothschild, Mrs Martin (Elizabeth L Barrett)', 'Rowe, Mr Alfred G', 'Ryerson, Mr Arthur Larned', 'Ryerson, Mrs Arthur Larned (Emily Maria Borie)']
# ['Ryerson, Miss Emily Borie', 'Ryerson, Master John Borie', 'Ryerson, Miss Susan (Suzette) Parker', 'Saalfeld, Mr Adolphe', 'Salomon, Mr Abraham L']
# ['Schabert, Mrs Paul (Emma Mock)', 'Seward, Mr Frederic Kimber', 'Shutes, Miss Elizabeth W', 'Silverthorne, Mr Spencer Victor', 'Silvey, Mr William Baird']
# ['Silvey, Mrs William Baird (Alice Munger)', 'Simonius-Blumer, Col Alfons', 'Sloper, Mr William Thompson', 'Smart, Mr John Montgomery', 'Smith, Mr James Clinch']
# ['Smith, Mr Lucien Philip', 'Smith, Mrs Lucien Philip (Mary Eloise Hughes', 'Smith, Mr Richard William', 'Snyder, Mr John Pillsbury', 'Snyder, Mrs John Pillsbury (Nelle Stevenson)']
# ['Spedden, Mr Frederick Oakley', 'Spedden, Mrs Frederick Oakley (Margaretta Corning Stone)', 'Spedden, Master Robert Douglas', 'Spencer, Mr William Augustus', 'Spencer, Mrs William Augustus (Marie Eugenie)']
# ['Staehlin, Dr Max', 'Stead, Mr William Thomas', 'Stengel, Mr Charles Emil Henry', 'Stengel, Mrs Charles Emil Henry (Annie May Morris)', 'Stephenson, Mrs Walter Bertram (Martha Eustis)']
# ['Stewart, Mr Albert A', 'Stone, Mrs George Nelson (Martha E)', 'Straus, Mr Isidor', 'Straus, Mrs Isidor (Ida Blun)', 'Sutton, Mr Frederick']
# ['Swift, Mrs Frederick Joel (Margaret Welles Barron)', 'Taussig, Mr Emil', 'Taussig, Mrs Emil (Tillie Mandelbaum)', 'Taussig, Miss Ruth', 'Taylor, Mr Elmer Zebley']
# ['Taylor, Mrs Elmer Zebley (Juliet Cummins Wright)', 'Thayer, Mr John Borland', 'Thayer, Mrs John Borland (Marian Longstreth Morris)', 'Thayer, Mr John Borland, jr', 'Thorne, Mr George (alias of: Mr George Rosenshine)']
# ['Thorne, Mrs Gertrude Maybelle', 'Tucker, Mr Gilbert Milligan, jr', 'Uruchurtu, Mr Manuel E', 'Van Derhoef, Mr Wyckoff', 'Walker, Mr William Anderson']
# ['Warren, Mr Frank Manley', 'Warren, Mrs Frank Manley (Anna S Atkinson)', 'Weir, Col John', 'White, Mrs J Stuart (Ella Holmes)', 'White, Mr Percival Wayland']
# ['White, Mr Richard Frasar', 'Wick, Mr George Dennick', 'Wick, Mrs George Dennick (Martha Hitchcock)', 'Wick, Miss Mary Natalie', 'Widener, Mr George Dunton']
# ['Widener, Mrs George Dunton (Eleanor Elkins)', 'Widener, Mr Harry Elkins', 'Willard, Miss Constance', 'Williams, Mr Charles Duane', 'Williams, Mr Fletcher Lambert']
# ['Williams, Mr Richard Norris II', 'Woolner, Mr Hugh', 'Wright, Mr George', 'Young, Miss Marie Grice', 'Barber, Ms ']
# ['Bazzani, Ms Albina', 'Bidois, Miss Rosalie', 'Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret']
# ['Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice', 'Daniels, Ms Sarah', 'Endres, Miss Caroline Louise', 'Farthing, Mr John']
# ['Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel', 'Fry, Mr Richard', 'Geiger, Miss Emily ', 'Giglio, Mr Victor']
# ['Harrington, Mr Charles', 'Harrison, Mr William   Henry', 'Hassah, Mr Hamad', 'Icabad (Icabod), Ms', 'Keeping, Mr Edwin']
# ['Kenchen, Ms Amelia', 'LeRoy, Miss Berthe', 'Lesneur, Mr Gustave', 'Maloney, Ms', 'Oliva, Mlle']
# ['Pericault, Ms', 'Ringhini, Mr Sante', 'Robbins, Mr Victor', 'Segesser, Mlle Emma', 'Seredeca, Ms']
# ['Ward, Ms Anna', 'Wilson, Ms Helen', 'Abelson, Mr Samuel', 'Abelson, Mrs Samuel (Anna)', 'Andrew, Mr Edgar Samuel']
# ['Andrew, Mr Frank', 'Angle, Mr William A', 'Angle, Mrs William A (Florence)', 'Ashby, Mr John', 'Bailey, Mr Percy Andrew']
# ['Baimbrigge, Mr Charles R', 'Balls, Mrs Ada E Hall', 'Banfield, Mr Frederick J', 'Bateman, Rev Robert James', 'Beane, Mr Edward']
# ['Beane, Mrs Edward (Ethel Clarke)', 'Beauchamp, Mr Henry James', 'Becker, Mrs Allen Oliver (Nellie E Baumgardner)', 'Becker, Miss Marion Louise', 'Becker, Master Richard F']
# ['Becker, Miss Ruth Elizabeth', 'Beesley, Mr Lawrence', 'Bentham, Miss Lilian W', 'Berriman, Mr William S', 'Botsford, Mr William Hull']
# ['Bowenur, Mr Solomon', 'Bracken, Mr James H', 'Brown, Miss Edith E', 'Brown, Mr Thomas William Solomon', 'Brown, Mrs Thomas William Solomon (Elizabeth C)']
# ['Bryhl, Miss Dagmar', 'Bryhl, Mr Kurt Arnold Gottfrid', 'Buss, Miss Kate', 'Butler, Mr Reginald Fenton', 'Byles, Rev Thomas Roussel D']
# ['Bystrom, Mrs Carolina', 'Caldwell, Mr Albert Francis', 'Caldwell, Mrs Albert Francis (Sylvia Mae Harbaugh)', 'Caldwell, Master Alden Gates', 'Cameron, Miss Clear']
# ['Campbell, Mr William', 'Carbines, Mr William', 'Carter, Rev Ernest Courtenay', 'Carter, Mrs Ernest Courtenay (Lillian Hughes)', 'Chapman, Mr Charles Henry']
# ['Chapman, Mr John Henry', 'Chapman, Mrs John Henry (Elizabeth Lawry)', 'Christy, Mrs Alice Frances', 'Christy, Miss Julie', 'Clarke, Mr Charles V']
# ['Clarke, Mrs Charles V (Ada Maria)', 'Coleridge, Mr Reginald Charles', 'Collander, Mr Erik', 'Collett, Mr Sidney C Stuart', 'Collyer, Mr Harvey']
# ['Collyer, Mrs Harvey (Charlotte Tate)', 'Collyer, Miss Marjorie', 'Cook, Mrs Selena Rogers', 'Corbett, Mrs Walter H (Irene Colvin)', 'Corey, Mrs Percy C (Mary Phyllis Elizabeth Miller)']
# ['Cotterill, Mr Harry', 'Cunningham, Mr Alfred Fleming', 'Davies, Mr Charles Henry', 'Davis, Mrs Agnes', 'Davis, Master John Morgan']
# ['Davis, Miss Mary', 'Deacon, Mr Percy', 'de Brito, Mr Jose Joaquim', 'del Carlo, Mr Sebastiano', 'del Carlo, Mrs Sebastiano (Argenia Genovese)']
# ['Denbury, Mr Herbert', 'Dibden, Mr William', 'Doling, Mrs Ada', 'Doling, Miss Elsie', 'Downton (?Douton), Mr William James']
# ['Drew, Mr James Vivian', 'Drew, Mrs James Vivian (Lulu Thorne Christian)', 'Drew, Master Marshall Brines', 'Duran y More, Miss Asuncion', 'Duran y More, Miss Florentina']
# ['Eitemiller, Mr George Floyd', 'Enander, Mr Ingvar', 'Fahlstrom, Mr Arne Jonas', 'Faunthorpe, Mr Harry', 'Faunthorpe, Mrs Lizzie (see Wilkinson, E)']
# ['Fillbrook, Mr Charles', 'Fox, Mr Stanley H', 'Frost, Mr Anthony (Archie) W', 'Funk, Miss Annie C', 'Fynney, Mr Joseph J']
# ['Gale, Mr Harry', 'Gale, Mr Shadrach', 'Garside, Miss Ethel', 'Gaskell, Mr Alfred', 'Gavey, Mr Lawrence']
# ['Gilbert, Mr William', 'Giles, Mr Edgar', 'Giles, Mr Frederick', 'Giles, Mr Ralph', 'Gill, Mr John W']
# ['Gillespie, Mr William', 'Givard, Mr Hans Christensen', 'Greenberg, Mr Samuel', 'Hale, Mr Reginald', 'Hamalainen, Mrs William (Anna)']
# ['Hamalainen, Master Viljo', 'Harbeck, Mr William H', 'Harper, Rev John', 'Harper, Miss Nina', 'Harris, Mr George']
# ['Harris, Mr Walter', 'Hart, Mr Benjamin', 'Hart, Mrs Benjamin (Esther)', 'Hart, Miss Eva Miriam', 'Herman, Miss Alice']
# ['Herman, Miss Kate', 'Herman, Mr Samuel', 'Herman, Mrs Samuel (Jane Laver)', 'Hewlett, Mrs Mary D', 'Hickman, Mr Leonard Mark']
# ['Hickman, Mr Lewis', 'Hickman, Mr Stanley George', 'Hiltunen, Miss Marta', 'Hocking, Mrs Elizabeth', 'Hocking, Mr George']
# ['Hocking, Miss Ellen (Nellie)', 'Hocking, Mr Samuel James', 'Hodges, Mr Henry Price', 'Hold, Mr Stephen', 'Hold, Mrs Stephen (Annie Margaret)']
# ['Hood, Mr Ambrose, Jr', 'Hosono, Mr Masafumi', 'Howard, Mr Benjamin', 'Howard, Mrs Benjamin (Ellen Truelove)', 'Hunt, Mr George Henry']
# ['Ilett, Miss Bertha', 'Jacobsohn Mr Samuel', 'Jacobsohn, Mrs Sidney Samuel (Amy Frances Christy)', 'Jarvis, Mr John Denzil', 'Jefferys, Mr Clifford']
# ['Jefferys, Mr Ernest', 'Jenkin, Mr Stephen Curnow', 'Jerwan, Mrs Amin S (Marie Thuillard)', 'Kantor, Mr Sinai', 'Kantor, Mrs Sinai (Miriam Sternim)']
# ['Karnes, Mrs J Frank (Claire Bennett)', 'Keane, Mr Daniel', 'Keane, Miss Nora A', 'Kelly, Mrs Florence (Fannie)', 'Kirkland, Rev Charles Leonard']
# ['Knight, Mr Robert', 'Kvillner, Mr Johan Henrik Johannesson', 'Lahtinen, Rev William', 'Lahtinen, Mrs William (Anna Sylvan)', 'Lamb, Mr John James']
# ['Lemore, Mrs Amelia', 'LaRoche, Mr Joseph', 'LaRoche, Mrs Joseph (Juliet)', 'LaRoche, Miss Louise', 'LaRoche, Miss Simonne']
# ['Lehmann, Miss Bertha', 'Leitch, Miss Jessie', 'Levy, Mr Rene Jacques', 'Leyson, Mr Robert William Norman', 'Lingan, Mr John']
# ['Louch, Mr Charles Alexander', 'Louch, Mrs Charles Alexander (Alice Adelaide)', 'Mack, Mrs Mary', 'Malachard, Mr Noel', 'Mallet, Mr Albert']
# ['Mallet, Mrs Albert (Antoinette)', 'Mallet, Master Andre', 'Mangiavacchi, Mr Serafino Emilio', 'Mantvila, Rev Joseph', 'Marshall, Mrs Kate Louise Phillips']
# ['Matthews, Mr William John', 'Maybery, Mr Frank H', 'McCrae, Mr Arthur Gordon', 'McCrie, Mr James Matthew', 'McKane, Mr Peter D']
# ['Mellenger, Mrs Elizabeth Anne', 'Mellenger, Miss Madeleine Violet', 'Mellor, Mr William John', 'Meyer, Mr August', 'Milling, Mr Jacob Christian']
# ['Mitchell, Mr Henry Michael', 'Moraweck, Dr Ernest', 'Morley, Mr William', 'Mudd, Mr Thomas C', 'Myles, Mr Thomas Francis']
# ['Nasser (Nasrallah), Mr Nicholas', 'Nasser (Nasrallah), Mrs Nicholas', 'Navratil, Master Edmond Roger', 'Navratil, Mr Michel', 'Navratil, Master Michel M']
# ['Nesson, Mr Israel', 'Nicholls, Mr Joseph Charles', 'Norman, Mr Robert Douglas', 'Nourney, Mr Alfred (aka Baron von Drachstedt)', 'Nye, Mrs Elizabeth Ramell']
# ['Otter, Mr Richard', 'Oxenham, Mr Percy Thomas', 'Padro y Manent, Mr Julian', 'Pain, Dr Alfred', 'Pallas y Castello, Mr Emilio']
# ['Parker, Mr Clifford R', 'Parkes, Mr Francis (Frank)', 'Parrish, Mrs Lutie Davis', 'Pengelly, Mr Frederick', 'Peruschitz, Rev Joseph M']
# ['Phillips, Miss Alice', 'Phillips, Mr Robert', 'Pinsky, Miss Rosa', 'Ponesell, Mr Martin', 'Portaluppi, Mr Emilio']
# ['Pulbaum, Mr Frank', 'Quick, Mrs Frederick C (Jane Richards)', 'Quick, Miss Phyllis May', 'Quick, Miss Winifred Vera', 'Reeves, Mr David']
# ['Renouf, Mr Peter Henry', 'Renouf, Mrs Peter Henry (Lillian Jefferys)', 'Reynaldo, Mrs Encarnacion', 'Richard, Mr Emil', 'Richards, Master George Sidney']
# ['Richards, Mrs Sidney (Emily Hocking)', 'Richards, Master William Rowe', 'Ridsdale, Miss Lucy', 'Rogers, Mr Harry', 'Rugg, Miss Emily']
# ['Sedgwick, Mr Charles Frederick Waddington', 'Sharp, Mr Percival', 'Shelley, Mrs William (Imanita)', 'Silven, Miss Lyyli', 'Sincock, Miss Maude']
# ['Siukonnen, Miss Anna', 'Sjostedt, Mr Ernst Adolf', 'Slayter, Miss Hilda Mary', 'Slemen, Mr Richard James', 'Smith (Schmidt), Mr Augustus']
# ['Smith, Miss Marion', 'Sobey, Mr Hayden', 'Stanton, Mr Samuel Ward', 'Stokes, Mr Philip Joseph', 'Sweet, Mr George']
# ['Toomey, Miss Ellen', 'Troupiansky, Mr Moses Aaron', 'Trout, Mrs William H (Jessie L)', 'Troutt, Miss Edwina Celia', 'Turpin, Mr William John']
# ['Turpin, Mrs William John (Dorothy Anne Wonnacott)', 'Veale, Mr James', 'Waelens, Mr Achille', 'Walcroft, Miss Nellie', 'Ware, Mr John James']
# ['Ware, Mrs John James (Florence Louise Long)', 'Ware, Mr William J', 'Watson, Mr Ennis Hastings', 'Watt, Miss Bertha', 'Watt, Mrs James (Bessie Inglis Milne)']
# ['Webber, Miss Susan', 'Weisz, Mr Leopold', 'Weisz, Mrs Leopold (Mathilde)', 'Wells, Mrs Arthur H (Addie Trevaskis)', 'Wells, Miss Joan']
# ['Wells, Master Ralph Lester', 'West, Miss Barbara J', 'West, Miss Constance Mirium', 'West, Mr Edwy Arthur', 'West, Mrs Edwy Arthur (Ada Mary)']
# ['Wheadon, Mr Edward', 'Wheeler, Mr Edwin', 'Wheeler, Mr Frederick', 'Wilhelms, Mr Charles', 'Wilkinson, Mrs Elizabeth Anne']
# ['Williams, Mr Charles Eugene', 'Wright, Miss Marion', 'Yrois, Miss Henriette', 'Aldworth, Mr Charles Augustus', 'Brown, Miss Mildred']
# ['Pernot, Mr Rene', 'Swane, Mr George', 'Abbing, Mr Anthony', 'Abbott, Master Eugene Joseph', 'Abbott, Mr Rossmore Edward']
# ['Abbott, Mrs Stanton (Rosa)', 'Abelseth, Miss Anna Karen', 'Abelseth, Mr Olaus', 'Abraham, Mrs Joseph (Sophie Easu)', 'Abrahamsson, Mr August']
# ['Adahl, Mr Mauritz Nils Martin', 'Adams, Mr John', 'Ahlin, Mrs Johanna Persdotter', 'Ahmed, Mr Ali', 'Aijo-Nirva, Mr Isak']
# ['Aks, Mrs Sam (Leah Rosen)', 'Aks, Master Philip', 'Alexander, Mr William', 'Alhomaki, Mr Ilmari Rudolf', 'Ali, Mr William']
# ['Allen, Mr William Henry', 'Allum, Mr Owen George', 'Andersen, Mr Albert Karvin', 'Andersen, Mr Thor Olsvigen', 'Andersson, Mr Anders Johan']
# ['Andersson, Mrs Anders Johan (Alfrida K Brogren)', 'Andersson, Miss Ebba Iris', 'Andersson, Miss Ellis Anna Maria', 'Andersson, Miss Erna', 'Andersson, Miss Ida Augusta Margareta']
# ['Andersson, Miss Ingeborg Constancia', 'Andersson, Mr Johan Samuel', 'Andersson, Miss Sigrid Elizabeth', 'Andersson, Master Sigvard Harald Elias', 'Andreasson, Mr Paul Edvin']
# ['Angheloff, Mr Minko', 'Arnold, Mr Josef', 'Arnold, Mrs Josef (Josephine Frank)', 'Aronsson, Mr Ernst Axel Algot', 'Asim, Mr Adola']
# ['Asplund, Mr Carl Oscar Vilhelm Gustafsson', 'Asplund, Mrs Carl Oscar (Selma Augusta Johansson)', 'Asplund, Master Carl Edgar', 'Asplund, Master Clarence Gustaf Hugo', 'Aspland, Master Edvin Rojj Felix']
# ['Asplund, Master Filip Oscar', 'Asplund, Mr John Charles', 'Asplund, Miss Lillian Gertrud', 'Assaf, Mr Gerios', 'Assaf, Mrs Mariana']
# ['Assam, Mr Ali', 'Attalah, Miss Malaka', 'Attala (Kalil), Mr Solomon', 'Augustsson, Mr Albert', 'Baccos, Mr Rafoul']
# ['Backstrom, Mr Karl Alfred', 'Backstrom, Mrs Karl Alfred (Maria Mathilda Gustafsson)', 'Baclini, Miss Eugenie', 'Baclini, Miss Helene', 'Baclini, Miss Maria']
# ['Baclini, Mrs Solomon (Latifa)', 'Badman, Miss Emily Louisa', 'Badt, Mr Mohamed', 'Balkic, Mr Cerin', 'Banoura, Miss Ayout']
# ['Barbara, Mrs Catherine', 'Barbara, Miss Saude', 'Barry, Miss Julia', 'Barton, Mr David', 'Beavan, Mr William Thomas']
# ['Bengtsson, Mr John Viktor', 'Berglund, Mr Karl Ivar Sven', 'Betros, Mr Tannous', 'Bing, Mr Lee', 'Birkeland, Mr Hans']
# ['Bjorklund, Ernst Herbert', 'Bostandyeff, Mr Guentcho', 'Boulos, Master Akar', 'Boulos, Mr Hanna', 'Boulos, Mrs Joseph (Sultana)']
# ['Boulos, Miss Laura', 'Bourke, Mr John', 'Bourke, Mrs John (Catherine)', 'Bourke, Miss Mary', 'Bowen, Mr David']
# ['Bradley, Miss Bridget Delia', 'Braf, Miss Elin Ester Maria', 'Brahim, Mr Youssef', 'Braund, Mr Lewis Richard', 'Braund, Mr Owen Harris']
# ['Brobek, Mr Karl Rudolf', 'Brocklebank, Mr William Alfred', 'Buckley, Mr Daniel', 'Buckley, Miss Katherine', 'Burke, Mr Jeremiah']
# ['Burns, Miss Mary Delia', 'Cacic, Mr Grego', 'Cacic, Mr Luka', 'Cacic, Mr Manda', 'Cacic, Mr Maria']
# ['Calic, Mr Peter', 'Canavan, Miss Mary', 'Canavan, Mr Patrick', 'Cann, Mr Ernest', 'Caram (Kareem), Mr Joseph']
# ['Caram (Kareem), Mrs Joseph (Maria Elias)', 'Carlsson, Mr Carl Robert', 'Carlsson, Mr Frans Olof', 'Carlsson, Mr Julius', 'Carlsson, Mr August Sigfrid']
# ['Carr, Miss Helen', 'Carr, Miss Jeannie', 'Carver, Mr Alfred John', 'Cassem, Mr Nassef Belmenly', 'Celotti, Mr Francesco']
# ['Chartens, Mr David', 'Chebab, Mr Emir Farres', 'Chip, Mr Chang', 'Christmann, Mr Emil', 'Chronopoulos, Mr Apostolos']
# ['Chronopoulos, Mr Demetrios', 'Coelho, Mr Domingos Fernandes', 'Cohen, Mr Gurshon (Gus)', 'Colbert, Mr Patrick', 'Coleff, Mr Fotio']
# ['Coleff, Mr Peyo', 'Conlin, Mr Thomas Henry', 'Connaghton, Mr Michael', 'Connolly, Miss Kate', 'Connolly, Miss Kate']
# ['Connors, Mr Patrick', 'Cook, Mr Jacob', 'Cor, Mr Bartol', 'Cor, Mr Ivan', 'Cor, Mr Ludovik']
# ['Corn, Mr Harry', 'Coutts, Mrs William (Minnie)', 'Coutts, Master Neville', 'Coutts, Master William Leslie', 'Coxon, Mr Daniel']
# ['Crease, Mr Ernest James', 'Cribb, Mr John Hatfield', 'Cribb, Miss Laura Alice', 'Daher, Mr Tannous', 'Dahl, Mr Charles Edward']
# ['Dahlberg, Miss Gerda Ulrika', 'Dakic, Mr Branko', 'Daly, Mr Eugene', 'Daly, Miss Marcella', 'Danbom, Mr Ernst Gilbert']
# ['Danbom, Mrs Ernst Gilbert (Anna Sigrid Maria Brogren)', 'Danbom, Master Gilbert Sigvard Emanuel', 'Danoff, Mr Yoto', 'Dantchoff, Mr Khristo', 'Davies, Mr Alfred']
# ['Davies, Mr Evan', 'Davies, Mr John', 'Davies, Mr Joseph', 'Davison, Mr Thomas Henry', 'Davison, Mrs Thomas Henry (Mary Finck)']
# ['Dean, Mr Bertram', 'Dean, Mrs Bertram (Eva)', 'Dean, Master Bertram Vere', 'Dean, Miss Elizabeth Gladys (Millvena)', 'Delalic, Mr Regyo']
# ['De Messemaeker, Mr William Joseph', 'De Messemaeker, Mrs William Joseph (Anna)', 'De Mulder, Mr Theo', 'Denkoff, Mr Mito', 'Dennis, Mr Samuel']
# ['Dennis, Mr William', 'Devaney, Miss Margaret', 'Dewan, Mr Frank', 'Dibo, Mr Elias', 'Dimic, Mr Jovan']
# ['Dintcheff, Mr Valtcho', 'Dooley, Mr Patrick', 'Dorkings, Mr Edward Arthur', 'Dowdell, Miss Elizabeth', 'Doyle, Miss Elizabeth']
# ['Drapkin, Miss Jennie', 'Drazonovic, Mr Josef', 'Driscoll, Miss Bridget', 'Duquemin, Mr Joseph', 'Dyker, Mr Adolf Fredrik']
# ['Dyker, Mrs Adolf Fredrik (Anna Elizabeth Judith Andersson)', 'Econovic, Mr Joso', 'Edvardsson, Mr Gustaf Hjalmar', 'Eklund, Mr Hans Linus', 'Ekstrom, Mr Johan']
# ['Elias, Mr Elias', 'Elias, Mr John', 'Elias, Mr Joseph', 'Elsbury, Mr James', 'Emanuel, Miss Virginia Ethel']
# ['Emmeth, Mr Thomas', 'Everett, Thomas James', 'Farrell, Mr James', 'Finoli, Mr Luigi', 'Fischer, Mr Eberhard Telander']
# ['Flynn, Mr James', 'Flynn, Mr John', 'Foley, Mr Joseph', 'Foley, Mr William', 'Foo, Mr Choong']
# ['Ford, Mr Arthur', 'Ford, Miss Doolina Margaret', 'Ford, Mr Edward Watson', 'Ford, Miss Maggie', 'Ford, Mrs Edward (Margaret Ann)']
# ['Ford, Mr Neil Watson', 'Fox, Mr Patrick', 'Franklin, Mr Charles', 'Gallagher, Mr Martin', 'Garfirth, Mr John']
# ['Georges, Mrs Shahini Weappi', 'Gilinski, Mr Leslie', 'Gilnagh, Miss Katie', 'Glynn, Miss Mary Agatha', 'Goldsmith, Mr Frank John']
# ['Goldsmith, Mrs Frank John (Emily A Brown)', 'Goldsmith, Master Frank John William', 'Goldsmith, Mr Nathan', 'Goncalves, Mr Manuel Estanslas', 'Goodwin, Mr Frederick']
# ['Goodwin, Mrs Frederick (Augusta)', 'Goodwin, Mr Charles E', 'Goodwin, Miss Lillian A', 'Goodwin, Master Harold V', 'Goodwin, Miss Jessie A']
# ['Goodwin, Master Sidney L', 'Goodwin, Master William F', 'Green, Mr George', 'Gronnestad, Mr Daniel Danielsen', 'Guest, Mr Robert']
# ['Gustafsson, Mr Alfred Ossian', 'Gustafsson, Mr Anders Vilhelm', 'Gustafsson, Mr Johan Birger', 'Gustafsson, Mr Karl Gideon', 'Haas, Miss Aloisia']
# ['Hagardon, Miss Kate', 'Hagland, Mr Ingvald Olsen', 'Hagland, Mr Konrad Mathias Reiersen', 'Hakkarainen, Mr Pekko Pietari', 'Hakkarainen, Mrs Pekko Pietari']
# ['Hampe, Mr Leon', 'Hansen, Mr Claus Peter', 'Hansen, Mrs Claus Peter', 'Hansen, Mr Henrik Juul', 'Hansen, Mr Henry Damsgaard']
# ['Harknett, Miss Alice', 'Harmer, Mr Abraham', 'Hart, Mr Henry', 'Hassan, Mr M Houssein', 'Healy, Miss Nora']
# ['Hedman, Mr Oscar', 'Hee, Mr Ling', 'Hegarty, Miss Nora', 'Heikkinen, Miss Laina', 'Heininen, Miss Wendla Maria']
# ['Hellstrom, Hilda Maria', 'Hemming, Miss Nora', 'Hendekovic, Mr Ignaz', 'Henery, Delia', 'Henriksson, Jenny Lovisa']
# ['Hirvonen, Mrs Alexander', 'Hirvonen, Miss Hildur E', 'Holm, Mr John Frederik Alexander', 'Holthen, Mr Johan Martin', 'Honkanen, Miss Eluna']
# ['Horgan, Mr John', 'Howard, Miss May', 'Humblin, Mr Adolf Mathias Nicolai Olsen', 'Hyman, Mr Abraham', 'Ilieff, Mr Ylio']
# ['Ilmakangas, Miss Ida Livija', 'Ilmakangas, Miss Pieta Sofia', 'Ivanoff, Mr Konio', 'Jansen, Mr Carl Olof', 'Jardin, Mr Jose Netto']
# ['Jensen, Miss Carla Christine', 'Jensen, Mr Hans Peder', 'Jensen, Mr Niels Peder', 'Jensen, Mr Svend Lauritz', 'Jermyn, Miss Annie']
# ['Johannesen-Bratthammer, Mr Bernt', 'Johanson, Mr Jakob Alfred', 'Johansson, Mr Erik', 'Johansson, Mr Gustaff Joel', 'Johansson, Mr Karl Johan']
# ['Johansson, Mr Nils', 'Johansson, Oscar L', 'Johnson, Mr Alfred', 'Johnson, Miss Eleanor Ileen', 'Johnson, Mr Malkolm Joackim']
# ['Johnson, Master Harold Theodor', 'Johnson, Mrs Oscar W', 'Johnson, Mr William Cahoone Jr', 'Johnston, Mr Andrew G', 'Johnston, Mrs Andrew G']
# ['Johnston, Miss Catherine H', 'Johnston, Master William A', 'Jonkoff, Mr Lazor', 'Jonsson, Mr Carl', 'Jonsson, Nils Hilding']
# ['Jussila, Miss Aina Maria', 'Jussila, Mr Erik', 'Jussila, Miss Katriina', 'Kallio, Mr Nikolai Erland', 'Kalvig, Mr Johannes K Halverson']
# ['Karajic, Mr Milan', 'Karlsson, Mr Einar Gervasius', 'Karlsson, Mr Julius Konrad Eugen', 'Karlsson, Mr Nils August', 'Karun, Miss Anna Mary']
# ['Karun, Mr Franz', 'Kassem, Mr Fared', 'Keane, Mr Andrew', 'Keefe, Mr Arthur', 'Kekic, Mr Tido']
# ['Kelly, Miss Anna Kate', 'Kelly, Mr James', 'Kelly, Mr James', 'Kelly, Miss Mary', 'Kennedy, Mr John']
# ['Khalil, Mr Betros', 'Khalil, Mrs Betros', 'Khalil, Mr Saad', 'Kiernan, Mr John', 'Kiernan, Mr Philip']
# ['Kilgannon, Mr Thomas', 'Kink, Mr Anton', 'Kink, Mrs Anton (Louise Heilmann)', 'Kink, Miss Louise Gretchen', 'Kink, Miss Maria']
# ['Kink, Mr Vincenz', 'Klasen, Miss Gertrud Emilia', 'Klasen, Mrs Hulda Kristina', 'Klasen, Mr Klas Albin', 'Kraeff, Mr Theodor']
# ['Krekorian, Mr Neshan', 'Lahowd, Mr Sarkis', 'Laitinen, Miss Kritina Sofia', 'Laleff, Mr Kristo', 'Lam, Mr Ali']
# ['Lam, Mr Len', 'Landegren, Miss Aurora Adelia', 'Lane, Mr Patrick', 'Lang, Mr Fang', 'Larsson, Mr August Viktor']
# ['Larsson, Mr Bengt Edvin', 'Larsson-Rondberg, Mr Edvard', 'Leeni, Mr Fahim', 'Lefebre, Mrs Frank', 'Lefebre, Master Henry']
# ['Lefebre, Miss Ida', 'Lefebre, Miss Jeannie', 'Lefebre, Miss Mathilde', 'Leinonen, Mr Antti Gustaf', 'Lemberopolous, Mr Peter L']
# ['Lemom, Mr Denis', 'Lemon, Miss Mary', 'Leonard, Mr Lionel', 'Lester, Mr James', 'Lindahl, Miss Agda V']
# ['Lindblom, Miss Augusta Charlotta', 'Lindell, Mr Edvard Bengtsson', 'Lindell, Mrs Edvard Bengtsson', 'Lindqvist, Eino William', 'Linehan, Mr Michael']
# ['Ling, Mr Lee', 'Lithman, Mr Simon', 'Lobb, Mr William Arthur', 'Lobb, Mrs William Arthur', 'Lockyer, Mr Edward']
# ['Lovell, Mr John', 'Lulich, Mr Nicola', 'Lundahl, Mr Johan', 'Lundin, Miss Olga Elida', 'Lundstrom, Mr Thure Edvin']
# ['Lyntakoff, Mr Stanko', 'MacKay, Mr George William', 'Madigan, Miss Margaret', 'Madsen, Mr Frithiof', 'Maenpaa, Mr Matti Alexanteri']
# ['Mahon, Miss Delia', 'Maisner, Mr Simon', 'Makinen, Mr Kalle Edvard', 'Mamee, Mr Hanna', 'Mangan, Miss Mary']
# ['Mannion, Miss Margareth', 'Mansour, Mr Hanna', 'Mardirosian, Mr Sarkis', 'Marinko, Mr Dmitri', 'Markim, Mr Johann']
# ['Markoff, Mr Marin', 'Masselmany, Mrs Fatima', 'Matinoff, Mr Nicola', 'McCarthy, Miss Katie', 'McCormack, Mr Thomas J']
# ['McCoy, Miss Agnes', 'McCoy, Miss Alice', 'McCoy, Mr Bernard', 'McDermott, Miss Delia', 'McElroy, Mr Michael']
# ['McGovern, Mrs Hugh', 'McGowan, Miss Anna', 'McGowan, Miss Katherine', 'McMahon, Mr Martin', 'McNamee, Mr Neal']
# ['McNamee, Mrs Neal', 'Meanwell, Miss Marion Ogden', 'Mechen, Mr John', 'Meek, Mrs Thomas', 'Melkebuk, Mrs Philemon']
# ['Meo, Mr Alfonso', 'Midtsjo, Mr Karl Albert', 'Mihoff, Mr Stoytcho', 'Miles, Mr Frank', 'Mineff, Mr Ivan']
# ['Minkoff, Mr Lazar', 'Mirko, Mr Dika', 'Mitkoff, Mr Mito', 'Mocklare, Miss Helen Mary', 'Moen, Mr Sigurd H']
# ['Moor, Mrs Beila', 'Moor, Master Meier', 'Moore, Mr Leonard Charles', 'Moran, Miss Bertha', 'Moran, Mr Daniel J']
# ['Moran, Mr James', 'Morley, Mr Henry Samuel', 'Morrow, Mr Thomas Rowan', 'Moubarek (Borak), Mr Hanna (John)', 'Moubarek, Mrs George']
# ['Moubarek, Master George', 'Moubarek, Master William George', 'Moss, Albert Johan', 'Moussa, Mrs Mantoura Baloics', 'Moutal, Mr Rahamin']
# ['Mullins, Miss Katie', 'Mulvihill, Miss Bertha E', 'Murdlin, Mr Joseph', 'Murphy, Miss Katherine', 'Murphy, Miss Margaret']
# ['Murphy, Miss Nora', 'Myhrman, Mr Pehr Fabian Oliver Malkolm', 'Nackid, Miss Maria', 'Nackid, Mr Said', 'Nackid, Mrs Said']
# ['Nahill, Mr Toufik', 'Naidenoff, Mr Penko', 'Nancarrow, W H', 'Niklasen, Sander', 'Nosworthy, Richard C']
# ['Najib, Miss Adele Kiamie', 'Nancarrow, Mr William Henry', 'Nankoff, Mr Minko', 'Nasr, Mr Mustafa', 'Nassr, Mr Saade Jean']
# ['Naughton, Miss Hannah', 'Nemaugh, Mr Robert', 'Nenkoff, Mr Christo', 'Nicola-Yarred, Miss Jamila', 'Nicola-Yarred, Master Elias']
# ['Nieminen, Miss Manta Josefina', 'Niklasson, Mr Samuel', 'Nilsson, Mr August Ferdinand', 'Nilsson, Miss Berta Olivia', 'Nilsson, Miss Helmina Josefina']
# ['Niskanen, Mr Johan', 'Nosworthy, Mr Richard Cater', 'Novel, Mansouer', 'Nysten, Miss Anna', 'Nysveen, Mr Johan H']
# ["O'Brien, Mr Denis", "O'Brien, Mr Thomas", "O'Brien, Mrs Thomas", "O'Connell, Mr Patrick D", "O'Connor, Mr Maurice"]
# ["O'Connor, Mr Patrick", 'Odahl, Mr Nils Martin', "O'Dwyer, Miss Nellie", 'Ohman, Miss Velin', "O'Keefe, Mr Patrick"]
# ['OLeary, Miss Norah', 'Olsen, Master Arthur', 'Olsen, Mr Charlie (Carl)', 'Olsen, Mr Henry Margido', 'Olsen, Mr Ole M']
# ['Olsson, Miss Elida', 'Olsson, Mr Nils Johan', 'Olsson, Mr Oscar Johansson', "O'Neill, Miss Bridget", 'Oreskovic, Mr Jeko']
# ['Oreskovic, Mr Luka', 'Oreskovic, Mr Maria', 'Osen, Mr Olof Elon', 'Osman, Miss Maria', "O'Sullivan, Miss Bridget"]
# ['Panula, Mr Ernesti Arvid', 'Panula, Mr Jaako Arnold', 'Panula, Master Juha Niilo', 'Panula, Mrs John', 'Panula, Master Urho Abraham']
# ['Panula, Master William', 'Pasic, Mr Jakob', 'Paulner, Mr Uscher', 'Paulsson, Master Gosta Leonard', 'Paulsson, Mrs Nils']
# ['Paulsson, Master Paul Folke', 'Paulsson, Miss Stina Viola', 'Paulsson, Miss Torborg Danira', 'Pavlovic, Mr Stefo', 'Peacock, Master Alfred Edward']
# ['Peacock, Mrs Benjamin', 'Peacock, Miss Treasteall', 'Pearce, Mr Ernest', 'Pecruic, Mr Mate', 'Pecruic, Mr Tome']
# ['Pedersen, Mr Olaf', 'Peduzzi, Mr Joseph', 'Pekoniemi, Mr Edvard', 'Peltomaki, Nikolai Johannes', 'Perkin, Mr John Henry']
# ['Persson, Mr Ernst Ulrik', 'Peter (Joseph), Miss Mary', 'Peter (Joseph), Mrs Catherine', 'Peter (Joseph), Master Michael J', 'Peters, Miss Katie']
# ['Petersen, Mr Marius', 'Petranec, Miss Matilda', 'Petroff, Mr Nedeca', 'Petroff, Mr Pentcho', 'Pettersson, Miss Ellen Natalia']
# ['Peterson, Mr Johan Emil', 'Pickard (Trembisky), Mr Berk', 'Plotcharsky, Mr Vasil', 'Potchett, Mr George', 'Radeff, Mr Alexander']
# ['Raibid, Mr Razi', 'Reed, Mr James George', 'Reynolds, Mr Harold', 'Rice, Master Albert', 'Rice, Master Arthur']
# ['Rice, Master George', 'Rice, Master Eric', 'Rice, Master Eugene', 'Rice, Mrs William', 'Riihiivouri, Miss Sanni']
# ['Rintamaki, Mr Matti', 'Riordan, Miss Hannah', 'Risien, Mr Samuel', 'Risien, Mrs Samuel', 'Robins, Mr Alexander A']
# ['Robins, Mrs Alexander A', 'Rommetvedt, Mr Karl Kristian Knut', 'Rogers, Mr William John', 'Rosblom, Mrs Viktor', 'Rosblom, Miss Salli Helena']
# ['Rosblom, Mr Viktor Rickard', 'Roth, Miss Sarah', 'Rouse, Mr Richard Henry', 'Rush, Mr Alfred George John', 'Ryan, Mr Edward Ryan']
# ['Ryan, Mr Patrick', 'Saad, Mr Amin', 'Saad, Khalil', 'Sadlier, Mr Matthew', 'Sadowitz, Mr Harry']
# ['Sage, Miss Ada', 'Sage, Miss Constance', 'Sage, Miss Dorothy', 'Sage, Mr Douglas', 'Sage, Mr Frederick']
# ['Sage, Mr George', 'Sage, Mr John', 'Sage, Mrs John', 'Sage, Miss Stella', 'Sage, Thomas (child)']
# ['Sage, Master William', 'Salander, Mr Karl Johan', 'Salkjelsvik, Miss Anna', 'Salonen, Mr Johan Werner', 'Samaan, Mr Elias']
# ['Samaan, Mr Hanna', 'Samaan, Mr Youssef', 'Sandstrom, Miss Hjalmar', 'Sandstrom, Miss Beatrice Irene', 'Sandstrom, Miss Marguerite Rut']
# ['Sather, Simon Sivertsen', 'Saundercock, William Henry', 'Sawyer, Mr Frederick', 'Scanlan, Mr James', 'Sdycoff, Mr Todor']
# ['Seman Master Betros', 'Serota, Mr Maurice', 'Shaughnesay, Mr Patrick', 'Shedid (Sitik), Mr Daher (Docart)', 'Sheerlinck, Mr Jean']
# ['Shellard, Mr Frederick B', 'Shine, Miss Ellen', 'Shorney, Mr Charles', 'Simmons, Mr John', 'Sirayanian, Mr Arsun']
# ['Sivic, Mr Husen', 'Sivola, Mr Antti', 'Sjoblom, Miss Anna Sofia', 'Sholt, Mr Peter Andreas Lauritz Andersen', 'Skinner, Mr Henry John']
# ['Skoog, Master Harald', 'Skoog, Master Karl', 'Skoog, Miss Mabel', 'Skoog, Miss Margit', 'Skoog, Mr William']
# ['Skoog, Mrs William', 'Slabenoff, Mr Petco', 'Slocovski, Mr Selman', 'Smiljanovic, Mr Mile', 'Smyth, Miss Julia']
# ['Solvang, Mrs Lena Jacobsen', 'Somerton, Mr Francis William', 'Sop, Mr Jules', 'Spector, Mr Woolf', 'Staneff, Mr Ivan']
# ['Stankovic, Mr Jovan', 'Stanley, Miss Amy Zilla Elsie', 'Stanley, Mr Edward Roland', 'Storey, Mr Thomas', 'Stoyehoff, Mr Ilia']
# ['Strandberg, Miss Ida Sofia', 'Stranden, Mr Juho', 'Strilic, Mr Ivan', 'Strom, Mrs Wilhelm', 'Strom, Miss Telma (Selma) Matilda']
# ['Sunderland, Mr Victor Francis', 'Sundman, Mr Johan Julian', 'Sutehall, Mr Henry, Jr', 'Svensson, Mr Johan', 'Svensson, Mr Johan Cervin']
# ['Svensson, Mr Olof', 'Tannous, Mr Thomas', 'Tenglin, Mr Gunnar Isidor', 'Theobald, Mr Thomas Leonard', 'Thomas, Mrs Alexander']
# ['Thomas, Master Assad Alexander', 'Thomas, Mr Charles', 'Thomas, Mr John, Jr', 'Thomas, Mr John (? 1st/2nd class)', 'Thomson, Mr Alexander']
# ['Thorneycroft, Mr Percival', 'Thorneycroft, Mrs Percival', 'Tikkanen, Mr Juho', 'Tobin, Mr Roger', 'Todoroff, Mr Lalio']
# ['Toerber, Mr Ernest William', 'Tomlin, Mr Ernest Portage', 'Torfa, Mr Assad', 'Tornquist, Mr William Henry', 'Touma (Thomas), Mrs Darwin']
# ['Touma (Thomas), Master George', 'Touma (Thomas), Miss Hannah', 'Turcin, Mr Stefan', 'Turja, Miss Anna Sofia', 'Turkula, Mrs Hedvig']
# ['Uzelas, Mr Joso', 'Van Billiard, Mr Austin Blyler', 'Van Billiard, Master James William', 'Van Billiard, Master Walter John', 'Van der Planke, Miss Augusta']
# ['Van der Planke, Mr Jules', 'Van der Planke, Mrs Jules', 'Van der Planke, Mr Leon', 'Van der Steen, Mr Leo Peter', 'Van de Velde, Mr John Joseph']
# ['Vandewalle, Mr Nestor Cyriel', 'Van Impe, Miss Catharine', 'Van Impe, Mr Jean Baptiste', 'Van Impe, Mrs Jean Baptiste', 'Vartunian, Mr David']
# ['Vassilios, Mr Catavelas', 'Vendel, Mr Olof Wdvin', 'Vereruysse, Mr Victor', 'Vestrom, Miss Hulda Amanda Adolfina', 'Vonk, Mr Jenko']
# ['Ware, Mr Frederick', 'Warren, Mr Charles William', 'Wazli, Mr Yousif', 'Webber, Mr James', 'Wennerstrom, Mr August Edvard']
# ['Wenzel, Mr Linhart', 'Widegren, Mr Charles Peter', 'Wiklund, Mr Jacob Alfred', 'Wilkes, Mrs Ellen', 'Willer, Mr Aaron']
# ['Willey, Mr Edward', 'Williams, Mr Howard Hugh', 'Williams, Mr Leslie', 'Windelov, Mr Einar', 'Wirz, Mr Albert']
# ['Wiseman, Mr Phillippe', 'Wittevrongel, Mr Camiel', 'Yalsevac, Mr Ivan', 'Yasbeck, Mr Antoni', 'Yasbeck, Mrs Antoni']
# ['Youssef, Mr Gerios', 'Zabour, Miss Hileni', 'Zabour, Miss Tamini', 'Zakarian, Mr Artun', 'Zakarian, Mr Maprieder']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Mr
#                                    Pattern 'Mr' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#                                                    \b(Mr)\b
# --------------------------------------------------------------------------------------------------------------
# /content/functions.py:424: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   list_of_names = list(df.loc[~df[nama_kolom].str.contains(pat=text_pattern, regex=True)]['Name'])
#                                          Values pada kolom Name = 562                                         :
# ['Allen, Miss Elisabeth Walton', 'Allison, Miss Helen Loraine', 'Allison, Mrs Hudson JC (Bessie Waldo Daniels)', 'Allison, Master Hudson Trevor', 'Andrews, Miss Kornelia Theodosia']
# ['Appleton, Mrs Edward Dale (Charlotte Lamson)', 'Astor, Colonel John Jacob', 'Astor, Mrs John Jacob (Madeleine Talmadge Force)', 'Aubert, Mrs Leontine Pauline', 'Baxter, Mrs James (Helene DeLaudeniere Chaput)']
# ['Beckwith, Mrs Richard Leonard (Sallie Monypeny)', 'Bishop, Mrs Dickinson H (Helen Walton)', 'Bonnell, Miss Caroline', 'Bonnell, Miss Elizabeth', 'Bowen, Miss Grace Scott']
# ['Bowerman, Miss Elsie Edith', 'Brewe, Dr Arthur Jackson', 'Brown, Mrs James Joseph (Margaret Molly" Tobin)"', 'Brown, Mrs John Murray (Caroline Lane Lamson)', 'Bucknell, Mrs William Robert (Emma Eliza Ward)']
# ['Butt, Major Archibald Willingham', 'Candee, Mrs Edward (Helen Churchill Hungerford)', 'Cardeza, Mrs James Warburton Martinez (Charlotte Wardle Drake)', 'Carter, Mrs William Ernest (Lucile Polk)', 'Carter, Miss Lucile Polk']
# ['Carter, Master William T II', 'Cassebeer, Mrs Henry Arthur jr (Genevieve Fosdick)', 'Cavendish, Mrs Tyrell William Julia Florence Siegel', 'Chaffee, Mrs Herbert Fuller (Carrie Constance Toogood)', 'Chambers, Mrs Norman Campbell (Bertha Griggs)']
# ['Cherry, Miss Gladys', 'Chibnall (Bowerman), Mrs Edith Martha', 'Clark, Mrs Walter Miller (Virginia McDowell)', 'Compton, Mrs Alexander Taylor (Mary Eliza Ingersoll)', 'Compton, Miss Sara Rebecca']
# ['Cornell, Mrs Robert Clifford (Malvina Helen Lamson)', 'Crosby, Captain Edward Gifford', 'Crosby, Mrs Edward Gifford (Catherine Elizabeth Halstead)', 'Crosby, Miss Harriet R', 'Cumings, Mrs John Bradley (Florence Briggs Thayer)']
# ['Davidson, Mrs Thornton (Orian Hays)', 'de Villiers, Madame Berthe', 'Dick, Mrs Albert Adrian Vera Gillespie', 'Dodge, Dr Washington', 'Dodge, Mrs Washington (Ruth Vidaver)']
# ['Dodge, Master Washington', 'Douglas, Mrs Frederick Charles (Suzette Baxter)', 'Douglas, Mrs Walter Donald (Mahala Dutton)', 'Duff Gordon, Sir Cosmo Edmund', 'Duff Gordon, Lady (Lucille Wallace Sutherland)']
# ['Earnshaw, Mrs Boulton (Olive Potter)', 'Eustis, Miss Elizabeth Mussey', 'Evans, Miss Edith Corse', 'Flegenheim, Mrs Alfred (Antoinette)', 'Fortune, Miss Alice Elizabeth']
# ['Fortune, Miss Ethel Flora', 'Fortune, Miss Mabel', 'Fortune, Mrs Mark (Mary McDougald)', 'Frauenthal, Dr Henry William', 'Frauenthal, Mrs Henry William (Clara Heinsheimer)']
# ['Frolicher, Miss Marguerite', 'Frolicher-Stehli, Mrs Maxmillian (Margaretha Emerentia Stehli)', 'Futrelle, Mrs Jacques (May Peel)', 'Gibson, Miss Dorothy', 'Gibson, Mrs Leonard (Pauline C Boeson)']
# ['Goldenberg, Mrs Samuel L (Edwiga Grabowsko)', 'Gracie, Colonel Archibald IV', 'Graham, Miss Margaret Edith', 'Graham, Mrs William Thompson (Edith Junkins)', 'Greenfield, Mrs Leo David (Blanche Strouse)']
# ['Harder, Mrs George Achilles (Dorothy Annan)', 'Harper, Mrs Henry Sleeper (Myna Haxtun)', 'Harris, Mrs Henry Birkhardt (Irene Wallach)', 'Hays, Mrs Charles Melville (Clara Jennings Gregg)', 'Hays, Miss Margaret Bechstein']
# ['Hippach, Miss Jean Gertrude', 'Hippach, Mrs Louis Albert (Ida Sophia Fischer)', 'Hogeboom, Mrs John C (Anna Andrews)', 'Holverson, Mrs Alexander Oskar (Mary Aline Towner)', 'Hoyt, Mrs Frederick Maxfield (Jane Anne Forby)']
# ['Isham, Miss Anne Elizabeth', 'Kenyon, Mrs Frederick R (Marion)', 'Kimball, Mrs Edwin Nelson Jr (Gertrude Parsons)', 'Leader, Dr Alice Farnham', 'Lindstrom, Mrs Carl Johan (Sigrid Posse)']
# ['Lines, Mrs Ernest H (Elizabeth Lindsey James)', 'Lines, Miss Mary Conover', 'Longley, Miss Gretchen Fiske', 'Madill, Miss Georgette Alexandra', 'Marvin, Mrs Daniel Warner (Mary Graham Carmichael Farquarson)']
# ['Meyer, Mrs Edgar Joseph (Leila Saks)', 'Minahan, Miss Daisy E', 'Minahan, Dr William Edward', 'Minahan, Mrs William Edward (Lillian E Thorpe)', 'Newell, Miss Madeleine']
# ['Newell, Miss Marjorie', 'Newsom, Miss Helen Monypeny', 'Ostby, Miss Helen Raghnild', 'Pears, Mrs Thomas (Edith)', 'Penasco, Mrs Victor de Satode (Josefa de Soto)']
# ['Peuchen, Major Arthur Godfrey', 'Potter, Mrs Thomas, Jr (Lily Alexenia Wilson)', 'Reuchlin, Jonkheer John George', 'Robert, Mrs Edward Scott (Elisabeth Walton McMillan)', 'Rosenbaum (Russell), Miss Edith Louise']
# ['Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)', 'Rothschild, Mrs Martin (Elizabeth L Barrett)', 'Ryerson, Mrs Arthur Larned (Emily Maria Borie)', 'Ryerson, Miss Emily Borie', 'Ryerson, Master John Borie']
# ['Ryerson, Miss Susan (Suzette) Parker', 'Schabert, Mrs Paul (Emma Mock)', 'Shutes, Miss Elizabeth W', 'Silvey, Mrs William Baird (Alice Munger)', 'Simonius-Blumer, Col Alfons']
# ['Smith, Mrs Lucien Philip (Mary Eloise Hughes', 'Snyder, Mrs John Pillsbury (Nelle Stevenson)', 'Spedden, Mrs Frederick Oakley (Margaretta Corning Stone)', 'Spedden, Master Robert Douglas', 'Spencer, Mrs William Augustus (Marie Eugenie)']
# ['Staehlin, Dr Max', 'Stengel, Mrs Charles Emil Henry (Annie May Morris)', 'Stephenson, Mrs Walter Bertram (Martha Eustis)', 'Stone, Mrs George Nelson (Martha E)', 'Straus, Mrs Isidor (Ida Blun)']
# ['Swift, Mrs Frederick Joel (Margaret Welles Barron)', 'Taussig, Mrs Emil (Tillie Mandelbaum)', 'Taussig, Miss Ruth', 'Taylor, Mrs Elmer Zebley (Juliet Cummins Wright)', 'Thayer, Mrs John Borland (Marian Longstreth Morris)']
# ['Thorne, Mrs Gertrude Maybelle', 'Warren, Mrs Frank Manley (Anna S Atkinson)', 'Weir, Col John', 'White, Mrs J Stuart (Ella Holmes)', 'Wick, Mrs George Dennick (Martha Hitchcock)']
# ['Wick, Miss Mary Natalie', 'Widener, Mrs George Dunton (Eleanor Elkins)', 'Willard, Miss Constance', 'Young, Miss Marie Grice', 'Barber, Ms ']
# ['Bazzani, Ms Albina', 'Bidois, Miss Rosalie', 'Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret']
# ['Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice', 'Daniels, Ms Sarah', 'Endres, Miss Caroline Louise', 'Fleming, Ms Margaret']
# ['Francatelli, Ms Laura Mabel', 'Geiger, Miss Emily ', 'Icabad (Icabod), Ms', 'Kenchen, Ms Amelia', 'LeRoy, Miss Berthe']
# ['Maloney, Ms', 'Oliva, Mlle', 'Pericault, Ms', 'Segesser, Mlle Emma', 'Seredeca, Ms']
# ['Ward, Ms Anna', 'Wilson, Ms Helen', 'Abelson, Mrs Samuel (Anna)', 'Angle, Mrs William A (Florence)', 'Balls, Mrs Ada E Hall']
# ['Bateman, Rev Robert James', 'Beane, Mrs Edward (Ethel Clarke)', 'Becker, Mrs Allen Oliver (Nellie E Baumgardner)', 'Becker, Miss Marion Louise', 'Becker, Master Richard F']
# ['Becker, Miss Ruth Elizabeth', 'Bentham, Miss Lilian W', 'Brown, Miss Edith E', 'Brown, Mrs Thomas William Solomon (Elizabeth C)', 'Bryhl, Miss Dagmar']
# ['Buss, Miss Kate', 'Byles, Rev Thomas Roussel D', 'Bystrom, Mrs Carolina', 'Caldwell, Mrs Albert Francis (Sylvia Mae Harbaugh)', 'Caldwell, Master Alden Gates']
# ['Cameron, Miss Clear', 'Carter, Rev Ernest Courtenay', 'Carter, Mrs Ernest Courtenay (Lillian Hughes)', 'Chapman, Mrs John Henry (Elizabeth Lawry)', 'Christy, Mrs Alice Frances']
# ['Christy, Miss Julie', 'Clarke, Mrs Charles V (Ada Maria)', 'Collyer, Mrs Harvey (Charlotte Tate)', 'Collyer, Miss Marjorie', 'Cook, Mrs Selena Rogers']
# ['Corbett, Mrs Walter H (Irene Colvin)', 'Corey, Mrs Percy C (Mary Phyllis Elizabeth Miller)', 'Davis, Mrs Agnes', 'Davis, Master John Morgan', 'Davis, Miss Mary']
# ['del Carlo, Mrs Sebastiano (Argenia Genovese)', 'Doling, Mrs Ada', 'Doling, Miss Elsie', 'Drew, Mrs James Vivian (Lulu Thorne Christian)', 'Drew, Master Marshall Brines']
# ['Duran y More, Miss Asuncion', 'Duran y More, Miss Florentina', 'Faunthorpe, Mrs Lizzie (see Wilkinson, E)', 'Funk, Miss Annie C', 'Garside, Miss Ethel']
# ['Hamalainen, Mrs William (Anna)', 'Hamalainen, Master Viljo', 'Harper, Rev John', 'Harper, Miss Nina', 'Hart, Mrs Benjamin (Esther)']
# ['Hart, Miss Eva Miriam', 'Herman, Miss Alice', 'Herman, Miss Kate', 'Herman, Mrs Samuel (Jane Laver)', 'Hewlett, Mrs Mary D']
# ['Hiltunen, Miss Marta', 'Hocking, Mrs Elizabeth', 'Hocking, Miss Ellen (Nellie)', 'Hold, Mrs Stephen (Annie Margaret)', 'Howard, Mrs Benjamin (Ellen Truelove)']
# ['Ilett, Miss Bertha', 'Jacobsohn, Mrs Sidney Samuel (Amy Frances Christy)', 'Jerwan, Mrs Amin S (Marie Thuillard)', 'Kantor, Mrs Sinai (Miriam Sternim)', 'Karnes, Mrs J Frank (Claire Bennett)']
# ['Keane, Miss Nora A', 'Kelly, Mrs Florence (Fannie)', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William', 'Lahtinen, Mrs William (Anna Sylvan)']
# ['Lemore, Mrs Amelia', 'LaRoche, Mrs Joseph (Juliet)', 'LaRoche, Miss Louise', 'LaRoche, Miss Simonne', 'Lehmann, Miss Bertha']
# ['Leitch, Miss Jessie', 'Louch, Mrs Charles Alexander (Alice Adelaide)', 'Mack, Mrs Mary', 'Mallet, Mrs Albert (Antoinette)', 'Mallet, Master Andre']
# ['Mantvila, Rev Joseph', 'Marshall, Mrs Kate Louise Phillips', 'Mellenger, Mrs Elizabeth Anne', 'Mellenger, Miss Madeleine Violet', 'Moraweck, Dr Ernest']
# ['Nasser (Nasrallah), Mrs Nicholas', 'Navratil, Master Edmond Roger', 'Navratil, Master Michel M', 'Nye, Mrs Elizabeth Ramell', 'Pain, Dr Alfred']
# ['Parrish, Mrs Lutie Davis', 'Peruschitz, Rev Joseph M', 'Phillips, Miss Alice', 'Pinsky, Miss Rosa', 'Quick, Mrs Frederick C (Jane Richards)']
# ['Quick, Miss Phyllis May', 'Quick, Miss Winifred Vera', 'Renouf, Mrs Peter Henry (Lillian Jefferys)', 'Reynaldo, Mrs Encarnacion', 'Richards, Master George Sidney']
# ['Richards, Mrs Sidney (Emily Hocking)', 'Richards, Master William Rowe', 'Ridsdale, Miss Lucy', 'Rugg, Miss Emily', 'Shelley, Mrs William (Imanita)']
# ['Silven, Miss Lyyli', 'Sincock, Miss Maude', 'Siukonnen, Miss Anna', 'Slayter, Miss Hilda Mary', 'Smith, Miss Marion']
# ...
#                          \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 51                                          :
# ['Duff Gordon, Lady (Lucille Wallace Sutherland)', 'Reuchlin, Jonkheer John George', 'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)', 'Simonius-Blumer, Col Alfons', 'Weir, Col John']
# ['Barber, Ms ', 'Bazzani, Ms Albina', 'Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret']
# ['Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice', 'Daniels, Ms Sarah', 'Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel']
# ['Icabad (Icabod), Ms', 'Kenchen, Ms Amelia', 'Maloney, Ms', 'Oliva, Mlle', 'Pericault, Ms']
# ['Segesser, Mlle Emma', 'Seredeca, Ms', 'Ward, Ms Anna', 'Wilson, Ms Helen', 'Bateman, Rev Robert James']
# ['Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay', 'Harper, Rev John', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William']
# ['Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M', 'Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria']
# ['Henery, Delia', 'Henriksson, Jenny Lovisa', 'Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William']
# ['Moss, Albert Johan', 'Nancarrow, W H', 'Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer']
# ['Peltomaki, Nikolai Johannes', 'Saad, Khalil', 'Sage, Thomas (child)', 'Sather, Simon Sivertsen', 'Saundercock, William Henry']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Lady
#                                   Pattern 'Lady' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#                       \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 50                                          :
# ['Reuchlin, Jonkheer John George', 'Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)', 'Simonius-Blumer, Col Alfons', 'Weir, Col John', 'Barber, Ms ']
# ['Bazzani, Ms Albina', 'Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret', 'Chaudanson, Ms         Victorine']
# ['Cleaver, Ms Alice', 'Daniels, Ms Sarah', 'Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel', 'Icabad (Icabod), Ms']
# ['Kenchen, Ms Amelia', 'Maloney, Ms', 'Oliva, Mlle', 'Pericault, Ms', 'Segesser, Mlle Emma']
# ['Seredeca, Ms', 'Ward, Ms Anna', 'Wilson, Ms Helen', 'Bateman, Rev Robert James', 'Byles, Rev Thomas Roussel D']
# ['Carter, Rev Ernest Courtenay', 'Harper, Rev John', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William', 'Mantvila, Rev Joseph']
# ['Peruschitz, Rev Joseph M', 'Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria', 'Henery, Delia']
# ['Henriksson, Jenny Lovisa', 'Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William', 'Moss, Albert Johan']
# ['Nancarrow, W H', 'Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer', 'Peltomaki, Nikolai Johannes']
# ['Saad, Khalil', 'Sage, Thomas (child)', 'Sather, Simon Sivertsen', 'Saundercock, William Henry', 'Zimmerman, Leo']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Jonkheer
#                                 Pattern 'Jonkheer' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#                   \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 49                                          :
# ['Rothes, the Countess of (Noel Lucy Martha Dyer-Edwardes)', 'Simonius-Blumer, Col Alfons', 'Weir, Col John', 'Barber, Ms ', 'Bazzani, Ms Albina']
# ['Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret', 'Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice']
# ['Daniels, Ms Sarah', 'Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel', 'Icabad (Icabod), Ms', 'Kenchen, Ms Amelia']
# ['Maloney, Ms', 'Oliva, Mlle', 'Pericault, Ms', 'Segesser, Mlle Emma', 'Seredeca, Ms']
# ['Ward, Ms Anna', 'Wilson, Ms Helen', 'Bateman, Rev Robert James', 'Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay']
# ['Harper, Rev John', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William', 'Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M']
# ['Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria', 'Henery, Delia', 'Henriksson, Jenny Lovisa']
# ['Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William', 'Moss, Albert Johan', 'Nancarrow, W H']
# ['Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer', 'Peltomaki, Nikolai Johannes', 'Saad, Khalil']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: the Countess of
#                              Pattern 'the Countess of' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#           \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 48                                          :
# ['Simonius-Blumer, Col Alfons', 'Weir, Col John', 'Barber, Ms ', 'Bazzani, Ms Albina', 'Bird, Ms Ellen']
# ['Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret', 'Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice', 'Daniels, Ms Sarah']
# ['Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel', 'Icabad (Icabod), Ms', 'Kenchen, Ms Amelia', 'Maloney, Ms']
# ['Oliva, Mlle', 'Pericault, Ms', 'Segesser, Mlle Emma', 'Seredeca, Ms', 'Ward, Ms Anna']
# ['Wilson, Ms Helen', 'Bateman, Rev Robert James', 'Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay', 'Harper, Rev John']
# ['Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William', 'Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M', 'Bjorklund, Ernst Herbert']
# ['Everett, Thomas James', 'Hellstrom, Hilda Maria', 'Henery, Delia', 'Henriksson, Jenny Lovisa', 'Johansson, Oscar L']
# ['Jonsson, Nils Hilding', 'Lindqvist, Eino William', 'Moss, Albert Johan', 'Nancarrow, W H', 'Niklasen, Sander']
# ['Nosworthy, Richard C', 'Novel, Mansouer', 'Peltomaki, Nikolai Johannes', 'Saad, Khalil', 'Sage, Thomas (child)']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Col
#                                    Pattern 'Col' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#         \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 46                                          :
# ['Barber, Ms ', 'Bazzani, Ms Albina', 'Bird, Ms Ellen', 'Bissetti, Ms Amelia', 'Burns, Ms Elizabeth Margaret']
# ['Chaudanson, Ms         Victorine', 'Cleaver, Ms Alice', 'Daniels, Ms Sarah', 'Fleming, Ms Margaret', 'Francatelli, Ms Laura Mabel']
# ['Icabad (Icabod), Ms', 'Kenchen, Ms Amelia', 'Maloney, Ms', 'Oliva, Mlle', 'Pericault, Ms']
# ['Segesser, Mlle Emma', 'Seredeca, Ms', 'Ward, Ms Anna', 'Wilson, Ms Helen', 'Bateman, Rev Robert James']
# ['Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay', 'Harper, Rev John', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William']
# ['Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M', 'Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria']
# ['Henery, Delia', 'Henriksson, Jenny Lovisa', 'Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William']
# ['Moss, Albert Johan', 'Nancarrow, W H', 'Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer']
# ['Peltomaki, Nikolai Johannes', 'Saad, Khalil', 'Sage, Thomas (child)', 'Sather, Simon Sivertsen', 'Saundercock, William Henry']
# --------------------------------------------------------------------------------------------------------------Ms
# Tuliskan pattern yang akan ditambahkan: Ms
#                                    Pattern 'Ms' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#       \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col|Ms)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 29                                          :
# ['Oliva, Mlle', 'Segesser, Mlle Emma', 'Bateman, Rev Robert James', 'Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay']
# ['Harper, Rev John', 'Kirkland, Rev Charles Leonard', 'Lahtinen, Rev William', 'Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M']
# ['Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria', 'Henery, Delia', 'Henriksson, Jenny Lovisa']
# ['Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William', 'Moss, Albert Johan', 'Nancarrow, W H']
# ['Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer', 'Peltomaki, Nikolai Johannes', 'Saad, Khalil']
# --------------------------------------------------------------------------------------------------------------Mlle
# Tuliskan pattern yang akan ditambahkan: Mlle
#                                   Pattern 'Mlle' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#     \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col|Ms|Mlle)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 27                                          :
# ['Bateman, Rev Robert James', 'Byles, Rev Thomas Roussel D', 'Carter, Rev Ernest Courtenay', 'Harper, Rev John', 'Kirkland, Rev Charles Leonard']
# ['Lahtinen, Rev William', 'Mantvila, Rev Joseph', 'Peruschitz, Rev Joseph M', 'Bjorklund, Ernst Herbert', 'Everett, Thomas James']
# ['Hellstrom, Hilda Maria', 'Henery, Delia', 'Henriksson, Jenny Lovisa', 'Johansson, Oscar L', 'Jonsson, Nils Hilding']
# ['Lindqvist, Eino William', 'Moss, Albert Johan', 'Nancarrow, W H', 'Niklasen, Sander', 'Nosworthy, Richard C']
# ['Novel, Mansouer', 'Peltomaki, Nikolai Johannes', 'Saad, Khalil', 'Sage, Thomas (child)', 'Sather, Simon Sivertsen']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Rev
#                                    Pattern 'Rev' sudah ditambahkan ke list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)1
# --------------------------------------------------------------------------------------------------------------
# ==============================================================================================================
#                         Pattern yang sudah ditambahkan ke list adalah sebagai berikut:
#   \b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col|Ms|Mlle|Rev)\b
# --------------------------------------------------------------------------------------------------------------
#                                          Values pada kolom Name = 19                                          :
# ['Bjorklund, Ernst Herbert', 'Everett, Thomas James', 'Hellstrom, Hilda Maria', 'Henery, Delia', 'Henriksson, Jenny Lovisa']
# ['Johansson, Oscar L', 'Jonsson, Nils Hilding', 'Lindqvist, Eino William', 'Moss, Albert Johan', 'Nancarrow, W H']
# ['Niklasen, Sander', 'Nosworthy, Richard C', 'Novel, Mansouer', 'Peltomaki, Nikolai Johannes', 'Saad, Khalil']
# --------------------------------------------------------------------------------------------------------------
# Tuliskan pattern yang akan ditambahkan: Rev
#                                 Pattern 'Rev' sudah ada sebelumnya pada list!
# --------------------------------------------------------------------------------------------------------------
# Masih ada pattern yang akan ditambahkan ke list? (1=ya/0=tidak)0
# --------------------------------------------------------------------------------------------------------------

# %%
# Cek hasil pemrosesan
title_pattern
# Out:
# '\\b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col|Ms|Mlle|Rev)\\b'

# %% [markdown]
# ---
# **TECHNICAL NOTE**: `REGEX`
#
# Arti dari notasi `regex`:
# ```python
# contoh_pattern = r"\b(Mr|Mrs)\b"
# ```
# > "Pola rangkaian string yang mengandung `Mrs` atau `Mr`.
# ___
# **RESUME**: `Name` Formatting
#
# Write your findings down here:
# 1. Penulisan Colonel ada yang Col
# 2. ada 19 nama tanpa title
# ___

# %% [markdown]
# ##### Column `PClass`

# %% [markdown]
# Di bawah berikut akan dilakukan pengecekan terhadap elemen unik pada kolom PClass.

# %%
# Cek elemen unik yang dimuat dalam kolom
df_titanic['PClass'].unique()
# Out:
# array(['1st', '2nd', '*', '3rd'], dtype=object)

# %%
# Cek rows dengan penulisan yang tidak seragam
df_titanic.loc[df_titanic['PClass']=='*', :]
# Out:
#                          Name PClass  Age   Sex  Survived  SexCode
# rownames
# 457       Jacobsohn Mr Samuel      *  NaN  male         0        0

# %% [markdown]
# ___
# **RESUME**: `PClass` Values
#
# Write your findings down here:
# 1. ... abacab ...
# 2. ... abacab ...
# ___

# %% [markdown]
# ## ***Data Manipulation***
#
# Dari pengamatan terhadap data di atas, terdapat beberapa hal yang perlu untuk dilakukan terhadap dataset, antara lain:
# 1. Menyeragamkan Formatting `Name`:
#   - Penambahan koma pada rows tanpa koma pada kolom `Name`;
#   - Penyeragaman penulisan title `Colonel`==`Col`.
# 2. Memiisahkan values pada kolom `Name` menjadi :
#   - `Title`;
#   - `Surname`;
#   - `Firstname`.
# 3. Mengisi missing values pada kolom:
#   - `Title`; dan
#   - `Age` berdasarkan `Title`.

# %% [markdown]
# ### `Name` Formatting
# 1. Manipulating rows with `Name` value without Comma

# %%
# Cek values pada kolom 'Name' yang tidak mengandung ","
df_titanic.loc[~df_titanic['Name'].str.contains(","), ['Name']]
# Out:
#                          Name
# rownames
# 457       Jacobsohn Mr Samuel
# 1196      Seman Master Betros

# %% [markdown]
# ___
# **TECHNICAL NOTE:**
#
# Untuk manipulasi penyisipan karakter ini, ketika dilakukan dengan menggunakan software spreadsheet, biasanya kita akan menerapkan algoritma manipulasi seperti berikut:
# 1. Filter dataframe untuk menunjukkan hanya rows dan kolom yang akan dimanipulasi, lalu terhadapnya assign hasil manipulasi;
# 2. Proses manipulasi:
#   - Ambil seluruh elemen dari kolom yang akan dimanipulasi;
#   - Filter ke rows spesifik bagi data yang akan dimanipulasi;
#   - Lakukan manipulasi.
# ___

# %%
# Menyisipkan koma ke value  tanpa ", " pada kolom Name
df_titanic.loc[~df_titanic['Name'].str.contains(","), ['Name']] = (  # Assign ke kolom 'Name' dengan rows terfilter:
    df_titanic['Name']                                               # Values pada kolom 'Name' yang
    .loc[~df_titanic['Name'].str.contains(",")]                      # difilter hanya rows berisi strings tidak berkoma, lalu
    .apply(lambda name: ", ".join(name.split(" ", maxsplit=1)))      # sisipkan karakter ", " tepat setelah nama belakangnya.
)

# %%
# Cek hasil manipulasi, seharusnya tidak ada lagi values pada `Name` tanpa ","
df_titanic.loc[~df_titanic['Name'].str.contains(","), :]
# Out:
# Empty DataFrame
# Columns: [Name, PClass, Age, Sex, Survived, SexCode]
# Index: []

# %%
df_titanic.loc[[457, 1196], :]
# Out:
#                           Name PClass  Age   Sex  Survived  SexCode
# rownames
# 457       Jacobsohn, Mr Samuel      *  NaN  male         0        0
# 1196      Seman, Master Betros    3rd  NaN  male         0        0

# %% [markdown]
# ___
# **TECHNICAL NOTE**
#
# > Perhatikan penulisan *script* manipulasi data di atas. `Method chaining` yang biasanya dituliskan dalam 1 baris dapat di*break down* seperti dicontohkan. Pada dasarnya, tidak ada perbedaan pada output yang dihasilkan antara penulisan `method chaining` dalam 1 baris atau terpotong-potong, akan tetapi penulisan terpotong meningkatkan readability dari script, sehingga dianjurkan untuk dilakukan jika `method chaining` yang dipakai cukup panjang.
#
# Sebagai ilustrasi, cermati kedua scripts di bawah berikut, cara penulisan mana yang lebih mudah untuk dimengerti??
# ```python
# # Ilustrasi `method chaining` 1 baris
# df_titanic['Name'].loc[~filter_comma].apply(lambda name: ", ".join(name.split(" ", maxsplit=1)))
#
# # Ilustrasi `method chaining` terpotong-potong
# (
#   df_titanic['Name']
#   .loc[~filter_comma]
#   .apply(lambda name: ", ".join(name.split(" ", maxsplit=1))))
# ```
#
# > *Accessor* `loc` sangat berguna dalam proses *data handling*, terutama pada saat melakukan perubahan `value` pada `row` dan `kolom` tertentu.
#
# ```python
# # Merubah nilai pada row dan kolom tertentu
# df.loc[<row_index|row_filter>, <nama_kolom>] = <Nilai pengganti>
# ```
# ___

# %% [markdown]
# 2. Standardizing title: turn all `Col` into `Colonel`

# %%
# Cek rows yang mengandung karakter 'Col` dan 'Colonel'
# 1. Set pattern
pattern_col_or_colonel = r"\b(Col|Colonel)\b"

# 2. Buat filter
filter_col_colonel = (               # Assign ke variabel filter_for_colonel
    df_titanic['Name']               # Values pada kolom 'Name' yang
    .str                             # diolah menggunakan operasi `string`
    .contains(                       # menggunakan method `contains` untuk memverifikasi
        pat=pattern_col_or_colonel,  # apakah mengandung pattern_col_or_colonel atau tidak
        regex=True,                  # set parameter pattern_col_or_colonel sebagai `regex`
        na=False)                    # set argumen na dengan parameter False
)

# 3. Sortir dataframe menggunakan filter yang sudah dibuat
df_titanic.loc[filter_col_colonel, :]
# Out:
# <ipython-input-50-0ee1c4d309e7>:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_titanic['Name']               # Values pada kolom 'Name' yang
#                                   Name PClass   Age   Sex  Survived  SexCode
# rownames
# 11           Astor, Colonel John Jacob    1st  47.0  male         0        0
# 121       Gracie, Colonel Archibald IV    1st  54.0  male         1        0
# 232        Simonius-Blumer, Col Alfons    1st  56.0  male         1        0
# 273                     Weir, Col John    1st  60.0  male         0        0

# %% [markdown]
# ___
# **TECHNICAL NOTE**
#
# Proses manipulasi pengubahan karakter ini akan menerapkan proses yang sedikit berbeda dengan sebelumnya, ketika dilakukan dengan menggunakan software spreadsheet, biasanya kita akan menerapkan algoritma sebagai berikut:
# 1. Ambil semua elemen dari kolom yang akan di manipulasi, lalu assign kepadanya hasil pengolahan;
# 2. Proses pengolahan:
#   - Cek satu persatu elemen, apakah mengandung karakter yang akan dirubah atau tidak;
#   - Lakukan perubahan ke setiap elemen yang mengandung karakter tersebut.
# ___

# %%
# Mengganti setiap title `Col' menjadi 'Colonel'
df_titanic['Name'] = (    # Assign ke kolom 'Name':
    df_titanic['Name']    # Values dari kolom 'Name'
    .str                  # yang diolah menggunakan operasi `string`
    .replace(             # menggunakan method `replace` untuk mengganti
        "\\bCol\\b",      # setiap rangkaian string 'Col'
        "Colonel",        # dengan rangkaian string 'Colonel'
        regex=True))

# %%
# Cek hasil penyeragaman
df_titanic.loc[filter_col_colonel, :]
# Out:
#                                      Name PClass   Age   Sex  Survived  \
# rownames
# 11              Astor, Colonel John Jacob    1st  47.0  male         0
# 121          Gracie, Colonel Archibald IV    1st  54.0  male         1
# 232       Simonius-Blumer, Colonel Alfons    1st  56.0  male         1
# 273                    Weir, Colonel John    1st  60.0  male         0
#
#           SexCode
# rownames
# 11              0
# 121             0
# 232             0
# 273             0

# %% [markdown]
# ### Splitting `Name` Values
# 1. Surname from `Name`

# %%
# Cek semua values pada kolom Name
df_titanic['Name'].head()
# Out:
# rownames
# 1                     Allen, Miss Elisabeth Walton
# 2                      Allison, Miss Helen Loraine
# 3              Allison, Mr Hudson Joshua Creighton
# 4    Allison, Mrs Hudson JC (Bessie Waldo Daniels)
# 5                    Allison, Master Hudson Trevor
# Name: Name, dtype: object

# %% [markdown]
# **TECHNICAL NOTE**
#
# Untuk melakukan manipulasi pemisahan values pada elemen nama ini, maka kita akan melakukan proses dengan algoritma sebagai berikut:
# 1. Buat sebuah dataframe baru berisikan data hasil manipulasi;
# 2. Proses manipulasi:
#   - Ambil seluruh elemen pada kolom `Name` pada `df_titanic`;
#   - Lakukan proses `string` menggunakan method split;
#   - Lakukan penyesuaian nama kolom

# %%
# Split values pada Name dengan comma
df_passenger_names = (                               # Assign ke `df_passenger_names` dataframe yang dihasilkan dari:
    df_titanic['Name']                               # Series berisi value kolom `Name` pada df_titanic yang
    .str                                             # diolah menggunakan operasi `string` dengan
    .split(                                          # menggunakan method `split`
        pat=", ",                                    # untuk memecah value pada series berdasarkan karakter ', '
        n=1,                                         # sebanyak 1 kali
        expand=True)                                 # dimana hasilnya diexpand menjadi DataFrame tersendiri
    .rename(                                         # lalu dilanjut dengan method 'rename'
        columns={0:'Surname', 1:'Firstname'})        # untuk merubah nama kolom 0 dan 1 menjadi `Surname` dan `Firstname`
)
df_passenger_names
# Out:
#             Surname                             Firstname
# rownames
# 1             Allen                 Miss Elisabeth Walton
# 2           Allison                    Miss Helen Loraine
# 3           Allison            Mr Hudson Joshua Creighton
# 4           Allison  Mrs Hudson JC (Bessie Waldo Daniels)
# 5           Allison                  Master Hudson Trevor
# ...             ...                                   ...
# 1309       Zakarian                              Mr Artun
# 1310       Zakarian                          Mr Maprieder
# 1311          Zenni                             Mr Philip
# 1312        Lievens                               Mr Rene
# 1313      Zimmerman                                   Leo
#
# [1313 rows x 2 columns]

# %% [markdown]
# ### Extracting Title from `Firstname`

# %%
title_pattern
# Out:
# '\\b(Mr|Mrs|Miss|Master|Colonel|Dr|Major|Captain|Madame|Sir|Lady|Jonkheer|the Countess of|Col|Ms|Mlle|Rev)\\b'

# %% [markdown]
# **TECHNICAL NOTE**
#
# Untuk memisahkan Title dari elemen pada kolom `Firstname`, maka kita akan memanfaatkan hasil pengumpulan pattern Title, `title_pattern`, yang sudah kita lakukan sebelumnya. Adapun algoritma pengerjaannya adalah sebagai berikut:
# 1. Buat kolom baru bernama `Title` pada `df_passenger` yang diisikan data hasil manipulasi;
# 2. Proses manipulasi:
#   - Ambil seluruh elemen pada kolom `Firstname` pada `df_passsenger_name`;
#   - Lakukan proses `string` dengan method `extract`, menggunakan `title_pattern` sebagai argumen bagi parameter `pat`;

# %%
# Extrak Title dari value pada kolom `Firstname` simpan ke kolom baru `Title`
df_passenger_names['Title'] = (       # Buat kolom baru bernama `Title` pada `df_passenger_names` untuk diassign:
    df_passenger_names['Firstname']   # Series berisi Values dari kolom 'Firstname' pada df_passenger_names yang
    .str                              # diolah menggunakan operasi `string` dengan
    .extract(                         # menggunakan method `extract` untuk
        pat=title_pattern)            # mengambil karakter pada value yang sesuai dengan `title_pattern`
)

df_passenger_names.head()
# Out:
#           Surname                             Firstname   Title
# rownames
# 1           Allen                 Miss Elisabeth Walton    Miss
# 2         Allison                    Miss Helen Loraine    Miss
# 3         Allison            Mr Hudson Joshua Creighton      Mr
# 4         Allison  Mrs Hudson JC (Bessie Waldo Daniels)     Mrs
# 5         Allison                  Master Hudson Trevor  Master

# %% [markdown]
# #### Omitting Title from `Firstname`'s values

# %%
# Cek Kondisi penulisan `Firstname`
df_passenger_names.head()
# Out:
#           Surname                             Firstname   Title
# rownames
# 1           Allen                 Miss Elisabeth Walton    Miss
# 2         Allison                    Miss Helen Loraine    Miss
# 3         Allison            Mr Hudson Joshua Creighton      Mr
# 4         Allison  Mrs Hudson JC (Bessie Waldo Daniels)     Mrs
# 5         Allison                  Master Hudson Trevor  Master

# %%
# Penghapusan pattern Title dari value pada `Firstname`
df_passenger_names['Firstname'] = (      # Assign ke ...... values yang dihasilkan dari:
    df_passenger_names['Firstname']      # Olahan dari .....
    .str                                 # dengan operasi .....
    .replace(                            # menggunakan method .....
        f"{title_pattern}",        # untuk mengubah .....
        "",                              # menjadi .....
        regex=True)                      # set parameter ..... dengan argumen .....
    .str                                 # lalu olah lebih lanjut dengan operasi .....
    .strip()                             # menggunakan metode ..... untuk .....
)

# Cek 5 rows teratas dari hasil olahan
df_passenger_names.head()
# Out:
#           Surname                         Firstname   Title
# rownames
# 1           Allen                  Elisabeth Walton    Miss
# 2         Allison                     Helen Loraine    Miss
# 3         Allison           Hudson Joshua Creighton      Mr
# 4         Allison  Hudson JC (Bessie Waldo Daniels)     Mrs
# 5         Allison                     Hudson Trevor  Master

# %% [markdown]
# #### Joining Two DataFrames

# %%
df_titanic.head()
# Out:
#                                                    Name PClass    Age     Sex  \
# rownames
# 1                          Allen, Miss Elisabeth Walton    1st  29.00  female
# 2                           Allison, Miss Helen Loraine    1st   2.00  female
# 3                   Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 4         Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 5                         Allison, Master Hudson Trevor    1st   0.92    male
#
#           Survived  SexCode
# rownames
# 1                1        1
# 2                0        1
# 3                0        0
# 4                0        1
# 5                1        0

# %%
df_passenger_names.head()
# Out:
#           Surname                         Firstname   Title
# rownames
# 1           Allen                  Elisabeth Walton    Miss
# 2         Allison                     Helen Loraine    Miss
# 3         Allison           Hudson Joshua Creighton      Mr
# 4         Allison  Hudson JC (Bessie Waldo Daniels)     Mrs
# 5         Allison                     Hudson Trevor  Master

# %%
# 1. Buat list kolom yang diperlukan
final_columns_list = ['Title', 'Firstname', 'Surname', 'PClass', 'Age', 'Survived', 'SexCode']

# 2. Gabungkan df_titanic, dengan df_passenger_names berdasarkan indeksnya
df_titanic_all = (
    df_titanic
    .join(df_passenger_names, how='left')
    .loc[:, final_columns_list]
)

# Cek Visual hasil penggabungan
df_titanic_all.head()
# Out:
#            Title                         Firstname  Surname PClass    Age  \
# rownames
# 1           Miss                  Elisabeth Walton    Allen    1st  29.00
# 2           Miss                     Helen Loraine  Allison    1st   2.00
# 3             Mr           Hudson Joshua Creighton  Allison    1st  30.00
# 4            Mrs  Hudson JC (Bessie Waldo Daniels)  Allison    1st  25.00
# 5         Master                     Hudson Trevor  Allison    1st   0.92
#
#           Survived  SexCode
# rownames
# 1                1        1
# 2                0        1
# 3                0        0
# 4                0        1
# 5                1        0

# %%
df_titanic_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1313 entries, 1 to 1313
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1294 non-null   object
#  1   Firstname  1313 non-null   object
#  2   Surname    1313 non-null   object
#  3   PClass     1313 non-null   object
#  4   Age        756 non-null    float64
#  5   Survived   1313 non-null   int64
#  6   SexCode    1313 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 114.4+ KB

# %% [markdown]
# ---
# **TECHNICAL NOTE**
#
# Modul `pandas` menyediakan beberapa metode untuk menggabungkan beberapa *dataframe*, yang berguna dalam pengolahan data saat informasi yang kita perlukan tersebar di berbagai sumber. Penggabungan data dapat dilakukan berdasarkan berbagai kondisi seperti kesamaan kolom, posisi indeks, atau penyambungan secara vertikal/horizontal. Tiga metode utama yang disediakan oleh `pandas` adalah:
#
# a. `pd.DataFrame.merge`<br>
# [`merge`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) digunakan untuk menggabungkan dua *dataframe* dengan cara yang mirip dengan operasi `JOIN` pada SQL. Kita dapat menyatukan dua tabel berdasarkan satu atau beberapa kolom yang memiliki nilai kunci yang sama di kedua tabel.
#
# **Contoh Penggunaan**:
#   ```python
#   df_merged = df1.merge(df2, left_on='key_column', right_on='key_column', how='inner')
#   ```
#   - `left_on='key_column'`: Kolom yang menjadi dasar penggabungan di df1 (dataframe kiri).
#   - `right_on='key_column'`: Kolom yang menjadi dasar penggabungan di df2 (dataframe kanan).
#   - `how='inner'`: Tipe penggabungan (`'inner'`, `'left'`, `'right'`, `'outer'`).
#     - `'inner'`: Hanya menggabungkan baris yang memiliki kunci yang sama di kedua *dataframe*.
#     - `'left'`: Semua baris dari *dataframe* kiri, dan baris yang cocok dari *dataframe* kanan.
#     - `'right'`: Semua baris dari *dataframe* kanan, dan baris yang cocok dari *dataframe* kiri.
#     - `'outer'`: Semua baris dari kedua *dataframe*, baik yang cocok maupun yang tidak.
#
#   `merge` sangat fleksibel dan memungkinkan penggunaan multi-key joins serta penggabungan dengan kolom yang bernama berbeda.
#
# b. `pd.DataFrame.join`<br>
# [`join`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) digunakan untuk menggabungkan *dataframe* berdasarkan indeks. Jika kita memiliki dua tabel yang memiliki struktur indeks yang sama, kita dapat menyatukan data berdasarkan indeks tersebut.
#
# **Contoh Penggunaan**:
# ```python
# df_joined = df1.join(df2, how='left')
# ```
# - `how='left'`: Penggabungan tipe `'left'` berdasarkan indeks yang serupa pada kedua *dataframe*.
#
# `join` biasanya lebih sederhana digunakan jika kita sudah memiliki indeks yang tepat pada kedua tabel, dan lebih cocok untuk data dengan relasi berbasis indeks.
#
# c. `pd.concat`<br>
# [`concat`](https://pandas.pydata.org/docs/reference/api/pandas.concat.html) digunakan untuk menggabungkan beberapa *dataframe* secara vertikal (penambahan baris) atau horizontal (penambahan kolom), tanpa membutuhkan kesamaan kunci atau indeks.
#
# **Contoh Penggunaan**:
# ```python
# df_concatenated = pd.concat([df1, df2], axis=0, ignore_index=True)
# ```
# - `axis=0`: Menyambung baris (*stacking* data secara vertikal).
# - `axis=1`: Menyambung kolom (*side-by-side* data secara horizontal).
# - `ignore_index=True`: Mengatur ulang indeks pada *dataframe* yang digabungkan.
#
# `concat` memungkinkan kita untuk menggabungkan lebih dari dua *dataframe* sekaligus, dan sering digunakan untuk menggabungkan data yang terpisah dalam beberapa bagian atau jika kita ingin menggabungkan data tanpa syarat kesamaan kunci.
#
# ---

# %% [markdown]
# ### Handling Missing Values
# #### Imputations for Title Values

# %%
# Cek struktur dari dataframe
df_titanic_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1313 entries, 1 to 1313
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1294 non-null   object
#  1   Firstname  1313 non-null   object
#  2   Surname    1313 non-null   object
#  3   PClass     1313 non-null   object
#  4   Age        756 non-null    float64
#  5   Survived   1313 non-null   int64
#  6   SexCode    1313 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 114.4+ KB

# %%
# Cek rows dengan missing Title Value
no_title = df_titanic_all.loc[df_titanic_all['Title'].isna(), :]

no_title
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, Surname, PClass, Age, Survived, SexCode]
# Index: []

# %%
# Mengisi missing Title values orang dewasa berjenis kelamin 1 dengan 'Ms'
df_titanic_all.loc[[861, 864, 865], ['Title']]='Ms'

# Mengisi missing Title values Bagi Anak-anak berjenis kelamin 0
df_titanic_all.loc[1180, ['Title']]='Master'

# Mengisi missing Title values orang dewasa berjenis kelamin 0
df_titanic_all.loc[df_titanic_all['Title'].isna(), ['Title']] = 'Mr'

# %%
# Cek apakah masih ada missing values pada kolom 'Title'
df_titanic_all.loc[df_titanic_all['Title'].isna(), :]
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, Surname, PClass, Age, Survived, SexCode]
# Index: []

# %%
df_titanic_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1313 entries, 1 to 1313
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1313 non-null   object
#  1   Firstname  1313 non-null   object
#  2   Surname    1313 non-null   object
#  3   PClass     1313 non-null   object
#  4   Age        756 non-null    float64
#  5   Survived   1313 non-null   int64
#  6   SexCode    1313 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 114.4+ KB

# %%
all_titles = df_titanic_all['Title'].unique()
all_titles
# Out:
# array(['Miss', 'Mr', 'Mrs', 'Master', 'Colonel', 'Dr', 'Major', 'Captain',
#        'Madame', 'Sir', 'Lady', 'Jonkheer', 'the Countess of', 'Ms',
#        'Mlle', 'Rev'], dtype=object)

# %% [markdown]
# #### Age Values

# %%
# Check Kondisi missing value masing-masing Title
(df_titanic_all.groupby('Title')
.agg({'Age':'count', 'Firstname':'count'})
.assign(MissingValues=lambda df: df['Firstname']-df['Age']))
# Out:
#                  Age  Firstname  MissingValues
# Title
# Captain            1          1              0
# Colonel            4          4              0
# Dr                 5          8              3
# Jonkheer           0          1              1
# Lady               1          1              0
# Madame             0          1              1
# Major              2          2              0
# Master            33         61             28
# Miss             145        236             91
# Mlle               0          2              2
# Mr               416        766            350
# Mrs              139        200             61
# Ms                 2         20             18
# Rev                6          8              2
# Sir                1          1              0
# the Countess of    1          1              0

# %% [markdown]
# ##### Imputation secara Statistik
#
# 1. Cek Sebaran Data untuk kelompok Title Mr

# %%
# Melihat sebaran value Age untuk kelompok ber-Title 'Mr'
dataframe = df_titanic_all.loc[df_titanic_all['Title']=='Mr', :]
print(f"{'':=^50}\n\tMISSING VALUES:\n\r", dataframe.isna().sum())
print(f"{'':=^50}\n\tDESCRIPTIVE STATISTICS:\n\r", dataframe['Age'].describe())
print(f"{'':=^50}\n\tSEBARAN DATA:\n")
dataframe['Age'].plot.hist(bins=10)
# Out:
# ==================================================
# 	MISSING VALUES:
#  Title        0
# Firstname    0
# Surname      0
# PClass       0
# Age          0
# Survived     0
# SexCode      0
# dtype: int64
# ==================================================
# 	DESCRIPTIVE STATISTICS:
#  count    766.000000
# mean      31.071802
# std        8.999604
# min       14.000000
# 25%       28.000000
# 50%       29.500000
# 75%       30.000000
# max       71.000000
# Name: Age, dtype: float64
# ==================================================
# 	SEBARAN DATA:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 2. Isi Missing Value kolom `Age` bagi rows ber `Title`=='Mr' dengan median bagi `Age` di kelompok 'Mr'

# %%
# Mengisi missing Age value Untuk Kelompok bertitel Mr
df_titanic_all.loc[
    (df_titanic_all['Title']=='Mr') &
    (df_titanic_all['Age'].isna()),
    ['Age']
] = (df_titanic_all
     .loc[
         df_titanic_all['Title']=='Mr',
         :
     ]['Age']
     .median())

# %% [markdown]
# 3. Melakukan imputation menggunakan users' defined function

# %%
# Import fungsi handling_missing_value dari modul functions
from functions import handling_missing_value

# %%
help(handling_missing_value)
# Out:
# Help on function handling_missing_value in module functions:
#
# handling_missing_value(df: pandas.core.frame.DataFrame, kolom_filter: str, kolom_nilai: str, pattern: str, bins: int = 10) -> None
#     Fungsi untuk mengeksplorasi pola dari data pada kolom tertentu:
#     1. Missing Values pada kolom dengan filter pattern;
#     2. Statistik Deskriptif dari kolom nilai dengan filter pattern;
#     3. Histogram sederhana.
#
#     ARGUMEN:
#         - df: pd.DataFrame, DataFrame yang berisi data;
#         - kolom_filter: str, nama kolom yang akan difilter berdasarkan pattern;
#         - kolom_nilai: str, nama kolom yang nilainya akan dianalisis;
#         - pattern: str, pattern yang dicari dalam kolom_filter;
#         - bins: int, jumlah bins untuk histogram.

# %%
# Handling missing value pada Age untuk Title=='Mrs'
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Mrs')
# Out:
# ==================================================================
#                    MISSING VALUES KELOMPOK Mrs:
# ------------------------------------------------------------------
# Title         0
# Firstname     0
# Surname       0
# PClass        0
# Age          61
# Survived      0
# SexCode       0
# dtype: int64
# ==================================================================
#                DESCRIPTIVE STATS Age KELOMPOK Mrs:
# ------------------------------------------------------------------
# count    139.000000
# mean      37.561151
# std       12.792160
# min       15.000000
# 25%       27.000000
# 50%       36.000000
# 75%       47.000000
# max       69.000000
# Name: Age, dtype: float64
# ==================================================================
#                   SEBARAN DATA Age KELOMPOK Mrs:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 1

# %%
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Rev')
# Out:
# ==================================================================
#                    MISSING VALUES KELOMPOK Rev:
# ------------------------------------------------------------------
# Title        0
# Firstname    0
# Surname      0
# PClass       0
# Age          2
# Survived     0
# SexCode      0
# dtype: int64
# ==================================================================
#                DESCRIPTIVE STATS Age KELOMPOK Rev:
# ------------------------------------------------------------------
# count     6.000000
# mean     38.333333
# std      11.944315
# min      27.000000
# 25%      28.500000
# 50%      35.000000
# 75%      48.250000
# max      54.000000
# Name: Age, dtype: float64
# ==================================================================
#                   SEBARAN DATA Age KELOMPOK Rev:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 2

# %%
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Dr')
# Out:
# ==================================================================
#                    MISSING VALUES KELOMPOK Dr:
# ------------------------------------------------------------------
# Title        0
# Firstname    0
# Surname      0
# PClass       0
# Age          3
# Survived     0
# SexCode      0
# dtype: int64
# ==================================================================
#                 DESCRIPTIVE STATS Age KELOMPOK Dr:
# ------------------------------------------------------------------
# count     5.00000
# mean     40.60000
# std      12.36123
# min      24.00000
# 25%      32.00000
# 50%      44.00000
# 75%      49.00000
# max      54.00000
# Name: Age, dtype: float64
# ==================================================================
#                   SEBARAN DATA Age KELOMPOK Dr:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 1

# %%
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Ms')
# Out:
# ==================================================================
#                    MISSING VALUES KELOMPOK Ms:
# ------------------------------------------------------------------
# Title         0
# Firstname     0
# Surname       0
# PClass        0
# Age          18
# Survived      0
# SexCode       0
# dtype: int64
# ==================================================================
#                 DESCRIPTIVE STATS Age KELOMPOK Ms:
# ------------------------------------------------------------------
# count     2.000000
# mean     25.000000
# std       4.242641
# min      22.000000
# 25%      23.500000
# 50%      25.000000
# 75%      26.500000
# max      28.000000
# Name: Age, dtype: float64
# ==================================================================
#                   SEBARAN DATA Age KELOMPOK Ms:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 1

# %%
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Master')
# Out:
# ==================================================================
#                  MISSING VALUES KELOMPOK Master:
# ------------------------------------------------------------------
# Title         0
# Firstname     0
# Surname       0
# PClass        0
# Age          28
# Survived      0
# SexCode       0
# dtype: int64
# ==================================================================
#               DESCRIPTIVE STATS Age KELOMPOK Master:
# ------------------------------------------------------------------
# count    33.000000
# mean      5.233636
# std       4.077652
# min       0.330000
# 25%       2.000000
# 50%       4.000000
# 75%       9.000000
# max      13.000000
# Name: Age, dtype: float64
# ==================================================================
#                 SEBARAN DATA Age KELOMPOK Master:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 2

# %%
handling_missing_value(df_titanic_all, 'Title', 'Age', 'Miss')
# Out:
# ==================================================================
#                   MISSING VALUES KELOMPOK Miss:
# ------------------------------------------------------------------
# Title         0
# Firstname     0
# Surname       0
# PClass        0
# Age          91
# Survived      0
# SexCode       0
# dtype: int64
# ==================================================================
#                DESCRIPTIVE STATS Age KELOMPOK Miss:
# ------------------------------------------------------------------
# count    145.000000
# mean      21.518414
# std       12.169640
# min        0.170000
# 25%       16.000000
# 50%       21.000000
# 75%       27.000000
# max       63.000000
# Name: Age, dtype: float64
# ==================================================================
#                  SEBARAN DATA Age KELOMPOK Miss:
# ------------------------------------------------------------------
# ==================================================================
#                    HANDLING MISSING Age VALUES:
# ------------------------------------------------------------------
#
# Pilih metode pengisian missing value: 1=Mean, 2=Median 2

# %% [markdown]
# ##### Imputation menggunakan accessor `.loc`

# %%
# Handling missing value pada Age untuk Title=='Jonkheer'
(df_titanic_all
 .loc[
     df_titanic_all['Title']=='Jonkheer',
      ['Age']]) = (df_titanic_all
                   .loc[
                       df_titanic_all['Title']=='Mr',
                        ['Age']]['Age'].mean())

# %%
# Handling missing value pada Age untuk Title=='Madame' & 'Mlle'
(df_titanic_all
 .loc[
     df_titanic_all['Title']
     .isin(['Madame', 'Mlle']),
      ['Age']]) = (df_titanic_all
                   .loc[
                       df_titanic_all['Title']
                       .isin(['Mrs', 'Ms']),
                        ['Age']]['Age'].mean())

# %%
df_titanic_all
# Out:
#            Title                         Firstname    Surname PClass    Age  \
# rownames
# 1           Miss                  Elisabeth Walton      Allen    1st  29.00
# 2           Miss                     Helen Loraine    Allison    1st   2.00
# 3             Mr           Hudson Joshua Creighton    Allison    1st  30.00
# 4            Mrs  Hudson JC (Bessie Waldo Daniels)    Allison    1st  25.00
# 5         Master                     Hudson Trevor    Allison    1st   0.92
# ...          ...                               ...        ...    ...    ...
# 1309          Mr                             Artun   Zakarian    3rd  27.00
# 1310          Mr                         Maprieder   Zakarian    3rd  26.00
# 1311          Mr                            Philip      Zenni    3rd  22.00
# 1312          Mr                              Rene    Lievens    3rd  24.00
# 1313          Mr                               Leo  Zimmerman    3rd  29.00
#
#           Survived  SexCode
# rownames
# 1                1        1
# 2                0        1
# 3                0        0
# 4                0        1
# 5                1        0
# ...            ...      ...
# 1309             0        0
# 1310             0        0
# 1311             0        0
# 1312             0        0
# 1313             0        0
#
# [1313 rows x 7 columns]

# %% [markdown]
# ## Menghitung Survival Rate Penumpang MS. Titanic

# %%
# Total Survival Rate
(df_titanic_all
 .agg({'Survived':'sum'}))/(df_titanic_all.agg({'Survived':'count'}))*100
# Out:
# Survived    34.272658
# dtype: float64

# %%
# Survival Rate by SexCode
(df_titanic_all.groupby('SexCode')
.agg({'Survived':['sum', 'count']})
.pipe(lambda df: df.set_axis(['Survivors', 'Passengers'], axis=1))
.assign(SurvivalRate= lambda df: round(df['Survivors']/df['Passengers']*100, 2))
)
# Out:
#          Survivors  Passengers  SurvivalRate
# SexCode
# 0              142         851         16.69
# 1              308         462         66.67

# %%
# Survival Rate by SexCode, PClass
(df_titanic_all.groupby(['SexCode', 'PClass'])
.agg({'Survived':['sum', 'count']})
.pipe(lambda df: df.set_axis(['Survivors', 'Passengers'], axis=1))
.assign(SurvivalRate= lambda df: round(df['Survivors']/df['Passengers']*100, 2)))
# Out:
#                 Survivors  Passengers  SurvivalRate
# SexCode PClass
# 0       *               0           1          0.00
#         1st            59         179         32.96
#         2nd            25         172         14.53
#         3rd            58         499         11.62
# 1       1st           134         143         93.71
#         2nd            94         107         87.85
#         3rd            80         212         37.74

# %%
# Survival Rate by SexCode, Title, PClass
(df_titanic_all.groupby(['SexCode', 'Title', 'PClass'])
.agg({'Survived':['sum', 'count']})
.pipe(lambda df: df.set_axis(['Survivors', 'Passengers'], axis=1))
.assign(SurvivalRate= lambda df: round(df['Survivors']/df['Passengers']*100, 2)))
# Out:
#                                 Survivors  Passengers  SurvivalRate
# SexCode Title           PClass
# 0       Captain         1st             0           1          0.00
#         Colonel         1st             2           4         50.00
#         Dr              1st             3           5         60.00
#                         2nd             0           2          0.00
#         Jonkheer        1st             0           1          0.00
#         Major           1st             1           2         50.00
#         Master          1st             5           5        100.00
#                         2nd            11          11        100.00
#                         3rd             7          45         15.56
#         Mr              *               0           1          0.00
#                         1st            47         160         29.38
#                         2nd            14         151          9.27
#                         3rd            51         454         11.23
#         Rev             2nd             0           8          0.00
#         Sir             1st             1           1        100.00
# 1       Dr              1st             1           1        100.00
#         Lady            1st             1           1        100.00
#         Madame          1st             1           1        100.00
#         Miss            1st            39          42         92.86
#                         2nd            47          50         94.00
#                         3rd            53         144         36.81
#         Mlle            1st             1           2         50.00
#         Mrs             1st            76          78         97.44
#                         2nd            47          57         82.46
#                         3rd            26          65         40.00
#         Ms              1st            14          17         82.35
#                         3rd             1           3         33.33
#         the Countess of 1st             1           1        100.00

# %%
# Memperoleh informasi apakah seseorang itu travelling sendiri atau bersama keluarga
# Kriteria seseorang Solo VS With Family adalah travelling lebih dari 1 pada kelas yang sama
family_or_solo_passengers = (
    df_titanic_all.groupby(['PClass', 'Surname'])
     .agg({'Firstname':'count'})
     .rename(columns={'Firstname':'Travelling'})
     .assign(Travelling=lambda df: df['Travelling'].apply(lambda x: "Solo" if x==1 else 'With Family'))
     .reset_index()
)

# %%
family_or_solo_passengers
# Out:
#     PClass    Surname   Travelling
# 0        *  Jacobsohn         Solo
# 1      1st      Allen         Solo
# 2      1st    Allison  With Family
# 3      1st   Anderson         Solo
# 4      1st    Andrews  With Family
# ..     ...        ...          ...
# 906    3rd    Youssef         Solo
# 907    3rd     Zabour  With Family
# 908    3rd   Zakarian  With Family
# 909    3rd      Zenni         Solo
# 910    3rd  Zimmerman         Solo
#
# [911 rows x 3 columns]

# %%
# Gabungkan hasil olahan di atas dengan dataframe original
(df_titanic_all
 .merge(
     family_or_solo_passengers,
     left_on=['PClass', 'Surname'],
     right_on=['PClass', 'Surname'],
     how='left')
 .groupby(['Travelling', 'SexCode'])
 .agg({'Survived':['count', 'sum']})
 .pipe(lambda df: df.set_axis(['Passengers', 'Survivors'], axis=1))
 .assign(SurvivalRate=lambda df: round(df['Survivors']/df['Passengers']*100, 2))
)
# Out:
#                      Passengers  Survivors  SurvivalRate
# Travelling  SexCode
# Solo        0               504         78         15.48
#             1               180        123         68.33
# With Family 0               347         64         18.44
#             1               282        185         65.60

# %%
df_titanic_all.loc[df_titanic_all['Surname']=='Allen']
# Out:
#          Title         Firstname Surname PClass   Age  Survived  SexCode
# rownames
# 1         Miss  Elisabeth Walton   Allen    1st  29.0         1        1
# 621         Mr     William Henry   Allen    3rd  35.0         0        0

# %% [markdown]
# ___
