# %% [markdown]
# # *DATA MANIPULATION*
# > ***Data Manipulation*** merujuk kepada proses penyesuaian (*adjustments*) yang dilakukan terhadap data agar lebih terorganisir dan mudah dibaca.
#
# Dalam sebuah organisasi yang mengedepankan pengambilan keputusan berbasis data, maka ***Data Manipulation*** adalah sebuah proses penting yang harus dilakukan terhadap beragam data yang dimanfaatkan olehnya. Proses tersebut akan memastikan bahwa berbagai `datasets` yang tersedia selaras dengan kebutuhan organisasi, serta memiliki format dan struktur yang konsisten, sehingga meningkatkan efisiensi pada pelaksanaan berbagai proses penting seperti:
# 1. Pembacaan data;
# 2. Analisis data;
# 3. Interpretasi data; dan
# 4. Proyeksi data.
#
# Python adalah salah satu ***Data Manipulation Languange*** (**DML**) yang paling populer dipergunakan oleh para *data scientists*, *data analysts*, peneliti dan akademisi. Popularitas Python tersebut tak lepas dari tersedianya sebuah modul/library bernama `pandas`, yang menyediakan berbagai *toolkits* yang sangat handal untuk dimanfaatkan melakukan *handling* dan *manipulating* data yang terstruktur.
#
# Pada pertemuan sebelumnya, secara sekilas telah diperkenalkan beberapa `methods` dari `pandas` yang umumnya dipergunakan untuk tujuan `dataframe` construction. Beberapa methods tersebut antara lain:
# - `pandas.DataFrame()`, untuk mengkonversi berbagai objek python--`list`, `tuple`, dan `dictionary`--menjadi sebuah `pandas.dataframe`;
# - `pandas.read_csv()`, untuk parsing data pada file berekstensi `.csv` dan `.txt` ke sebuah `pandas.dataframe`;
# - `pandas.read_json()`, untuk parsing data pada file berekstensi `.json` ke sebuah `pandas.dataframe`; dan
# - `pandas.read_excel()`, untuk parsing data pada file berekstensi `.xls` dan `.xlsx` ke sebuah `pandas.dataframe`.
#
# Pertemuan kesepuluh ini secara khusus ditujukan untuk membahas pemanfaatan objek `pandas.dataframe` lebih jauh lagi. Pada pertemuan ini akan dipraktekan berbagai methods serta attributes dari `pandas.dataframe` yang dapat dimanfaatkan untuk melakukan ***Data Manipulation***.

# %% [markdown]
# # `Pandas Dataframe`
# > `Pandas Dataframe` adalah sebuah `objek` Python berstruktur data dua dimensional berupa `rows` dan `columns` yang masing-masingnya memiliki label unik.
#
# Sesuai dengan deskripsi di atas, secara visual, sebuah `Pandas Dataframe` memiliki struktur tabular. Serupa dengan tabel SQL pada sebuah *database*, atau sebuah *spreadsheet* pada sebuah file excel. Pada sebuah `pandas.dataframe`, terdapat dua elemen berupa:
# 1. `columns`, yang masing-masingnya merupakan objek satu dimensional--`pandas.series`--dan memiliki nomor/nama indeks yang unik.
# > Objek `pandas.series` memiliki karakteristik hampir serupa dengan sebuah `list` yang berisikan banyak elemen yang homogen, akan tetapi sebuah `pandas.series` memiliki cara indexing yang jauh lebih fleksibel dibandingkan `python fundamental objects`.
# 2. `rows`, yang merepresentasikan catatan data (*records*) dan berkarakter satu dimensional--`pandas.series`--yang masing-masing elemennya harus diberikan indeks (berupa nama kolom) yang unik.
# > `rows` memiliki karakteristik serupa dengan sebuah `dictionary` yang berisikan *paired-element* berupa `key` = `str` berupa nama kolom, dan `value` = `list` dengan elemen berupa data yang tersimpan pada kolom tersebut.

# %% [markdown]
# #### Ilustrasi 1: `.csv` Data Parsing
# Lakukan *data parsing* dari sebuah file `.csv` yang disimpan di: 'https://storage.googleapis.com/dqlab-dataset/SuperStore.csv'. Lakukan langkah-langkah berikut:
# 1. Import modul pandas lalu berikan alias `pd`;
# 2. Assign lokasi dari file ke `file_path`;
# 3. Parse data, dan assign ke `df_superstore`;
# 4. Tunjukkan isi dari dataframe tersebut;
# 5. *Slice* dataframe untuk hanya menunjukkan data kolom 'Sales` saja; dan
# 6. *Slice* dataframe untuk hanya menunjukkan data baris pertama hingga kelima saja.
#
# Lengkapi berbagai ekspresi yang tidak lengkap pada setiap *statement* di `code cells` di bawah, lalu jawab pertanyaan-pertanyaan berikut:
# - Berapa banyak `columns` yang terdapat pada dataframe tersebut?
# - Berapa banyak `rows` yang terdapat pada dataframe tersebut?
# - Tipe data apa yang disimpan dalam kolom `Sales`?

# %%
# Mengimpor modul pandas ke environment
import pandas as pd

# %%
# Assign lokasi file ke `file_path`
file_path = 'https://storage.googleapis.com/dqlab-dataset/SuperStore.csv'

# %%
# Parsing data dari file menjadi sebuah dataframe `df_superstore`
df_superstore = pd.read_csv(file_path)

# %%
# Tunjukkan isi dataframe
df_superstore
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2     CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4     US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# ...              ...         ...          ...              ...       ...
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.6000
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.1600
#
#       Quantity  Discount    Profit         Category Sub-Category  \
# 0            2      0.00   41.9136        Furniture    Bookcases
# 1            3      0.00  219.5820        Furniture       Chairs
# 2            2      0.00    6.8714  Office Supplies       Labels
# 3            5      0.45 -383.0310        Furniture       Tables
# 4            2      0.20    2.5164  Office Supplies      Storage
# ...        ...       ...       ...              ...          ...
# 9989         3      0.20    4.1028        Furniture  Furnishings
# 9990         2      0.00   15.6332        Furniture  Furnishings
# 9991         2      0.20   19.3932       Technology       Phones
# 9992         4      0.00   13.3200  Office Supplies        Paper
# 9993         2      0.00   72.9480  Office Supplies   Appliances
#
#                                            Product_Name  Order_Date  \
# 0                     Bush Somerset Collection Bookcase   11/8/2019
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...   11/8/2019
# 2     Self-Adhesive Address Labels for Typewriters b...   6/12/2019
# 3         Bretford CR4500 Series Slim Rectangular Table  10/11/2018
# 4                        Eldon Fold 'N Roll Cart System  10/11/2018
# ...                                                 ...         ...
# 9989                             Ultra Door Pull Handle   1/21/2017
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   2/26/2020
# 9991                              Aastra 57i VoIP phone   2/26/2020
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   2/26/2020
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...    5/4/2020
#
#        Ship_Date       Ship_Mode     Customer_Name    Segment Country/Region  \
# 0     11/11/2019    Second Class       Claire Gute   Consumer  United States
# 1     11/11/2019    Second Class       Claire Gute   Consumer  United States
# 2      6/16/2019    Second Class   Darrin Van Huff  Corporate  United States
# 3     10/18/2018  Standard Class    Sean O'Donnell   Consumer  United States
# 4     10/18/2018  Standard Class    Sean O'Donnell   Consumer  United States
# ...          ...             ...               ...        ...            ...
# 9989   1/23/2017    Second Class  Tom Boeckenhauer   Consumer  United States
# 9990    3/3/2020  Standard Class       Dave Brooks   Consumer  United States
# 9991    3/3/2020  Standard Class       Dave Brooks   Consumer  United States
# 9992    3/3/2020  Standard Class       Dave Brooks   Consumer  United States
# 9993    5/9/2020    Second Class      Chris Cortes   Consumer  United States
#
#                  City       State Region
# 0           Henderson    Kentucky  South
# 1           Henderson    Kentucky  South
# 2         Los Angeles  California   West
# 3     Fort Lauderdale     Florida  South
# 4     Fort Lauderdale     Florida  South
# ...               ...         ...    ...
# 9989            Miami     Florida  South
# 9990       Costa Mesa  California   West
# 9991       Costa Mesa  California   West
# 9992       Costa Mesa  California   West
# 9993      Westminster  California   West
#
# [9994 rows x 20 columns]

# %%
# Mengakses isi dari kolom 'Sales'
df_superstore['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
# Tunjukkan row pertama hingga kelima dari df_superstore
df_superstore[0:5]
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
#
#                                         Product_Name  Order_Date   Ship_Date  \
# 0                  Bush Somerset Collection Bookcase   11/8/2019  11/11/2019
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   11/8/2019  11/11/2019
# 2  Self-Adhesive Address Labels for Typewriters b...   6/12/2019   6/16/2019
# 3      Bretford CR4500 Series Slim Rectangular Table  10/11/2018  10/18/2018
# 4                     Eldon Fold 'N Roll Cart System  10/11/2018  10/18/2018
#
#         Ship_Mode    Customer_Name    Segment Country/Region             City  \
# 0    Second Class      Claire Gute   Consumer  United States        Henderson
# 1    Second Class      Claire Gute   Consumer  United States        Henderson
# 2    Second Class  Darrin Van Huff  Corporate  United States      Los Angeles
# 3  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State Region
# 0    Kentucky  South
# 1    Kentucky  South
# 2  California   West
# 3     Florida  South
# 4     Florida  South

# %% [markdown]
# ## EXERCISE 1

# %%
# Tunjukkan isi row pertama hingga ketiga dari df_superstore,
# khusus untuk kolom `Order_ID` dan `Sales` saja
df_superstore[0:3][['Order_ID', 'Sales']]
# Out:
#          Order_ID   Sales
# 0  CA-2019-152156  261.96
# 1  CA-2019-152156  731.94
# 2  CA-2019-138688   14.62

# %% [markdown]
# #### Ilustrasi 2: `pandas.dataframe` VS `pandas.series`
# Lengkapi setiap ekspresi yang tidak lengkap agar `code cells` di bawah dapat dieksekusi, lalu jawab pertanyaan-pertanyaan berikut:
# 1. Apa kelas objek dari `df_superstore`?
# 2. Apa kelas objek dari `df_superstore['Sales']`?
# 3. Apa kelas objek dari `df_superstore[0:5]`?
# 4. Apa kelas objek dari `df_superstore[['Order_ID', 'Sales']]`?
# 5. Apa perbedaan antara sebuah `DataFrame` dan `Series`??

# %%
# Gunakan fungsi `type()` untuk mengidentifikasi tipe object df_superstore
print(type(df_superstore))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Gunakan fungsi `type()` untuk mengidentifikasi tipe object df_superstore['Sales']
print(type(df_superstore['Sales']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Gunakan fungsi `type()` untuk mengidentifikasi tipe object df_superstore[0:5]
print(type(df_superstore[0:5]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Gunakan fungsi `type()` untuk mengidentifikasi tipe object df_superstore[['Order_ID', 'Sales']]
print(type(df_superstore[['Order_ID', 'Sales']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # *Data Description*
# > `Attributes` VS `Methods`
# > - `Attributes` adalah berbagai karakteristik yang terdapat pada sebuah objek;
# > - `Methods` adalah berbagai fungsi yang dapat diterapkan kepada sebuah objek.
#
# Oleh karena pada prinsipnya `pandas.dataframe` adalah sebuah objek python, maka sudah barang tentu ia akan memiliki `attributes` dan juga `methods`. Dua ilustrasi pada bagian ini akan mencontohkan bagaimana penerapan baik `attributes` maupun `methods` dari `pandas.dataframe` dalam proses mendeskripsikan data.

# %% [markdown]
# #### Ilustrasi 3: `pandas.dataframe` attributes
# Eksekusi beberapa attributes di bawah berikut, lalu tuliskan jawaban beberapa pertanyaan di bawah ini pada `markdown cell` yang disediakan:
# - Apa perbedaan dari `pd.dataframe.ndim`, `pd.dataframe.shape`, dan `pd.dataframe.size`?
# - Attribute apa yang kita pergunakan untuk mengetahui berbagai indeks dan sekaligus nama kolom yang ada pada sebuah dataframe?
# - Attribute apa yang kita pergunakan untuk mengetahui informasi tipe data dari masing-masing kolom pada sebuah dataframe?

# %%
df_superstore.ndim
# Out:
# 2

# %%
df_superstore['Sales'].ndim
# Out:
# 1

# %%
df_superstore.shape
# Out:
# (9994, 20)

# %%
df_superstore.size
# Out:
# 199880

# %%
df_superstore.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Postal_Code', 'Product_ID', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Category', 'Sub-Category',
#        'Product_Name', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_Name',
#        'Segment', 'Country/Region', 'City', 'State', 'Region'],
#       dtype='object')

# %%
df_superstore.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df_superstore.axes
# Out:
# [RangeIndex(start=0, stop=9994, step=1),
#  Index(['Order_ID', 'Customer_ID', 'Postal_Code', 'Product_ID', 'Sales',
#         'Quantity', 'Discount', 'Profit', 'Category', 'Sub-Category',
#         'Product_Name', 'Order_Date', 'Ship_Date', 'Ship_Mode', 'Customer_Name',
#         'Segment', 'Country/Region', 'City', 'State', 'Region'],
#        dtype='object')]

# %%
df_superstore.dtypes
# Out:
# Order_ID           object
# Customer_ID        object
# Postal_Code         int64
# Product_ID         object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Category           object
# Sub-Category       object
# Product_Name       object
# Order_Date         object
# Ship_Date          object
# Ship_Mode          object
# Customer_Name      object
# Segment            object
# Country/Region     object
# City               object
# State              object
# Region             object
# dtype: object

# %%
df_superstore.values
# Out:
# array([['CA-2019-152156', 'CG-12520', 42420, ..., 'Henderson',
#         'Kentucky', 'South'],
#        ['CA-2019-152156', 'CG-12520', 42420, ..., 'Henderson',
#         'Kentucky', 'South'],
#        ['CA-2019-138688', 'DV-13045', 90036, ..., 'Los Angeles',
#         'California', 'West'],
#        ...,
#        ['CA-2020-121258', 'DB-13060', 92627, ..., 'Costa Mesa',
#         'California', 'West'],
#        ['CA-2020-121258', 'DB-13060', 92627, ..., 'Costa Mesa',
#         'California', 'West'],
#        ['CA-2020-119914', 'CC-12220', 92683, ..., 'Westminster',
#         'California', 'West']], dtype=object)

# %% [markdown]
# **JAWABAN:**
# - ndim - dimensi,
# - `pd.dataframe.axes`
# - `pd.dataframe.dtype`

# %% [markdown]
# #### Ilustrasi 4: `pandas.dataframe`'s methods
# Eksekusi beberapa `cell codes` di bawah berikut, lalu tuliskan jawaban beberapa pertanyaan berikut ini di `markdown cell` yang disediakan:
# 1. Apa perbedaan antara method `pd.dataframe.head()` dengan `pd.dataframe.tail()`?
# 2. Apa perbedaan antara method `pd.dataframe.info()` dengan `pd.dataframe.describe()`?
# 3. Opsi apa saja yang dapat dijadikan `argument` bagi parameter `include` pada method `pd.dataframe.describe()`?
# 4. Berapa nilai rata-rata dari kolom `Sales`?
# 5. Nilai apa yang menjadi `modus` dari kolom `Category`?

# %%
df_superstore.head(10)
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# 5  CA-2017-115812    BH-11710        90032  FUR-FU-10001487   48.8600
# 6  CA-2017-115812    BH-11710        90032  OFF-AR-10002833    7.2800
# 7  CA-2017-115812    BH-11710        90032  TEC-PH-10002275  907.1520
# 8  CA-2017-115812    BH-11710        90032  OFF-BI-10003910   18.5040
# 9  CA-2017-115812    BH-11710        90032  OFF-AP-10002892  114.9000
#
#    Quantity  Discount    Profit         Category Sub-Category  \
# 0         2      0.00   41.9136        Furniture    Bookcases
# 1         3      0.00  219.5820        Furniture       Chairs
# 2         2      0.00    6.8714  Office Supplies       Labels
# 3         5      0.45 -383.0310        Furniture       Tables
# 4         2      0.20    2.5164  Office Supplies      Storage
# 5         7      0.00   14.1694        Furniture  Furnishings
# 6         4      0.00    1.9656  Office Supplies          Art
# 7         6      0.20   90.7152       Technology       Phones
# 8         3      0.20    5.7825  Office Supplies      Binders
# 9         5      0.00   34.4700  Office Supplies   Appliances
#
#                                         Product_Name  Order_Date   Ship_Date  \
# 0                  Bush Somerset Collection Bookcase   11/8/2019  11/11/2019
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   11/8/2019  11/11/2019
# 2  Self-Adhesive Address Labels for Typewriters b...   6/12/2019   6/16/2019
# 3      Bretford CR4500 Series Slim Rectangular Table  10/11/2018  10/18/2018
# 4                     Eldon Fold 'N Roll Cart System  10/11/2018  10/18/2018
# 5  Eldon Expressions Wood and Plastic Desk Access...    6/9/2017   6/14/2017
# 6                                         Newell 322    6/9/2017   6/14/2017
# 7                     Mitel 5320 IP Phone VoIP phone    6/9/2017   6/14/2017
# 8  DXL Angle-View Binders with Locking Rings by S...    6/9/2017   6/14/2017
# 9                   Belkin F5C206VTEL 6 Outlet Surge    6/9/2017   6/14/2017
#
#         Ship_Mode    Customer_Name    Segment Country/Region             City  \
# 0    Second Class      Claire Gute   Consumer  United States        Henderson
# 1    Second Class      Claire Gute   Consumer  United States        Henderson
# 2    Second Class  Darrin Van Huff  Corporate  United States      Los Angeles
# 3  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5  Standard Class  Brosina Hoffman   Consumer  United States      Los Angeles
# 6  Standard Class  Brosina Hoffman   Consumer  United States      Los Angeles
# 7  Standard Class  Brosina Hoffman   Consumer  United States      Los Angeles
# 8  Standard Class  Brosina Hoffman   Consumer  United States      Los Angeles
# 9  Standard Class  Brosina Hoffman   Consumer  United States      Los Angeles
#
#         State Region
# 0    Kentucky  South
# 1    Kentucky  South
# 2  California   West
# 3     Florida  South
# 4     Florida  South
# 5  California   West
# 6  California   West
# 7  California   West
# 8  California   West
# 9  California   West

# %%
df_superstore.tail()
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID    Sales  \
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.248
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.960
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.576
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.600
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.160
#
#       Quantity  Discount   Profit         Category Sub-Category  \
# 9989         3       0.2   4.1028        Furniture  Furnishings
# 9990         2       0.0  15.6332        Furniture  Furnishings
# 9991         2       0.2  19.3932       Technology       Phones
# 9992         4       0.0  13.3200  Office Supplies        Paper
# 9993         2       0.0  72.9480  Office Supplies   Appliances
#
#                                            Product_Name Order_Date  Ship_Date  \
# 9989                             Ultra Door Pull Handle  1/21/2017  1/23/2017
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...  2/26/2020   3/3/2020
# 9991                              Aastra 57i VoIP phone  2/26/2020   3/3/2020
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"  2/26/2020   3/3/2020
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...   5/4/2020   5/9/2020
#
#            Ship_Mode     Customer_Name   Segment Country/Region         City  \
# 9989    Second Class  Tom Boeckenhauer  Consumer  United States        Miami
# 9990  Standard Class       Dave Brooks  Consumer  United States   Costa Mesa
# 9991  Standard Class       Dave Brooks  Consumer  United States   Costa Mesa
# 9992  Standard Class       Dave Brooks  Consumer  United States   Costa Mesa
# 9993    Second Class      Chris Cortes  Consumer  United States  Westminster
#
#            State Region
# 9989     Florida  South
# 9990  California   West
# 9991  California   West
# 9992  California   West
# 9993  California   West

# %%
df_superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        9994 non-null   object
#  1   Customer_ID     9994 non-null   object
#  2   Postal_Code     9994 non-null   int64
#  3   Product_ID      9994 non-null   object
#  4   Sales           9994 non-null   float64
#  5   Quantity        9994 non-null   int64
#  6   Discount        9994 non-null   float64
#  7   Profit          9994 non-null   float64
#  8   Category        9994 non-null   object
#  9   Sub-Category    9994 non-null   object
#  10  Product_Name    9994 non-null   object
#  11  Order_Date      9994 non-null   object
#  12  Ship_Date       9994 non-null   object
#  13  Ship_Mode       9994 non-null   object
#  14  Customer_Name   9994 non-null   object
#  15  Segment         9994 non-null   object
#  16  Country/Region  9994 non-null   object
#  17  City            9994 non-null   object
#  18  State           9994 non-null   object
#  19  Region          9994 non-null   object
# dtypes: float64(3), int64(2), object(15)
# memory usage: 1.5+ MB

# %%
df_superstore.describe()
# Out:
#         Postal_Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.371023    229.858001     3.789574     0.156203    28.656896
# std    32063.704510    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df_superstore.describe(include='number')
# Out:
#         Postal_Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.371023    229.858001     3.789574     0.156203    28.656896
# std    32063.704510    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df_superstore.describe(include='object')
# Out:
#               Order_ID Customer_ID       Product_ID         Category  \
# count             9994        9994             9994             9994
# unique            5009         793             1862                3
# top     CA-2020-100111    WB-21850  OFF-PA-10001970  Office Supplies
# freq                14          37               19             6026
#
#        Sub-Category     Product_Name Order_Date   Ship_Date       Ship_Mode  \
# count          9994             9994       9994        9994            9994
# unique           17             1817       1236        1334               4
# top         Binders  Staple envelope   9/5/2019  12/16/2018  Standard Class
# freq           1523               48         38          35            5968
#
#         Customer_Name   Segment Country/Region           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region
# count    9994
# unique      4
# top      West
# freq     3203

# %%
df_superstore.describe(include='all')
# Out:
#               Order_ID Customer_ID   Postal_Code       Product_ID  \
# count             9994        9994   9994.000000             9994
# unique            5009         793           NaN             1862
# top     CA-2020-100111    WB-21850           NaN  OFF-PA-10001970
# freq                14          37           NaN               19
# mean               NaN         NaN  55190.371023              NaN
# std                NaN         NaN  32063.704510              NaN
# min                NaN         NaN   1040.000000              NaN
# 25%                NaN         NaN  23223.000000              NaN
# 50%                NaN         NaN  56430.500000              NaN
# 75%                NaN         NaN  90008.000000              NaN
# max                NaN         NaN  99301.000000              NaN
#
#                Sales     Quantity     Discount       Profit         Category  \
# count    9994.000000  9994.000000  9994.000000  9994.000000             9994
# unique           NaN          NaN          NaN          NaN                3
# top              NaN          NaN          NaN          NaN  Office Supplies
# freq             NaN          NaN          NaN          NaN             6026
# mean      229.858001     3.789574     0.156203    28.656896              NaN
# std       623.245101     2.225110     0.206452   234.260108              NaN
# min         0.444000     1.000000     0.000000 -6599.978000              NaN
# 25%        17.280000     2.000000     0.000000     1.728750              NaN
# 50%        54.490000     3.000000     0.200000     8.666500              NaN
# 75%       209.940000     5.000000     0.200000    29.364000              NaN
# max     22638.480000    14.000000     0.800000  8399.976000              NaN
#
#        Sub-Category     Product_Name Order_Date   Ship_Date       Ship_Mode  \
# count          9994             9994       9994        9994            9994
# unique           17             1817       1236        1334               4
# top         Binders  Staple envelope   9/5/2019  12/16/2018  Standard Class
# freq           1523               48         38          35            5968
# mean            NaN              NaN        NaN         NaN             NaN
# std             NaN              NaN        NaN         NaN             NaN
# min             NaN              NaN        NaN         NaN             NaN
# 25%             NaN              NaN        NaN         NaN             NaN
# 50%             NaN              NaN        NaN         NaN             NaN
# 75%             NaN              NaN        NaN         NaN             NaN
# max             NaN              NaN        NaN         NaN             NaN
#
#         Customer_Name   Segment Country/Region           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
# mean              NaN       NaN            NaN            NaN         NaN
# std               NaN       NaN            NaN            NaN         NaN
# min               NaN       NaN            NaN            NaN         NaN
# 25%               NaN       NaN            NaN            NaN         NaN
# 50%               NaN       NaN            NaN            NaN         NaN
# 75%               NaN       NaN            NaN            NaN         NaN
# max               NaN       NaN            NaN            NaN         NaN
#
#        Region
# count    9994
# unique      4
# top      West
# freq     3203
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
df_superstore.nlargest(5, 'Profit')
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 6826  CA-2019-118689    TC-20980        47905  TEC-CO-10004722  17499.95
# 8153  CA-2020-140151    RB-19360        98115  TEC-CO-10004722  13999.96
# 4190  CA-2020-166709    HL-15040        19711  TEC-CO-10004722  10499.97
# 9039  CA-2019-117121    AB-10105        48205  OFF-BI-10000545   9892.74
# 4098  CA-2017-116904    SC-20095        55407  OFF-BI-10001120   9449.95
#
#       Quantity  Discount     Profit         Category Sub-Category  \
# 6826         5       0.0  8399.9760       Technology      Copiers
# 8153         4       0.0  6719.9808       Technology      Copiers
# 4190         3       0.0  5039.9856       Technology      Copiers
# 9039        13       0.0  4946.3700  Office Supplies      Binders
# 4098         5       0.0  4630.4755  Office Supplies      Binders
#
#                                           Product_Name  Order_Date  \
# 6826             Canon imageCLASS 2200 Advanced Copier   10/2/2019
# 8153             Canon imageCLASS 2200 Advanced Copier   3/23/2020
# 4190             Canon imageCLASS 2200 Advanced Copier  11/17/2020
# 9039  GBC Ibimaster 500 Manual ProClick Binding System  12/17/2019
# 4098              Ibico EPK-21 Electric Binding System   9/23/2017
#
#        Ship_Date       Ship_Mode  Customer_Name    Segment Country/Region  \
# 6826   10/9/2019  Standard Class   Tamara Chand  Corporate  United States
# 8153   3/25/2020     First Class   Raymond Buch   Consumer  United States
# 4190  11/22/2020  Standard Class   Hunter Lopez   Consumer  United States
# 9039  12/21/2019  Standard Class  Adrian Barton   Consumer  United States
# 4098   9/28/2017  Standard Class   Sanjit Chand   Consumer  United States
#
#              City       State   Region
# 6826    Lafayette     Indiana  Central
# 8153      Seattle  Washington     West
# 4190       Newark    Delaware     East
# 9039      Detroit    Michigan  Central
# 4098  Minneapolis   Minnesota  Central

# %%
df_superstore.nsmallest(5, 'Profit')
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 7772  CA-2019-108196    CS-12505        43130  TEC-MA-10000418  4499.985
# 683   US-2020-168116    GT-14635        27217  TEC-MA-10004125  7999.980
# 9774  CA-2017-169019    LF-17185        78207  OFF-BI-10004995  2177.584
# 3011  CA-2020-134845    SR-20425        80027  TEC-MA-10000822  2549.985
# 4991  US-2020-122714    HG-14965        60653  OFF-BI-10001120  1889.990
#
#       Quantity  Discount     Profit         Category Sub-Category  \
# 7772         5       0.7 -6599.9780       Technology     Machines
# 683          4       0.5 -3839.9904       Technology     Machines
# 9774         8       0.8 -3701.8928  Office Supplies      Binders
# 3011         5       0.7 -3399.9800       Technology     Machines
# 4991         5       0.8 -2929.4845  Office Supplies      Binders
#
#                                    Product_Name  Order_Date   Ship_Date  \
# 7772  Cubify CubeX 3D Printer Double Head Print  11/25/2019   12/2/2019
# 683   Cubify CubeX 3D Printer Triple Head Print   11/4/2020   11/4/2020
# 9774  GBC DocuBind P400 Electric Binding System   7/26/2017   7/30/2017
# 3011  Lexmark MX611dhe Monochrome Laser Printer   4/17/2020   4/23/2020
# 4991       Ibico EPK-21 Electric Binding System   12/7/2020  12/13/2020
#
#            Ship_Mode   Customer_Name      Segment Country/Region         City  \
# 7772  Standard Class   Cindy Stewart     Consumer  United States    Lancaster
# 683         Same Day  Grant Thornton    Corporate  United States   Burlington
# 9774  Standard Class     Luke Foster     Consumer  United States  San Antonio
# 3011  Standard Class  Sharelle Roach  Home Office  United States   Louisville
# 4991  Standard Class   Henry Goldwyn    Corporate  United States      Chicago
#
#                State   Region
# 7772            Ohio     East
# 683   North Carolina    South
# 9774           Texas  Central
# 3011        Colorado     West
# 4991        Illinois  Central

# %% [markdown]
# **JAWABAN:**
#
# 1. head = 5 rows paling atas, tail = 5 rows paling bawah
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# #### Ilustrasi 5: `pandas.series`'s methods
# Eksekusi setiap `code cell` di bawah berikut, lalu lengkapi informasi terkait masing-masing method pada `code cell` terkait.

# %%
# Method `pd.series.value_counts` adalah untuk
df_superstore['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
# Method `pd.series.min` adalah untuk ...
df_superstore['Sales'].min()
# Out:
# 0.444

# %%
# Method `pd.series.max` adalah untuk ...
df_superstore['Sales'].max()
# Out:
# 22638.48

# %%
# Method `pd.series.sum` adalah untuk ...
df_superstore['Sales'].sum()
# Out:
# 2297200.8603000003

# %%
# Method `pd.series.mean` adalah untuk ...
df_superstore['Sales'].mean()
# Out:
# 229.85800083049833

# %%
# Method `pd.series.std` adalah untuk ...
df_superstore['Sales'].std()
# Out:
# 623.2451005086818

# %%
# Method `pd.series.median` adalah untuk ...
df_superstore['Sales'].median()
# Out:
# 54.489999999999995

# %%
# Method `pd.series.quantile(0.25)` adalah untuk ...
df_superstore['Sales'].quantile(0.25)
# Out:
# 17.28

# %%
# Method `pd.series.quantile(0.5)` adalah untuk ...
df_superstore['Sales'].quantile(0.5)
# Out:
# 54.489999999999995

# %%
# Method `pd.series.quantile(0.75)` adalah untuk ...
df_superstore['Sales'].quantile(0.75)
# Out:
# 209.94

# %% [markdown]
# # *Data Selection*
# Salah satu keunggulan utama `pandas` dalam melakukan manipulasi data adalah kemudahan dalam melakukan pemilihan data. Pada prinsipnya pemilihan data dapat dilakukan dengan menggunakan teknik *slicing* seperti telah dicontohkan pada ilustrasi sebelumnya, akan tetapi cara tersebut dirasa kurang *elegan* dan seringkali sulit untuk dimengerti.
#
# Pada bagian ini akan disampaikan tatacara pemilihan data yang biasanya dilakukan dalam `pandas`, dimulai dengan pengenalan terhadap `accessors` untuk pemilihan data, hingga penyusunan `filter`.

# %% [markdown]
# ## Accessors
# > `Accessors` adalah objek yang disematkan ke sebuah `attribute` dari `pandas.dataframe/pandas.series` yang memberikan fungsionalitas ekstra tertentu.
#
# `pandas` menyediakan dua `accessors` yang sangat populer dipergunakan untuk melakukan pemilihan data secara fleksibel, antara lain:
# 1. `pd.dataframe.loc[]`, dengan format penggunaan:
# ```
# nama_dataframe.loc[<pilih_rows>, <pilih_nama_kolom>]
# ```
# 2. `pd.dataframe.iloc[]`, dengan format penggunaan:
# ```
# nama_dataframe.iloc[<pilih_rows>, <pilih_indeks_kolom>]
# ```

# %% [markdown]
# #### Ilustrasi 6: Pemilihan Data - `Accessors`
# Tuliskan beberapa perbedaan utama baik dalam cara penggunaan maupun output dari `accessor` `.loc` dengan `.iloc`, di `markdown cell` yang disediakan di bawah, setelah `kedua `code cell` di bawah berikut di eksekusi.

# %%
df_superstore.loc[df_superstore['Profit']<0, ['Order_ID', 'Category', 'Sub-Category', 'Sales', 'Profit']]
# Out:
#             Order_ID         Category Sub-Category      Sales     Profit
# 3     US-2018-108966        Furniture       Tables   957.5775  -383.0310
# 14    US-2018-118983  Office Supplies   Appliances    68.8100  -123.8580
# 15    US-2018-118983  Office Supplies      Binders     2.5440    -3.8160
# 23    US-2020-156909        Furniture       Chairs    71.3720    -1.0196
# 27    US-2018-150630        Furniture    Bookcases  3083.4300 -1665.0522
# ...              ...              ...          ...        ...        ...
# 9920  CA-2019-149272  Office Supplies      Binders    22.3860   -35.8176
# 9921  CA-2017-111360  Office Supplies      Binders     5.7420    -4.5936
# 9931  CA-2018-104948        Furniture    Bookcases   683.3320   -40.1960
# 9937  CA-2019-164889        Furniture       Tables    71.0880    -1.7772
# 9962  CA-2018-168088        Furniture    Bookcases   383.4656   -67.6704
#
# [1871 rows x 5 columns]

# %%
df_superstore.iloc[0:10, [0, 8, 9, 4, 7]]
# Out:
#          Order_ID         Category Sub-Category     Sales    Profit
# 0  CA-2019-152156        Furniture    Bookcases  261.9600   41.9136
# 1  CA-2019-152156        Furniture       Chairs  731.9400  219.5820
# 2  CA-2019-138688  Office Supplies       Labels   14.6200    6.8714
# 3  US-2018-108966        Furniture       Tables  957.5775 -383.0310
# 4  US-2018-108966  Office Supplies      Storage   22.3680    2.5164
# 5  CA-2017-115812        Furniture  Furnishings   48.8600   14.1694
# 6  CA-2017-115812  Office Supplies          Art    7.2800    1.9656
# 7  CA-2017-115812       Technology       Phones  907.1520   90.7152
# 8  CA-2017-115812  Office Supplies      Binders   18.5040    5.7825
# 9  CA-2017-115812  Office Supplies   Appliances  114.9000   34.4700

# %% [markdown]
# **PERBEDAAN `loc` vs `iloc`:**
#
# 1.

# %% [markdown]
# ## Filtering
# Salah satu fitur lain yang disediakan `pandas` adalah memanfaatkan `boolean arrays` untuk melakukan filtering. Filtering dilakukan melalui dua tahap berikut, yaitu:
# 1. Menyusun filter, dengan format penulisan umumnya:
# ```python
# nama_filter = <boolean_expression>
# ```
# 2. Menyematkan filter ke dataframe, dengan format penulisan:
# ```python
# data_difilter = nama_dataframe[nama_filter]
# ```

# %% [markdown]
# ### Ilustrasi 7: Data Filtering
# Lengkapi ekspresi pada statements di bawah, agar dapat dieksekusi untuk menghasilkan dataframe berisikan `rows` dengan nilai `Profit` negatif (mengalami kerugian) dari `df_superstore` yang sebelumnya sudah kita *parse*.

# %%
# Membuat filter bagi row yang mengalami kerugian (profit<0)
filter_sales_rugi = df_superstore['Profit']<0

# Menyematkan filter ke dataframe induk, assign ke sales_merugi
sales_merugi = df_superstore[filter_sales_rugi]

# lihat isi sales_merugi
sales_merugi
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID      Sales  \
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 14    US-2018-118983    HP-14815        76106  OFF-AP-10002311    68.8100
# 15    US-2018-118983    HP-14815        76106  OFF-BI-10000756     2.5440
# 23    US-2020-156909    SF-20065        19140  FUR-CH-10002774    71.3720
# 27    US-2018-150630    TB-21520        19140  FUR-BO-10004834  3083.4300
# ...              ...         ...          ...              ...        ...
# 9920  CA-2019-149272    MY-18295        77803  OFF-BI-10004233    22.3860
# 9921  CA-2017-111360    AT-10435        44312  OFF-BI-10003350     5.7420
# 9931  CA-2018-104948    KH-16510        92404  FUR-BO-10004357   683.3320
# 9937  CA-2019-164889    CP-12340        90049  FUR-TA-10001676    71.0880
# 9962  CA-2018-168088    CM-12655        77041  FUR-BO-10004218   383.4656
#
#       Quantity  Discount     Profit         Category Sub-Category  \
# 3            5      0.45  -383.0310        Furniture       Tables
# 14           5      0.80  -123.8580  Office Supplies   Appliances
# 15           3      0.80    -3.8160  Office Supplies      Binders
# 23           2      0.30    -1.0196        Furniture       Chairs
# 27           7      0.50 -1665.0522        Furniture    Bookcases
# ...        ...       ...        ...              ...          ...
# 9920         7      0.80   -35.8176  Office Supplies      Binders
# 9921         3      0.70    -4.5936  Office Supplies      Binders
# 9931         4      0.15   -40.1960        Furniture    Bookcases
# 9937         2      0.20    -1.7772        Furniture       Tables
# 9962         4      0.32   -67.6704        Furniture    Bookcases
#
#                                            Product_Name  Order_Date  \
# 3         Bretford CR4500 Series Slim Rectangular Table  10/11/2018
# 14    Holmes Replacement Filter for HEPA Air Cleaner...  11/22/2018
# 15     Storex DuraTech Recycled Plastic Frosted Binders  11/22/2018
# 23                   Global Deluxe Stacking Chair, Gray   7/16/2020
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...   9/17/2018
# ...                                                 ...         ...
# 9920  GBC Pre-Punched Binding Paper, Plastic, White,...   3/15/2019
# 9921                    Acco Expandable Hanging Binders  11/24/2017
# 9931     O'Sullivan Living Dimensions 3-Shelf Bookcases  11/13/2018
# 9937       Hon 61000 Series Interactive Training Tables    6/3/2019
# 9962  Bush Heritage Pine Collection 5-Shelf Bookcase...   3/19/2018
#
#        Ship_Date       Ship_Mode     Customer_Name      Segment  \
# 3     10/18/2018  Standard Class    Sean O'Donnell     Consumer
# 14    11/26/2018  Standard Class     Harold Pawlan  Home Office
# 15    11/26/2018  Standard Class     Harold Pawlan  Home Office
# 23     7/18/2020    Second Class   Sandra Flanagan     Consumer
# 27     9/21/2018  Standard Class   Tracy Blumstein     Consumer
# ...          ...             ...               ...          ...
# 9920   3/19/2019  Standard Class   Muhammed Yedwab    Corporate
# 9921  11/30/2017  Standard Class       Alyssa Tate  Home Office
# 9931  11/17/2018  Standard Class     Keith Herrera     Consumer
# 9937    6/6/2019    Second Class    Christine Phan    Corporate
# 9962   3/22/2018     First Class  Corinna Mitchell  Home Office
#
#      Country/Region             City         State   Region
# 3     United States  Fort Lauderdale       Florida    South
# 14    United States       Fort Worth         Texas  Central
# 15    United States       Fort Worth         Texas  Central
# 23    United States     Philadelphia  Pennsylvania     East
# 27    United States     Philadelphia  Pennsylvania     East
# ...             ...              ...           ...      ...
# 9920  United States            Bryan         Texas  Central
# 9921  United States            Akron          Ohio     East
# 9931  United States   San Bernardino    California     West
# 9937  United States      Los Angeles    California     West
# 9962  United States          Houston         Texas  Central
#
# [1871 rows x 20 columns]

# %% [markdown]
# ## QUERYING
#
# Selain kedua cara yang telah disebutkan sebelumnya di atas, `pandas` juga menyediakan sebuah method yang memungkinkan dilakukannya filtering dengan gaya query pada `SQL`. Terdapat dua method yang disedakan oleh `pandas`, yaitu:
# 1. `pd.DataFrame.query` yang dipergunakan untuk melakukan filtering rows berdasarkan kondisi tertentu, dengan contoh penggunaan method tersebut:
# ```python
# data_difilter = nama_dataframe.query("suatu_kolom == 1")
# ```
# 2. `pd.DataFrame.filter` yang dipergunakan untuk melakukan filtering terhadap index pada dataframe, baik kolom maupun rows, dengan contoh penggunaan sebagai berikut:
# ```python
# data_difilter_kolom = nama_dataframe.filter(<list_nama_kolom>, axis=1)
# data_difilter_row = nama_dataframe.filter(<list_index_row>, axis=0)
# ```

# %% [markdown]
# #### Ilustrasi 8: Querying
# Lengkapi ekspresi pada statements di bawah, agar dapat dieksekusi untuk menghasilkan dataframe berisikan `rows` dengan nilai `Profit` negatif (mengalami kerugian) dari `df_superstore` yang sebelumnya sudah kita *parse*.

# %%
# Terapkan method query untuk memfilter rows dengan nilai Profit<0
sales_merugi_query = df_superstore.query('Profit<0')

# lihat isi sales_merugi_query
sales_merugi_query
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID      Sales  \
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577   957.5775
# 14    US-2018-118983    HP-14815        76106  OFF-AP-10002311    68.8100
# 15    US-2018-118983    HP-14815        76106  OFF-BI-10000756     2.5440
# 23    US-2020-156909    SF-20065        19140  FUR-CH-10002774    71.3720
# 27    US-2018-150630    TB-21520        19140  FUR-BO-10004834  3083.4300
# ...              ...         ...          ...              ...        ...
# 9920  CA-2019-149272    MY-18295        77803  OFF-BI-10004233    22.3860
# 9921  CA-2017-111360    AT-10435        44312  OFF-BI-10003350     5.7420
# 9931  CA-2018-104948    KH-16510        92404  FUR-BO-10004357   683.3320
# 9937  CA-2019-164889    CP-12340        90049  FUR-TA-10001676    71.0880
# 9962  CA-2018-168088    CM-12655        77041  FUR-BO-10004218   383.4656
#
#       Quantity  Discount     Profit         Category Sub-Category  \
# 3            5      0.45  -383.0310        Furniture       Tables
# 14           5      0.80  -123.8580  Office Supplies   Appliances
# 15           3      0.80    -3.8160  Office Supplies      Binders
# 23           2      0.30    -1.0196        Furniture       Chairs
# 27           7      0.50 -1665.0522        Furniture    Bookcases
# ...        ...       ...        ...              ...          ...
# 9920         7      0.80   -35.8176  Office Supplies      Binders
# 9921         3      0.70    -4.5936  Office Supplies      Binders
# 9931         4      0.15   -40.1960        Furniture    Bookcases
# 9937         2      0.20    -1.7772        Furniture       Tables
# 9962         4      0.32   -67.6704        Furniture    Bookcases
#
#                                            Product_Name  Order_Date  \
# 3         Bretford CR4500 Series Slim Rectangular Table  10/11/2018
# 14    Holmes Replacement Filter for HEPA Air Cleaner...  11/22/2018
# 15     Storex DuraTech Recycled Plastic Frosted Binders  11/22/2018
# 23                   Global Deluxe Stacking Chair, Gray   7/16/2020
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...   9/17/2018
# ...                                                 ...         ...
# 9920  GBC Pre-Punched Binding Paper, Plastic, White,...   3/15/2019
# 9921                    Acco Expandable Hanging Binders  11/24/2017
# 9931     O'Sullivan Living Dimensions 3-Shelf Bookcases  11/13/2018
# 9937       Hon 61000 Series Interactive Training Tables    6/3/2019
# 9962  Bush Heritage Pine Collection 5-Shelf Bookcase...   3/19/2018
#
#        Ship_Date       Ship_Mode     Customer_Name      Segment  \
# 3     10/18/2018  Standard Class    Sean O'Donnell     Consumer
# 14    11/26/2018  Standard Class     Harold Pawlan  Home Office
# 15    11/26/2018  Standard Class     Harold Pawlan  Home Office
# 23     7/18/2020    Second Class   Sandra Flanagan     Consumer
# 27     9/21/2018  Standard Class   Tracy Blumstein     Consumer
# ...          ...             ...               ...          ...
# 9920   3/19/2019  Standard Class   Muhammed Yedwab    Corporate
# 9921  11/30/2017  Standard Class       Alyssa Tate  Home Office
# 9931  11/17/2018  Standard Class     Keith Herrera     Consumer
# 9937    6/6/2019    Second Class    Christine Phan    Corporate
# 9962   3/22/2018     First Class  Corinna Mitchell  Home Office
#
#      Country/Region             City         State   Region
# 3     United States  Fort Lauderdale       Florida    South
# 14    United States       Fort Worth         Texas  Central
# 15    United States       Fort Worth         Texas  Central
# 23    United States     Philadelphia  Pennsylvania     East
# 27    United States     Philadelphia  Pennsylvania     East
# ...             ...              ...           ...      ...
# 9920  United States            Bryan         Texas  Central
# 9921  United States            Akron          Ohio     East
# 9931  United States   San Bernardino    California     West
# 9937  United States      Los Angeles    California     West
# 9962  United States          Houston         Texas  Central
#
# [1871 rows x 20 columns]

# %%
# Terapkan method filter untuk menampilkan kolom-kolom tertentu saja dari sales_merugi_query
sales_merugi_query.filter(['Order_ID', 'Category', 'Sub-Category', 'Sales', 'Profit'])
# Out:
#             Order_ID         Category Sub-Category      Sales     Profit
# 3     US-2018-108966        Furniture       Tables   957.5775  -383.0310
# 14    US-2018-118983  Office Supplies   Appliances    68.8100  -123.8580
# 15    US-2018-118983  Office Supplies      Binders     2.5440    -3.8160
# 23    US-2020-156909        Furniture       Chairs    71.3720    -1.0196
# 27    US-2018-150630        Furniture    Bookcases  3083.4300 -1665.0522
# ...              ...              ...          ...        ...        ...
# 9920  CA-2019-149272  Office Supplies      Binders    22.3860   -35.8176
# 9921  CA-2017-111360  Office Supplies      Binders     5.7420    -4.5936
# 9931  CA-2018-104948        Furniture    Bookcases   683.3320   -40.1960
# 9937  CA-2019-164889        Furniture       Tables    71.0880    -1.7772
# 9962  CA-2018-168088        Furniture    Bookcases   383.4656   -67.6704
#
# [1871 rows x 5 columns]

# %% [markdown]
# ## EXERCISE 2
# Melakukan pemilihan data menggunakan:
# 1. Tiga filter:
#   - `rows` dimana value `Sales` melebihi nilai quantile ke-3nya;
#   - `rows` dimana value `Region` adalah 'East'; dan
#   - `rows` dimana value `Profit` melebihi nilai quantile ke-3nya.
# 2. Kolom-kolom terpilih:
# ```python
# ['Order_ID', 'Category', 'Sub-Category', 'Sales', 'Profit', 'Region']
# ```

# %%
# FILTERING : ACCESSOR .loc
# Buat filters
filter_sales_over = df_superstore['Sales']>df_superstore['Sales'].quantile(0.75)
filter_region = df_superstore['Region']=='East'
filter_profit = df_superstore['Profit']>df_superstore['Profit'].quantile(0.75)

# Buat kolom pilihan:
kolom_terpilih = ['Order_ID', 'Category', 'Sub-Category', 'Sales', 'Profit', 'Region']

# Pilih data, gunakan accessor `.loc`
sales_tinggi_east = df_superstore.loc[filter_sales_over & filter_region & filter_profit, kolom_terpilih]

# Cek isi sales_tinggi
sales_tinggi_east
# Out:
#             Order_ID         Category Sub-Category     Sales    Profit Region
# 54    CA-2019-105816       Technology       Phones  1029.950  298.6855   East
# 121   CA-2019-103730  Office Supplies      Storage   226.560   63.4368   East
# 189   CA-2018-102281        Furniture    Bookcases   899.136  112.3920   East
# 192   CA-2018-102281        Furniture    Bookcases   626.352   46.9764   East
# 253   CA-2019-146941  Office Supplies    Envelopes   361.920  162.8640   East
# ...              ...              ...          ...       ...       ...    ...
# 9879  CA-2019-122581        Furniture       Chairs   573.174   63.6860   East
# 9897  CA-2019-112830        Furniture  Furnishings   466.320   34.9740   East
# 9925  CA-2018-159534  Office Supplies      Binders  1087.936  353.5792   East
# 9957  US-2017-143287  Office Supplies        Paper   223.920  109.7208   East
# 9968  CA-2020-153871  Office Supplies      Binders   735.980  331.1910   East
#
# [441 rows x 6 columns]

# %%
# QUERYING
# Siapkan data sales_q3 dan profit_q3
sales_q3 = df_superstore['Sales'].quantile(0.75)
profit_q3 = df_superstore['Profit'].quantile(0.75)

# Buat query bagi filtering
query_filter = f"Region=='East' & Sales>{sales_q3} & Profit>{profit_q3}"

# gunakan method `pd.dataframe.query` & `pd.dataframe.filter` untuk melakukan filtering
sales_tinggi_east_query = df_superstore.query(query_filter).filter(kolom_terpilih)

# lihat isi sales_tinggi query
sales_tinggi_east_query
# Out:
#             Order_ID         Category Sub-Category     Sales    Profit Region
# 54    CA-2019-105816       Technology       Phones  1029.950  298.6855   East
# 121   CA-2019-103730  Office Supplies      Storage   226.560   63.4368   East
# 189   CA-2018-102281        Furniture    Bookcases   899.136  112.3920   East
# 192   CA-2018-102281        Furniture    Bookcases   626.352   46.9764   East
# 253   CA-2019-146941  Office Supplies    Envelopes   361.920  162.8640   East
# ...              ...              ...          ...       ...       ...    ...
# 9879  CA-2019-122581        Furniture       Chairs   573.174   63.6860   East
# 9897  CA-2019-112830        Furniture  Furnishings   466.320   34.9740   East
# 9925  CA-2018-159534  Office Supplies      Binders  1087.936  353.5792   East
# 9957  US-2017-143287  Office Supplies        Paper   223.920  109.7208   East
# 9968  CA-2020-153871  Office Supplies      Binders   735.980  331.1910   East
#
# [441 rows x 6 columns]

# %% [markdown]
# # Data Sorting
# Mengurutkan data berdasarkan value pada kolom tertentu dapat dengan mudah dilakukan dengan menggunakan method `pandas.dataframe.sort_values()`, dengan format penulisan seperti berikut:
# ```python
# nama_dataframe.sort_values(by=<list_nama_kolom>, ascending=<list_boolean>]
# ```

# %% [markdown]
# #### Ilustrasi 9: Sorting data
# 1. Lakukan pengurutan data `sales_merugi` berdasarkan kriteria berikut:
#  - Value `Profit` dari yang paling rendah;
#  - Value `Sales` dari yang paling tinggi.
# 2. Lakukan pengurutan data `sales_tinggi` berdasarkan kriteria berikut:
#  - Value `Profit` dari yang paling tinggi;
#  - Value `Sales` dari yang paling tinggi.

# %%
sales_merugi.sort_values(by=['Profit', 'Sales'], ascending=[True,False])
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 7772  CA-2019-108196    CS-12505        43130  TEC-MA-10000418  4499.985
# 683   US-2020-168116    GT-14635        27217  TEC-MA-10004125  7999.980
# 9774  CA-2017-169019    LF-17185        78207  OFF-BI-10004995  2177.584
# 3011  CA-2020-134845    SR-20425        80027  TEC-MA-10000822  2549.985
# 4991  US-2020-122714    HG-14965        60653  OFF-BI-10001120  1889.990
# ...              ...         ...          ...              ...       ...
# 4660  CA-2018-112130    SV-20785        19140  TEC-AC-10001542    27.552
# 7413  CA-2020-121125    MG-17890        97224  FUR-FU-10000820    13.592
# 1566  CA-2018-129112    AW-10840        75002  TEC-AC-10003038    21.480
# 1496  CA-2020-152485    JD-15790        75019  OFF-ST-10004950    16.784
# 3228  CA-2017-108189    ES-14080        85281  TEC-AC-10003038     7.160
#
#       Quantity  Discount     Profit         Category Sub-Category  \
# 7772         5       0.7 -6599.9780       Technology     Machines
# 683          4       0.5 -3839.9904       Technology     Machines
# 9774         8       0.8 -3701.8928  Office Supplies      Binders
# 3011         5       0.7 -3399.9800       Technology     Machines
# 4991         5       0.8 -2929.4845  Office Supplies      Binders
# ...        ...       ...        ...              ...          ...
# 4660         3       0.2    -0.3444       Technology  Accessories
# 7413         1       0.2    -0.3398        Furniture  Furnishings
# 1566         3       0.2    -0.2685       Technology  Accessories
# 1496         1       0.2    -0.2098  Office Supplies      Storage
# 3228         1       0.2    -0.0895       Technology  Accessories
#
#                                     Product_Name  Order_Date   Ship_Date  \
# 7772   Cubify CubeX 3D Printer Double Head Print  11/25/2019   12/2/2019
# 683    Cubify CubeX 3D Printer Triple Head Print   11/4/2020   11/4/2020
# 9774   GBC DocuBind P400 Electric Binding System   7/26/2017   7/30/2017
# 3011   Lexmark MX611dhe Monochrome Laser Printer   4/17/2020   4/23/2020
# 4991        Ibico EPK-21 Electric Binding System   12/7/2020  12/13/2020
# ...                                          ...         ...         ...
# 4660        SanDisk Cruzer 16 GB USB Flash Drive    5/3/2018    5/7/2018
# 7413   Tensor Brushed Steel Torchiere Floor Lamp   5/30/2020    6/3/2020
# 1566  Kingston Digital DataTraveler 16GB USB 2.0  11/29/2018  11/30/2018
# 1496    Acco Perma 3000 Stacking Storage Drawers    9/4/2020    9/8/2020
# 3228  Kingston Digital DataTraveler 16GB USB 2.0   10/2/2017   10/5/2017
#
#            Ship_Mode     Customer_Name      Segment Country/Region  \
# 7772  Standard Class     Cindy Stewart     Consumer  United States
# 683         Same Day    Grant Thornton    Corporate  United States
# 9774  Standard Class       Luke Foster     Consumer  United States
# 3011  Standard Class    Sharelle Roach  Home Office  United States
# 4991  Standard Class     Henry Goldwyn    Corporate  United States
# ...              ...               ...          ...            ...
# 4660  Standard Class  Stewart Visinsky     Consumer  United States
# 7413  Standard Class  Michael Granlund  Home Office  United States
# 1566     First Class      Anthony Witt     Consumer  United States
# 1496  Standard Class        John Dryer     Consumer  United States
# 3228     First Class        Erin Smith    Corporate  United States
#
#               City           State   Region
# 7772     Lancaster            Ohio     East
# 683     Burlington  North Carolina    South
# 9774   San Antonio           Texas  Central
# 3011    Louisville        Colorado     West
# 4991       Chicago        Illinois  Central
# ...            ...             ...      ...
# 4660  Philadelphia    Pennsylvania     East
# 7413        Tigard          Oregon     West
# 1566         Allen           Texas  Central
# 1496       Coppell           Texas  Central
# 3228         Tempe         Arizona     West
#
# [1871 rows x 20 columns]

# %%
sales_tinggi_east.sort_values(by=['Profit', 'Sales'], ascending=[False,False])
# Out:
#             Order_ID         Category Sub-Category      Sales     Profit  \
# 4190  CA-2020-166709       Technology      Copiers  10499.970  5039.9856
# 2623  CA-2020-127180       Technology      Copiers  11199.968  3919.9888
# 7666  US-2019-140158       Technology      Copiers   5399.910  2591.9568
# 1085  US-2019-143819       Technology     Machines   4899.930  2400.9657
# 4277  US-2019-107440       Technology     Machines   9099.930  2365.9818
# ...              ...              ...          ...        ...        ...
# 6155  CA-2020-151484  Office Supplies      Storage    332.704    33.2704
# 6778  US-2019-147711        Furniture    Bookcases    344.940    31.0446
# 6761  CA-2019-162943        Furniture       Chairs    253.764    31.0156
# 5972  CA-2020-115105        Furniture    Bookcases    240.784    30.0980
# 3383  CA-2018-130659        Furniture       Chairs    384.174    29.8802
#
#      Region
# 4190   East
# 2623   East
# 7666   East
# 1085   East
# 4277   East
# ...     ...
# 6155   East
# 6778   East
# 6761   East
# 5972   East
# 3383   East
#
# [441 rows x 6 columns]

# %% [markdown]
# # *Data Manipulation*

# %% [markdown]
# ### *Arithmatic Operations*
# Berbagai operasi aritmatik--penjumlahann(`+`), pengurangan (`-`), pembagian (`/`), perkalian (`*`), dan pemangkatan (`**`)--dapat diterapkan terhadap `pandas.series` dan `pandas.dataframe` objek.
# Format penulisan operasi aritmatika, antara lain:
# ```python
# # Operasi aritmatika antar kolom
# dataframe[<nama_kolom_baru>] = dataframe[<kolom_a>] <operator_aritmatika> dataframe[<kolom_b>]
# ```

# %% [markdown]
# #### Ilustrasi 10: Menghitung Harga Satuan
# Dataframe `df_superstore` yang sebelumnya telah kita parse ternyata tidak memiliki informasi terkait harga satuan dari masing-masing `Sales` yang terjadi. Oleh karena informasi tersebut diperlukan, maka kita perlu untuk melakukan penghitungan harga satuan, dan menyimpan hasil perhitungan tersebut pada sebuah kolom baru bernama `Price`.
#
# Sebelum menuliskan `script` untuk perhitungan diatas, lengkapi beberapa informasi yang diperlukan berikut:
# - Data yang akan diperlukan untuk menghitung `Price` adalah:
#   - ```Sales```
#   - ```Quantity```
# - Tuliskan rumus penghitungan `Price` di bawah berikut:
#
#   $ Price_i = \frac{Sales_i}{Price_i} $

# %%
# Menghitung Harga Satuan
df_superstore['Price'] = df_superstore['Sales']/df_superstore['Quantity']

# %%
df_superstore.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0         2      0.00   41.9136        Furniture    Bookcases  ...
# 1         3      0.00  219.5820        Furniture       Chairs  ...
# 2         2      0.00    6.8714  Office Supplies       Labels  ...
# 3         5      0.45 -383.0310        Furniture       Tables  ...
# 4         2      0.20    2.5164  Office Supplies      Storage  ...
#
#    Order_Date   Ship_Date       Ship_Mode    Customer_Name    Segment  \
# 0   11/8/2019  11/11/2019    Second Class      Claire Gute   Consumer
# 1   11/8/2019  11/11/2019    Second Class      Claire Gute   Consumer
# 2   6/12/2019   6/16/2019    Second Class  Darrin Van Huff  Corporate
# 3  10/11/2018  10/18/2018  Standard Class   Sean O'Donnell   Consumer
# 4  10/11/2018  10/18/2018  Standard Class   Sean O'Donnell   Consumer
#
#   Country/Region             City       State Region     Price
# 0  United States        Henderson    Kentucky  South  130.9800
# 1  United States        Henderson    Kentucky  South  243.9800
# 2  United States      Los Angeles  California   West    7.3100
# 3  United States  Fort Lauderdale     Florida  South  191.5155
# 4  United States  Fort Lauderdale     Florida  South   11.1840
#
# [5 rows x 21 columns]

# %% [markdown]
# ## EXERCISE 3
# *Management* memerlukan informasi terkait 10 Sales yang memiliki persentase nilai penjualan yang paling signifikan untuk tujuan pemberian reward. Lakukan penghitungan persentase sales dari total sales, dan simpan hasilnya pada kolom baru bernama `Share`.
#
# Sama seperti pada **Ilustrasi 9** sebelumnya, silahkan tuliskan beberapa informasi yang diperlukan di bawah ini:
# - Data yang diperlukan:
#   - ```Sales```
#   - ```Total_Sales```
# - Tuliskan rumus perhitungan:
#
#   $ Share_{i} = \frac{Sales_i}{\sum Sales}*100 $

# %%
# Hitung Percent_from_Total
df_superstore['Share'] = (df_superstore['Sales']/df_superstore['Sales'].sum())*100

# %%
# Tampilkan 10 rows dengan Share Sales paling besar
df_superstore.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0         2      0.00   41.9136        Furniture    Bookcases  ...
# 1         3      0.00  219.5820        Furniture       Chairs  ...
# 2         2      0.00    6.8714  Office Supplies       Labels  ...
# 3         5      0.45 -383.0310        Furniture       Tables  ...
# 4         2      0.20    2.5164  Office Supplies      Storage  ...
#
#     Ship_Date       Ship_Mode    Customer_Name    Segment Country/Region  \
# 0  11/11/2019    Second Class      Claire Gute   Consumer  United States
# 1  11/11/2019    Second Class      Claire Gute   Consumer  United States
# 2   6/16/2019    Second Class  Darrin Van Huff  Corporate  United States
# 3  10/18/2018  Standard Class   Sean O'Donnell   Consumer  United States
# 4  10/18/2018  Standard Class   Sean O'Donnell   Consumer  United States
#
#               City       State Region     Price     Share
# 0        Henderson    Kentucky  South  130.9800  0.011403
# 1        Henderson    Kentucky  South  243.9800  0.031862
# 2      Los Angeles  California   West    7.3100  0.000636
# 3  Fort Lauderdale     Florida  South  191.5155  0.041685
# 4  Fort Lauderdale     Florida  South   11.1840  0.000974
#
# [5 rows x 22 columns]

# %% [markdown]
# ### *Functions Application*
# `Pandas` menyediakan beberapa methods yang dapat mengakomodir proses manipulasi data terhadap objek `pandas.dataframe` dan `pandas.series` dengan menggunakan `methods` atau bahkan `user-defined functions` secara berantai (`method chaining`), antara lain:
# 1. `.apply()`, dengan format penulisan:
# ```python
# # Menerapkan method ke sebuah kolom tertentu:
# dataframe[<nama_kolom_baru>] = dataframe[<nama_kolom>].apply(lambda x: x.method())
# ```
# 2. `.assign()`, dengan format penulisan:
# ```python
# # Merubah value pada suatu kolom menggunakan method dan menyimpan hasilnya di kolom baru
# dataframe.assign(nama_kolom_baru=lambda x: x[<nama_kolom>].str.method())
# ```
# 3. `.pipe()`, dengan format penulisan:
# ```python
# # Memanipulasi dataframe menggunakan fungsi user-defined
# dataframe.pipe(<nama_fungsi_userdefined>, parameter=argument)
# ```
# Dari ketiga contoh format penulisan di atas, dua methods paling awal menggunakan sebuah fungsi anonymous dalam python, yang biasanya disebut sebagai `lambda function`.
# > `lambda function` adalah sebuah fungsi anonymous yang menerima banyak *arguments* namun hanya terdiri dari sebuah ekspresi.

# %% [markdown]
# #### Ilustrasi 11: Memanipulasi penulisan Nama Customer
# Lengkapi berbagai ekspresi yang tidak lengkap pada statements di `code cells` di bawah, lalu jawablah beberapa pertanyaan berikut:
# 1. Method apa yang dipergunakan untuk menyeragamkan format penulisan objek `str` menjadi huruf kapital?
# 2. Method apa yang dipergunakan untuk menyeragamkan format objek `str` ke lower case?
# 3. Method apa yang dipergunakan untuk memecah sebuah objek `str` menjadi sebuah list berisi beberapa elemen bertipe `str`.

# %%
df_superstore['Customer_Name'].head()
# Out:
# 0        Claire Gute
# 1        Claire Gute
# 2    Darrin Van Huff
# 3     Sean O'Donnell
# 4     Sean O'Donnell
# Name: Customer_Name, dtype: object

# %%
# Merubah Value pada Customer_Name menjadi huruf kapital menggunakan .apply()
df_superstore['Customer_Capitalized'] = df_superstore['Customer_Name'].apply(lambda x: x.upper())
# Out:
# 0            CLAIRE GUTE
# 1            CLAIRE GUTE
# 2        DARRIN VAN HUFF
# 3         SEAN O'DONNELL
# 4         SEAN O'DONNELL
#               ...
# 9989    TOM BOECKENHAUER
# 9990         DAVE BROOKS
# 9991         DAVE BROOKS
# 9992         DAVE BROOKS
# 9993        CHRIS CORTES
# Name: Customer_Name, Length: 9994, dtype: object

# %%
df_superstore_olahan.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0         2      0.00   41.9136        Furniture    Bookcases  ...
# 1         3      0.00  219.5820        Furniture       Chairs  ...
# 2         2      0.00    6.8714  Office Supplies       Labels  ...
# 3         5      0.45 -383.0310        Furniture       Tables  ...
# 4         2      0.20    2.5164  Office Supplies      Storage  ...
#
#      Customer_Name    Segment Country/Region             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   Region     Price     Share Customer_Capitalized Customer_Lower_Case
# 0  South  130.9800  0.011403          CLAIRE GUTE         claire gute
# 1  South  243.9800  0.031862          CLAIRE GUTE         claire gute
# 2   West    7.3100  0.000636      DARRIN VAN HUFF     darrin van huff
# 3  South  191.5155  0.041685       SEAN O'DONNELL      sean o'donnell
# 4  South   11.1840  0.000974       SEAN O'DONNELL      sean o'donnell
#
# [5 rows x 24 columns]

# %%
# Merubah Value pada Customer_Name menjadi lower case menggunakan .assign()
df_superstore_olahan = df_superstore.assign(Customer_Lower_Case=lambda x: x['Customer_Name'].str.lower())

# %%
# Check isi df_superstore
df_superstore.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0         2      0.00   41.9136        Furniture    Bookcases  ...
# 1         3      0.00  219.5820        Furniture       Chairs  ...
# 2         2      0.00    6.8714  Office Supplies       Labels  ...
# 3         5      0.45 -383.0310        Furniture       Tables  ...
# 4         2      0.20    2.5164  Office Supplies      Storage  ...
#
#         Ship_Mode    Customer_Name    Segment Country/Region             City  \
# 0    Second Class      Claire Gute   Consumer  United States        Henderson
# 1    Second Class      Claire Gute   Consumer  United States        Henderson
# 2    Second Class  Darrin Van Huff  Corporate  United States      Los Angeles
# 3  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State Region     Price     Share Customer_Capitalized
# 0    Kentucky  South  130.9800  0.011403          CLAIRE GUTE
# 1    Kentucky  South  243.9800  0.031862          CLAIRE GUTE
# 2  California   West    7.3100  0.000636      DARRIN VAN HUFF
# 3     Florida  South  191.5155  0.041685       SEAN O'DONNELL
# 4     Florida  South   11.1840  0.000974       SEAN O'DONNELL
#
# [5 rows x 23 columns]

# %%
# User-defined function
def split_string(
    df: object,
    nama_kolom: str,
    list_kolom_baru: list,
    pattern: str = " ",
    jumlah_split: int = 1,
    inplace: bool = False) -> object:
    """
    Fungsi untuk memecah value bertipe str pada sebuah kolom,
    lalu menyimpan hasilnya ke dua kolom baru
    Arguments:
       1. df: dataframe yang salah satu kolomnya akan displit;
       2. nama_kolom: Nama kolom yang valuenya akan displit;
       3. list_kolom_baru: List berisi dua nama kolom baru untuk menyimpan hasil split;
       4. pattern: Pola string yang dijadikan patokan bagi proses split;
       5. jumlah_split: Jumlah proses pemisahan yang dilakukan terhadap sebuah elemen;
       6. inplace: Proses pemisahan langsung dilakukan terhadap df original atau tidak.
    """
    # Validasi jumlah elemen list_kolom_baru
    if len(list_kolom_baru) != jumlah_split+1:
        raise ValueError('Jumlah elemen pada list_kolom_baru tidak sesuai dengan jumlah_split')

    # Split Strings lalu simpan di kolom baru
    if inplace == True:
        df[list_kolom_baru] = df[nama_kolom].str.split(pat=pattern, n=jumlah_split, expand=True)
        return df
    else:
        df_copy = df.copy()
        df_copy[list_kolom_baru] = df_copy[nama_kolom].str.split(pat=pattern, n=jumlah_split, expand=True)
        return df_copy

# %%
# Membuat kolom First_Name dan Last_Name menggunakan method .pipe()
df_superstore.pipe(split_string, nama_kolom='Customer_Name', list_kolom_baru=['First_Name', 'Last_Name'])
# Out:
#             Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0     CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1     CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2     CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3     US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4     US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
# ...              ...         ...          ...              ...       ...
# 9989  CA-2017-110422    TB-21400        33180  FUR-FU-10001889   25.2480
# 9990  CA-2020-121258    DB-13060        92627  FUR-FU-10000747   91.9600
# 9991  CA-2020-121258    DB-13060        92627  TEC-PH-10003645  258.5760
# 9992  CA-2020-121258    DB-13060        92627  OFF-PA-10004041   29.6000
# 9993  CA-2020-119914    CC-12220        92683  OFF-AP-10002684  243.1600
#
#       Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0            2      0.00   41.9136        Furniture    Bookcases  ...
# 1            3      0.00  219.5820        Furniture       Chairs  ...
# 2            2      0.00    6.8714  Office Supplies       Labels  ...
# 3            5      0.45 -383.0310        Furniture       Tables  ...
# 4            2      0.20    2.5164  Office Supplies      Storage  ...
# ...        ...       ...       ...              ...          ...  ...
# 9989         3      0.20    4.1028        Furniture  Furnishings  ...
# 9990         2      0.00   15.6332        Furniture  Furnishings  ...
# 9991         2      0.20   19.3932       Technology       Phones  ...
# 9992         4      0.00   13.3200  Office Supplies        Paper  ...
# 9993         2      0.00   72.9480  Office Supplies   Appliances  ...
#
#         Segment Country/Region             City       State Region     Price  \
# 0      Consumer  United States        Henderson    Kentucky  South  130.9800
# 1      Consumer  United States        Henderson    Kentucky  South  243.9800
# 2     Corporate  United States      Los Angeles  California   West    7.3100
# 3      Consumer  United States  Fort Lauderdale     Florida  South  191.5155
# 4      Consumer  United States  Fort Lauderdale     Florida  South   11.1840
# ...         ...            ...              ...         ...    ...       ...
# 9989   Consumer  United States            Miami     Florida  South    8.4160
# 9990   Consumer  United States       Costa Mesa  California   West   45.9800
# 9991   Consumer  United States       Costa Mesa  California   West  129.2880
# 9992   Consumer  United States       Costa Mesa  California   West    7.4000
# 9993   Consumer  United States      Westminster  California   West  121.5800
#
#          Share Customer_Capitalized First_Name     Last_Name
# 0     0.011403          CLAIRE GUTE     Claire          Gute
# 1     0.031862          CLAIRE GUTE     Claire          Gute
# 2     0.000636      DARRIN VAN HUFF     Darrin      Van Huff
# 3     0.041685       SEAN O'DONNELL       Sean     O'Donnell
# 4     0.000974       SEAN O'DONNELL       Sean     O'Donnell
# ...        ...                  ...        ...           ...
# 9989  0.001099     TOM BOECKENHAUER        Tom  Boeckenhauer
# 9990  0.004003          DAVE BROOKS       Dave        Brooks
# 9991  0.011256          DAVE BROOKS       Dave        Brooks
# 9992  0.001289          DAVE BROOKS       Dave        Brooks
# 9993  0.010585         CHRIS CORTES      Chris        Cortes
#
# [9994 rows x 25 columns]

# %%
# Cek lima rows paling atas pada df_superstore
df_superstore.head()
# Out:
#          Order_ID Customer_ID  Postal_Code       Product_ID     Sales  \
# 0  CA-2019-152156    CG-12520        42420  FUR-BO-10001798  261.9600
# 1  CA-2019-152156    CG-12520        42420  FUR-CH-10000454  731.9400
# 2  CA-2019-138688    DV-13045        90036  OFF-LA-10000240   14.6200
# 3  US-2018-108966    SO-20335        33311  FUR-TA-10000577  957.5775
# 4  US-2018-108966    SO-20335        33311  OFF-ST-10000760   22.3680
#
#    Quantity  Discount    Profit         Category Sub-Category  ...  \
# 0         2      0.00   41.9136        Furniture    Bookcases  ...
# 1         3      0.00  219.5820        Furniture       Chairs  ...
# 2         2      0.00    6.8714  Office Supplies       Labels  ...
# 3         5      0.45 -383.0310        Furniture       Tables  ...
# 4         2      0.20    2.5164  Office Supplies      Storage  ...
#
#         Ship_Mode    Customer_Name    Segment Country/Region             City  \
# 0    Second Class      Claire Gute   Consumer  United States        Henderson
# 1    Second Class      Claire Gute   Consumer  United States        Henderson
# 2    Second Class  Darrin Van Huff  Corporate  United States      Los Angeles
# 3  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4  Standard Class   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State Region     Price     Share Customer_Capitalized
# 0    Kentucky  South  130.9800  0.011403          CLAIRE GUTE
# 1    Kentucky  South  243.9800  0.031862          CLAIRE GUTE
# 2  California   West    7.3100  0.000636      DARRIN VAN HUFF
# 3     Florida  South  191.5155  0.041685       SEAN O'DONNELL
# 4     Florida  South   11.1840  0.000974       SEAN O'DONNELL
#
# [5 rows x 23 columns]

# %%
# Melakukan manipulasi secara method Chaining dari awal hingga akhir
(pd.read_csv(file_path, usecols=['Customer_Name'])
 .assign(Customer_Capitalized=lambda x: x['Customer_Name'].str.upper(),
         Customer_Lower_Case=lambda x: x['Customer_Name'].str.lower())
 .pipe(split_string, nama_kolom='Customer_Name', list_kolom_baru=['First_Name', 'Last_Name']))
# Out:
#          Customer_Name Customer_Capitalized Customer_Lower_Case First_Name  \
# 0          Claire Gute          CLAIRE GUTE         claire gute     Claire
# 1          Claire Gute          CLAIRE GUTE         claire gute     Claire
# 2      Darrin Van Huff      DARRIN VAN HUFF     darrin van huff     Darrin
# 3       Sean O'Donnell       SEAN O'DONNELL      sean o'donnell       Sean
# 4       Sean O'Donnell       SEAN O'DONNELL      sean o'donnell       Sean
# ...                ...                  ...                 ...        ...
# 9989  Tom Boeckenhauer     TOM BOECKENHAUER    tom boeckenhauer        Tom
# 9990       Dave Brooks          DAVE BROOKS         dave brooks       Dave
# 9991       Dave Brooks          DAVE BROOKS         dave brooks       Dave
# 9992       Dave Brooks          DAVE BROOKS         dave brooks       Dave
# 9993      Chris Cortes         CHRIS CORTES        chris cortes      Chris
#
#          Last_Name
# 0             Gute
# 1             Gute
# 2         Van Huff
# 3        O'Donnell
# 4        O'Donnell
# ...            ...
# 9989  Boeckenhauer
# 9990        Brooks
# 9991        Brooks
# 9992        Brooks
# 9993        Cortes
#
# [9994 rows x 5 columns]

# %% [markdown]
# ### *Grouping and Aggregation*
# Secara sederhana, proses mengaggregatkan sekelompok value, seperti yang dimuat dalam sebuah `pandas.series` dapat dilakukan dengan menggunakan beberapa method seperti berikut:
# 1. `.sum()`;
# 2. `.count()`;
# 3. `.mean()`;
# 4. `.median()`;
# 5. `.min()`;
# 6. `.max()`; dan
# 7. `.std()`.
#
# Namun pada prakteknya, aggregasi akan jauh lebih bermanfaat jika dilakukan berdasarkan pengelompokkan atau pelabelan tertentu. Untuk melakukan aggregasi dengan pengelompokkan, maka `pandas` menyediakan method `.groupby()` yang dapat dikombinasikan langsung dengan `aggregate methods` di atas, dengan format penulisan seperti berikut ini:
# ```python
# # Aggregasi dengan grouping sederhana
# dataframe.groupby([<kolom_kolom_pengelompokkan>])[kolom_dihitung].method()
# ```
# Tak jarang diperlukan beberapa aggregasi yang dilakukan sekaligus terhadap beberapa values, berdasarkan pengelompokkan tertentu. `Pandas` juga menyediakan fitur yang memungkinkan dilakukannya kebutuhan seperti tersebut, melalui method `.agg()`, dengan format penulisan sebagai berikut:
# ```python
# # Multiple Aggregation
# dataframe.groupby([<kolom_kolom_pengelompokkan>]).agg({
#   'kolom_dihitung_1':[fungsi_fungsi_aggregat],
#   'kolom_dihitung_2':[fungsi_fungsi_aggregat]
# })
# ```

# %% [markdown]
# #### Ilustrasi 12: Grouping and Aggregation
# Lengkapi ekspresi yang tidak lengkap pada setiap statements di `cell codes` di bawah, lalu jawab pertanyaan ini:
# 1. Negara bagian mana yang memiliki rata-rata Sales paling tinggi?
# 2. Negara bagian mana yang memiliki total Profit paling rendah?
# 2. Apa perbedaan baik dari proses maupun output yang dihasilkan antara aggregasi sederhana dengan aggregasi menggunakan method `.agg()`?

# %%
# Aggregasi Sederhana Rata-rata Sales per Negara Bagian
df_superstore.groupby(['State'])['Sales'].mean()
# Out:
# State
# Alabama                  319.846557
# Arizona                  157.508933
# Arkansas                 194.635500
# California               228.729451
# Colorado                 176.418231
# Connecticut              163.223866
# Delaware                 285.948635
# District of Columbia     286.502000
# Florida                  233.612815
# Georgia                  266.825217
# Idaho                    208.689810
# Illinois                 162.939230
# Indiana                  359.431946
# Iowa                     152.658667
# Kansas                   121.429583
# Kentucky                 263.250000
# Louisiana                219.453095
# Maine                    158.816250
# Maryland                 225.766886
# Massachusetts            212.106919
# Michigan                 299.096525
# Minnesota                335.541011
# Mississippi              203.232830
# Missouri                 336.441667
# Montana                  372.623467
# Nebraska                 196.445526
# Nevada                   428.951333
# New Hampshire            270.093481
# New Jersey               275.110092
# New Mexico               129.284378
# New York                 275.599531
# North Carolina           223.305880
# North Dakota             131.415714
# Ohio                     166.861697
# Oklahoma                 298.233182
# Oregon                   140.573790
# Pennsylvania             198.487077
# Rhode Island             404.070643
# South Carolina           201.945476
# South Dakota             109.630000
# Tennessee                167.551219
# Texas                    172.779742
# Utah                     211.699170
# Vermont                  811.760909
# Virginia                 315.342500
# Washington               273.994605
# West Virginia            302.456000
# Wisconsin                291.951000
# Wyoming                 1603.136000
# Name: Sales, dtype: float64

# %%
# Aggregasi Sederhana Total Profit per Negara Bagian
df_superstore.groupby(['State'])['Profit'].sum()
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# Nevada                   3316.7659
# New Hampshire            1706.5028
# New Jersey               9772.9138
# New Mexico               1157.1161
# New York                74038.5486
# North Carolina          -7490.9122
# North Dakota              230.1497
# Ohio                   -16971.3766
# Oklahoma                 4853.9560
# Oregon                  -1190.4705
# Pennsylvania           -15559.9603
# Rhode Island             7285.6293
# South Carolina           1769.0566
# South Dakota              394.8283
# Tennessee               -5341.6936
# Texas                  -25729.3563
# Utah                     2546.5335
# Vermont                  2244.9783
# Virginia                18597.9504
# Washington              33402.6517
# West Virginia             185.9216
# Wisconsin                8401.8004
# Wyoming                   100.1960
# Name: Profit, dtype: float64

# %%
# Aggregasi Total dan Rata-rata Sales dan Profit per Negara Bagian
(df_superstore
 .groupby(['State'])
 .agg({'Sales':['sum', 'mean'], 'Profit':['sum', 'mean']})
 .rename(columns={'sum':'Total', 'mean':'Rataan'}))
# Out:
#                             Sales                   Profit
#                             Total       Rataan       Total      Rataan
# State
# Alabama                19510.6400   319.846557   5786.8253   94.865989
# Arizona                35282.0010   157.508933  -3427.9246  -15.303235
# Arkansas               11678.1300   194.635500   4008.6871   66.811452
# California            457687.6315   228.729451  76381.3871   38.171608
# Colorado               32108.1180   176.418231  -6527.8579  -35.867351
# Connecticut            13384.3570   163.223866   3511.4918   42.823071
# Delaware               27451.0690   285.948635   9977.3748  103.930988
# District of Columbia    2865.0200   286.502000   1059.5893  105.958930
# Florida                89473.7080   233.612815  -3399.3017   -8.875461
# Georgia                49095.8400   266.825217  16250.0433   88.315453
# Idaho                   4382.4860   208.689810    826.7231   39.367767
# Illinois               80166.1010   162.939230 -12607.8870  -25.625787
# Indiana                53555.3600   359.431946  18382.9363  123.375411
# Iowa                    4579.7600   152.658667   1183.8119   39.460397
# Kansas                  2914.3100   121.429583    836.4435   34.851813
# Kentucky               36591.7500   263.250000  11199.6966   80.573357
# Louisiana               9217.0300   219.453095   2196.1023   52.288150
# Maine                   1270.5300   158.816250    454.4862   56.810775
# Maryland               23705.5230   225.766886   7031.1788   66.963608
# Massachusetts          28634.4340   212.106919   6785.5016   50.262975
# Michigan               76269.6140   299.096525  24463.1876   95.934069
# Minnesota              29863.1500   335.541011  10823.1874  121.608847
# Mississippi            10771.3400   203.232830   3172.9762   59.867475
# Missouri               22205.1500   336.441667   6436.2105   97.518341
# Montana                 5589.3520   372.623467   1833.3285  122.221900
# Nebraska                7464.9300   196.445526   2037.0942   53.607742
# Nevada                 16729.1020   428.951333   3316.7659   85.045279
# New Hampshire           7292.5240   270.093481   1706.5028   63.203807
# New Jersey             35764.3120   275.110092   9772.9138   75.176260
# New Mexico              4783.5220   129.284378   1157.1161   31.273408
# New York              310876.2710   275.599531  74038.5486   65.637011
# North Carolina         55603.1640   223.305880  -7490.9122  -30.083985
# North Dakota             919.9100   131.415714    230.1497   32.878529
# Ohio                   78258.1360   166.861697 -16971.3766  -36.186304
# Oklahoma               19683.3900   298.233182   4853.9560   73.544788
# Oregon                 17431.1500   140.573790  -1190.4705   -9.600569
# Pennsylvania          116511.9140   198.487077 -15559.9603  -26.507598
# Rhode Island           22627.9560   404.070643   7285.6293  130.100523
# South Carolina          8481.7100   201.945476   1769.0566   42.120395
# South Dakota            1315.5600   109.630000    394.8283   32.902358
# Tennessee              30661.8730   167.551219  -5341.6936  -29.189583
# Texas                 170188.0458   172.779742 -25729.3563  -26.121174
# Utah                   11220.0560   211.699170   2546.5335   48.047802
# Vermont                 8929.3700   811.760909   2244.9783  204.088936
# Virginia               70636.7200   315.342500  18597.9504   83.026564
# Washington            138641.2700   273.994605  33402.6517   66.013146
# West Virginia           1209.8240   302.456000    185.9216   46.480400
# Wisconsin              32114.6100   291.951000   8401.8004   76.380004
# Wyoming                 1603.1360  1603.136000    100.1960  100.196000

# %% [markdown]
# ## EXERCISE 4
# 1. Lakukan aggregasi data df_superstore berdasarkan `Category` dan `Sub-Category`;
# 2. Hitung Total, Jumlah, dan Rata-rata dari `Sales`;
# 3. Gunakan method `.assign()` untuk menghitung persentase `Sales` dari Total `Sales` untuk masing-masing `row`, simpan ke kolom baru bernama `Sales_Share`;
# 4. Simpan hasil pengolahan ke variabel `sales_by_cat`.

# %%
sales_by_cat =(
    df_superstore
    .groupby(['Category', 'Sub-Category'])
    .agg({'Sales':['sum', 'count', 'mean']})
    .assign(Sales_Share=lambda x: (x[('Sales', 'sum')] / x[('Sales', 'sum')].sum()) * 100)
)
sales_by_cat
# Out:
#                                     Sales                    Sales_Share
#                                       sum count         mean
# Category        Sub-Category
# Furniture       Bookcases     114879.9963   228   503.859633    5.000869
#                 Chairs        328449.1030   617   532.332420   14.297796
#                 Furnishings    91705.1640   957    95.825668    3.992039
#                 Tables        206965.5320   319   648.794771    9.009466
# Office Supplies Appliances    107532.1610   466   230.755710    4.681008
#                 Art            27118.7920   796    34.068834    1.180515
#                 Binders       203412.7330  1523   133.560560    8.854808
#                 Envelopes      16476.4020   254    64.867724    0.717238
#                 Fasteners       3024.2800   217    13.936774    0.131651
#                 Labels         12486.3120   364    34.303055    0.543545
#                 Paper          78479.2060  1370    57.284092    3.416297
#                 Storage       223843.6080   846   264.590553    9.744190
#                 Supplies       46673.5380   190   245.650200    2.031757
# Technology      Accessories   167380.3180   775   215.974604    7.286273
#                 Copiers       149528.0300    68  2198.941618    6.509140
#                 Machines      189238.6310   115  1645.553313    8.237792
#                 Phones        330007.0540   889   371.211534   14.365616

# %%
sales_by_cat[[('Sales', 'count')]]
# Out:
#                              Sales
#                              count
# Category        Sub-Category
# Furniture       Bookcases      228
#                 Chairs         617
#                 Furnishings    957
#                 Tables         319
# Office Supplies Appliances     466
#                 Art            796
#                 Binders       1523
#                 Envelopes      254
#                 Fasteners      217
#                 Labels         364
#                 Paper         1370
#                 Storage        846
#                 Supplies       190
# Technology      Accessories    775
#                 Copiers         68
#                 Machines       115
#                 Phones         889

# %% [markdown]
# ## *Pivot Table*
# Salah satu fitur penting yang disediakan `pandas` untuk melakukan data manipulation adalah fungsi `pandas.pivot_table()`. Pada dasarnya fungsi ini menghasilkan output yang hampir serupa dengan proses `Grouping and Aggregation` seperti dijelaskan sebelumnya. Format penulisan bagi fungsi ini adalah sebagai berikut:
# ```python
# pd.pivot_table(df,
#   index=[kolom_kolom_grouping],
#   values=kolom_dihitung,
#   columns=[kolom_kolom_pemilah_values],
#   aggfunc=[fungsi_fungsi_aggregasi]
# )
# ```

# %% [markdown]
# #### Ilustrasi 13: `pd.pivot_table`
# Melakukan Aggregasi Total, Jumlah, dan Rata-rata dari `Sales` per `Region`, yang dikelompokkan berdasarkan `Category` dan `Sub-Category` dari produk menggunakan fungsi `pd.pivot_table()`. Lengkapi ekspresi yang tidak lengkap pada statement di bawah ini, lalu eksekusi untuk melihat hasilnya.

# %%
pd.pivot_table(
    data=pd.read_csv(file_path, usecols=['Category', 'Segment', 'Sales', 'Region']),
    index=['Category', 'Segment'],
    columns='Region',
    values='Sales',
    aggfunc=['sum', 'count', 'mean'],
    margins=True,
    margins_name='All'
)
# Out:
#                                      sum                           \
# Region                           Central        East        South
# Category        Segment
# Furniture       Consumer      86229.2190  114211.802   70800.2040
#                 Corporate     52085.6018   64209.046   29645.0315
#                 Home Office   25482.3430   29870.356   16853.4485
# Office Supplies Consumer      93111.4790  101255.136   59504.5810
#                 Corporate     41137.7010   66474.735   45930.1700
#                 Home Office   32777.2350   37786.184   20216.5620
# Technology      Consumer      72690.7360  135441.229   65276.1860
#                 Corporate     64772.5100   69725.566   46310.7310
#                 Home Office   32953.0660   59807.186   37184.9910
# All                          501239.8908  678781.240  391721.9050
#
#                                                          count              \
# Region                              West           All Central  East South
# Category        Segment
# Furniture       Consumer     119808.0870  3.910493e+05     255   303   180
#                 Corporate     83080.1065  2.290198e+05     137   198   101
#                 Home Office   49724.5500  1.219307e+05      89   100    51
# Office Supplies Consumer     110080.9400  3.639521e+05     739   888   505
#                 Corporate     77133.8560  2.306765e+05     417   520   324
#                 Home Office   33638.4530  1.244184e+05     266   304   166
# Technology      Consumer     132991.7460  4.063999e+05     218   278   153
#                 Corporate     65641.3120  2.464501e+05     119   159    85
#                 Home Office   53358.7740  1.833040e+05      83    98    55
# All                          725457.8245  2.297201e+06    2323  2848  1620
#
#                                                mean                          \
# Region                       West   All     Central        East       South
# Category        Segment
# Furniture       Consumer      375  1113  338.153800  376.936640  393.334467
#                 Corporate     210   646  380.186874  324.288111  293.515163
#                 Home Office   122   362  286.318461  298.703560  330.459775
# Office Supplies Consumer      995  3127  125.996589  114.026054  117.830853
#                 Corporate     559  1820   98.651561  127.836029  141.759784
#                 Home Office   343  1079  123.222688  124.296658  121.786518
# Technology      Consumer      302   951  333.443743  487.198665  426.641739
#                 Corporate     191   554  544.306807  438.525572  544.832129
#                 Home Office   106   342  397.024892  610.277408  676.090745
# All                          3203  9994  215.772661  238.336110  241.803645
#
#
# Region                             West         All
# Category        Segment
# Furniture       Consumer     319.488232  351.347091
#                 Corporate    395.619555  354.519792
#                 Home Office  407.578279  336.825131
# Office Supplies Consumer     110.634111  116.390194
#                 Corporate    137.985431  126.745309
#                 Home Office   98.071292  115.309021
# Technology      Consumer     440.370020  427.339534
#                 Corporate    343.671791  444.855810
#                 Home Office  503.384660  535.976658
# All                          226.493233  229.858001

# %% [markdown]
# # *Serialization*
# > *Serialization* adalah proses konversi sebuah objek ke format yang memudahkan penyimpanan atau pengiriman.
#
# Python secara khusus menyediakan modul/library bernama `pickle` untuk tujuan *serialization* ini. Meskipun demikian, `pandas` memberikan keleluasaan pengguna untuk melakukan *serialization* object `dataframe` ke berbagai tipe file lainnya, seperti:
# 1. `.csv` dan `.txt` dengan menggunakan method `pandas.dataframe.to_csv()`;
# 2. `.json` dengan menggunakan method `pandas.dataframe.to_json()`;
# 3. `.xlsx` atau `.xls` dengan menggunakan method `pandas.dataframe.to_excel()`; atau
# 4. `pickle` file yang dapat memuat semua object python.

# %% [markdown]
# ## EXERCISE 5: Menyimpan Hasil Manipulasi langsung ke file `.csv`
# Ikuti perintah di bawah berikut untuk melakukan manipulasi data terhadap dataframe `df_superstore`:
# 1. Buat sebuah filter untuk hanya menunjukkan `rows` dengan value 'Technology' pada kolom `Category`, simpan pada sebuah variable bernama `filter_data`;
# 2. Buat list, `kolom_diperlukan`, yang berisi `Product_Name`, `Quantity`, dan `Sales`;
# 3. Lakukan manipulasi data dengan urutan seperti berikut:
#   - Gunakan *accessor* `loc` untuk memilah data dengan memanfaatkan `filter_data`, dan `kolom_diperlukan`;
#   - Kelompokkan `dataframe` berdasarkan `Product_Name`;
#   - Lakukan aggregasi berupa penjumlahan bagi kolom `Quantity` dan `Sales`;
#   - Gunakan method `.assign()` untuk menghitung Harga setiap `Product_Name` yang disimpan pada kolom baru bernama `Price`;
#   - Ambil hanya 10 item dengan nilai `Price` paling tinggi;
#   - Gunakan method `.reset_index()`;
#   - Lakukan *Serialization* dari `dataframe` hasil manipulasi ke sebuah file `.csv` bernama `Top 10 Most Expensive Technology Items.csv`.

# %%
# Buat Filter
filter_data = df_superstore['Category']=='Technology'

# Buat List Kolom
kolom_diperlukan = ['Product_Name', 'Quantity', 'Sales']

# Proses Data Manipulation dan Serialization to_csv
(df_superstore
 .loc[filter_data, kolom_diperlukan]
 .groupby('Product_Name')
 .agg({'Quantity':'sum', 'Sales':'sum'})
 .assign(Price=lambda x: x['Sales']/x['Quantity'])
 .nlargest(10, 'Price')
 .reset_index()
 .to_csv('Top 10 Most Expensive Technology Items.csv', index=False)
)

# %% [markdown]
# ___
